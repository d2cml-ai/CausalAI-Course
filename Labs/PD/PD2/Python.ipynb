# %%
# !pip install numpy scikit-learn seaborn matplotlib

# %% [markdown]
# ## 1. Fitting polinomial predictors to data

# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### First, generate the features from $U~(0,1)$

# %%
W = np.random.uniform(0, 1, 1000)
W.sort()
W = W.reshape(-1, 1)
print(W)
# Out:
# [[0.00153724]
#  [0.00163377]
#  [0.00222891]
#  [0.00290419]
#  [0.00306319]
#  [0.00341952]
#  [0.00391838]
#  [0.00494968]
#  [0.00587443]
#  [0.00623517]
#  [0.00660415]
#  [0.00900393]
#  [0.00965927]
#  [0.01149455]
#  [0.01172319]
#  [0.01238886]
#  [0.01257186]
#  [0.01268653]
#  [0.01291856]
#  [0.01532588]
#  [0.01547315]
#  [0.01622849]
#  [0.01661184]
#  [0.01734112]
#  [0.01864068]
#  [0.01926228]
#  [0.02061034]
#  [0.02197195]
#  [0.02273676]
#  [0.02570752]
#  [0.02920364]
#  [0.0292592 ]
#  [0.02996086]
#  [0.03017554]
#  [0.03074685]
#  [0.03273538]
#  [0.0330091 ]
#  [0.03427281]
#  [0.03798914]
#  [0.03869459]
#  [0.03870025]
#  [0.04209088]
#  [0.04234036]
#  [0.04285388]
#  [0.04301683]
#  [0.04324241]
#  [0.04461505]
#  [0.04694275]
#  [0.04851036]
#  [0.04954145]
#  [0.04977266]
#  [0.04999399]
#  [0.05001429]
#  [0.05026951]
#  [0.05126542]
#  [0.0521955 ]
#  [0.05272446]
#  [0.05311949]
#  [0.05757509]
#  [0.05792743]
#  [0.05795451]
#  [0.05796881]
#  [0.05812029]
#  [0.05872805]
#  [0.05912667]
#  [0.06066714]
#  [0.06078202]
#  [0.06127456]
#  [0.06217739]
#  [0.06256564]
#  [0.06384339]
#  [0.06387351]
#  [0.06445191]
#  [0.06460114]
#  [0.06483676]
#  [0.06509121]
#  [0.06597329]
#  [0.06868679]
#  [0.06929324]
#  [0.06947262]
#  [0.07053617]
#  [0.07112097]
#  [0.07158781]
#  [0.07244325]
#  [0.07311842]
#  [0.07390734]
#  [0.07461974]
#  [0.07470557]
#  [0.07572264]
#  [0.08285646]
#  [0.08599794]
#  [0.08637886]
#  [0.08671028]
#  [0.08723703]
#  [0.08773955]
#  [0.08784907]
#  [0.08843143]
#  [0.08906314]
#  [0.09063242]
#  [0.09068243]
#  [0.09219681]
#  [0.09230715]
#  [0.09240852]
#  [0.09524282]
#  [0.09582419]
#  [0.09587288]
#  [0.09740724]
#  [0.09771014]
#  [0.09883637]
#  [0.09899004]
#  [0.09984493]
#  [0.10000215]
#  [0.10038913]
#  [0.10046553]
#  [0.10134945]
#  [0.10235996]
#  [0.10426508]
#  [0.10482455]
#  [0.10655681]
#  [0.10700061]
#  [0.11049722]
#  [0.1111086 ]
#  [0.11167393]
#  [0.11523854]
#  [0.11592436]
#  [0.11698558]
#  [0.1174424 ]
#  [0.11823854]
#  [0.11843433]
#  [0.1194306 ]
#  [0.11973684]
#  [0.11990525]
#  [0.12084466]
#  [0.12111455]
#  [0.12127365]
#  [0.12267884]
#  [0.12355387]
#  [0.1245021 ]
#  [0.12514822]
#  [0.12635914]
#  [0.13016298]
#  [0.13048842]
#  [0.13060891]
#  [0.13119237]
#  [0.13164954]
#  [0.13254268]
#  [0.13452138]
#  [0.13548486]
#  [0.13585862]
#  [0.1360492 ]
#  [0.13799705]
#  [0.13801911]
#  [0.13843351]
#  [0.13961618]
#  [0.1411409 ]
#  [0.14134669]
#  [0.14760015]
#  [0.14793175]
#  [0.14797118]
#  [0.15055391]
#  [0.15122271]
#  [0.15130352]
#  [0.15188797]
#  [0.15206467]
#  [0.15493047]
#  [0.15637596]
#  [0.1572765 ]
#  [0.15809654]
#  [0.1586594 ]
#  [0.15866168]
#  [0.15971049]
#  [0.16315464]
#  [0.16320093]
#  [0.16345671]
#  [0.16377362]
#  [0.16436456]
#  [0.16541124]
#  [0.16543382]
#  [0.16545936]
#  [0.16692457]
#  [0.16734315]
#  [0.16947548]
#  [0.17172418]
#  [0.1731149 ]
#  [0.17608036]
#  [0.17674109]
#  [0.17699731]
#  [0.1777934 ]
#  [0.17822649]
#  [0.17949191]
#  [0.18054231]
#  [0.18082756]
#  [0.18331547]
#  [0.1834824 ]
#  [0.18470715]
#  [0.18589581]
#  [0.18731711]
#  [0.1878903 ]
#  [0.19015575]
#  [0.19065633]
#  [0.19077337]
#  [0.1952554 ]
#  [0.19613864]
#  [0.19907247]
#  [0.19939821]
#  [0.19947149]
#  [0.19957929]
#  [0.19994301]
#  [0.19997097]
#  [0.20173799]
#  [0.20179274]
#  [0.20306948]
#  [0.20324579]
#  [0.20339409]
#  [0.20408727]
#  [0.20559009]
#  [0.21008169]
#  [0.21294506]
#  [0.21369233]
#  [0.21722337]
#  [0.21744459]
#  [0.21794279]
#  [0.21809277]
#  [0.22089526]
#  [0.22225787]
#  [0.22450849]
#  [0.22609725]
#  [0.22635465]
#  [0.22796434]
#  [0.2292926 ]
#  [0.22967276]
#  [0.23242562]
#  [0.2341771 ]
#  [0.23426992]
#  [0.23595083]
#  [0.23667724]
#  [0.23766844]
#  [0.23861154]
#  [0.23894502]
#  [0.23970672]
#  [0.24081012]
#  [0.24164993]
#  [0.24333038]
#  [0.24375883]
#  [0.24436754]
#  [0.24461422]
#  [0.24510855]
#  [0.24516404]
#  [0.2455021 ]
#  [0.24758829]
#  [0.24860652]
#  [0.25006172]
#  [0.25071667]
#  [0.2507387 ]
#  [0.25101912]
#  [0.25146965]
#  [0.2516927 ]
#  [0.25357532]
#  [0.25365313]
#  [0.25391147]
#  [0.25398915]
#  [0.2542577 ]
#  [0.25428263]
#  [0.2547967 ]
#  [0.25537837]
#  [0.25545102]
#  [0.25584015]
#  [0.25596535]
#  [0.25710793]
#  [0.25714454]
#  [0.25759047]
#  [0.25954699]
#  [0.26011838]
#  [0.26027858]
#  [0.26385514]
#  [0.26574321]
#  [0.26681237]
#  [0.26760163]
#  [0.26801138]
#  [0.26870889]
#  [0.26877949]
#  [0.26903354]
#  [0.27060234]
#  [0.55175673]
#  [0.55276273]
#  [0.55315196]
#  [0.55408158]
#  [0.55811106]
#  [0.55866863]
#  [0.5590677 ]
#  [0.56437015]
#  [0.56464127]
#  [0.564644  ]
#  [0.56900552]
#  [0.57065032]
#  [0.57094548]
#  [0.57123721]
#  [0.57208955]
#  [0.57270679]
#  [0.57274128]
#  [0.57306871]
#  [0.57416575]
#  [0.5753333 ]
#  [0.575469  ]
#  [0.57603988]
#  [0.57643121]
#  [0.57680094]
#  [0.5768219 ]
#  [0.57730952]
#  [0.57917805]
#  [0.58015608]
#  [0.58060117]
#  [0.58112074]
#  [0.5819835 ]
#  [0.58272901]
#  [0.58504696]
#  [0.58670224]
#  [0.5882333 ]
#  [0.58841905]
#  [0.58844387]
#  [0.5884743 ]
#  [0.58882202]
#  [0.58909087]
#  [0.58927647]
#  [0.59034131]
#  [0.59073922]
#  [0.59244011]
#  [0.59246481]
#  [0.59444772]
#  [0.59516827]
#  [0.59699892]
#  [0.59934061]
#  [0.60019446]
#  [0.60048016]
#  [0.6006012 ]
#  [0.60060183]
#  [0.60092424]
#  [0.60138124]
#  [0.60146701]
#  [0.60151821]
#  [0.60278904]
#  [0.60370246]
#  [0.60378651]
#  [0.60875634]
#  [0.6132722 ]
#  [0.61372826]
#  [0.6152687 ]
#  [0.61595542]
#  [0.61637592]
#  [0.6165249 ]
#  [0.61707803]
#  [0.61775275]
#  [0.62058039]
#  [0.62078111]
#  [0.62108385]
#  [0.62201362]
#  [0.62286148]
#  [0.62317821]
#  [0.62319029]
#  [0.6264929 ]
#  [0.62695163]
#  [0.62696863]
#  [0.62701583]
#  [0.62965485]
#  [0.62976001]
#  [0.63171652]
#  [0.63322488]
#  [0.63349295]
#  [0.63592507]
#  [0.63604373]
#  [0.63884921]
#  [0.63894475]
#  [0.63916111]
#  [0.64020991]
#  [0.64114473]
#  [0.64275636]
#  [0.64379933]
#  [0.6455189 ]
#  [0.64553087]
#  [0.64809838]
#  [0.64987136]
#  [0.65031248]
#  [0.65290884]
#  [0.65331279]
#  [0.65467499]
#  [0.65697282]
#  [0.6569898 ]
#  [0.65750156]
#  [0.66001706]
#  [0.66009721]
#  [0.66178173]
#  [0.66263483]
#  [0.66298082]
#  [0.66433879]
#  [0.66457618]
#  [0.66818414]
#  [0.67079348]
#  [0.67153782]
#  [0.67368444]
#  [0.67435509]
#  [0.67483086]
#  [0.67533182]
#  [0.67540839]
#  [0.67722773]
#  [0.67737876]
#  [0.67905677]
#  [0.67949543]
#  [0.68035509]
#  [0.68089455]
#  [0.68128939]
#  [0.68345884]
#  [0.68490961]
#  [0.68536045]
#  [0.68686634]
#  [0.68729368]
#  [0.69205414]
#  [0.69360085]
#  [0.69368818]
#  [0.69497372]
#  [0.69555959]
#  [0.69611221]
#  [0.69724492]
#  [0.69890442]
#  [0.69990478]
#  [0.70010298]
#  [0.70201033]
#  [0.7033082 ]
#  [0.70436165]
#  [0.70462068]
#  [0.70757103]
#  [0.70958295]
#  [0.71000107]
#  [0.87499122]
#  [0.87719315]
#  [0.87822399]
#  [0.87966528]
#  [0.88097549]
#  [0.88266193]
#  [0.88281628]
#  [0.88320832]
#  [0.88377476]
#  [0.88392793]
#  [0.88459629]
#  [0.88583313]
#  [0.8925406 ]
#  [0.89424211]
#  [0.89476326]
#  [0.89480988]
#  [0.89691933]
#  [0.89780659]
#  [0.89874062]
#  [0.8989147 ]
#  [0.89922453]
#  [0.90032106]
#  [0.90144998]
#  [0.90575049]
#  [0.90645572]
#  [0.90691924]
#  [0.90739131]
#  [0.90791271]
#  [0.90805466]
#  [0.90878453]
#  [0.90983104]
#  [0.9105108 ]
#  [0.91316136]
#  [0.91358795]
#  [0.91425352]
#  [0.91482412]
#  [0.91564241]
#  [0.91567313]
#  [0.91612367]
#  [0.91635384]
#  [0.9170826 ]
#  [0.91749669]
#  [0.91865378]
#  [0.92052842]
#  [0.92083204]
#  [0.92131908]
#  [0.92150747]
#  [0.92176789]
#  [0.92178644]
#  [0.92192039]
#  [0.9226344 ]
#  [0.92266758]
#  [0.92335531]
#  [0.92412114]
#  [0.92417714]
#  [0.9245815 ]
#  [0.92476494]
#  [0.92484578]
#  [0.92670555]
#  [0.92685432]
#  [0.92968033]
#  [0.93009685]
#  [0.9320485 ]
#  [0.93412456]
#  [0.93509199]
#  [0.93512029]
#  [0.93919233]
#  [0.93944421]
#  [0.94044473]
#  [0.94072891]
#  [0.94105936]
#  [0.94154836]
#  [0.94248882]
#  [0.94335703]
#  [0.94387236]
#  [0.94432389]
#  [0.94454544]
#  [0.94707334]
#  [0.94799773]
#  [0.94808895]
#  [0.95004445]
#  [0.95138705]
#  [0.95177306]
#  [0.95573134]
#  [0.96102607]
#  [0.96176137]
#  [0.96251647]
#  [0.96295524]
#  [0.96297764]
#  [0.96315165]
#  [0.96453096]
#  [0.96560498]
#  [0.965625  ]
#  [0.96844177]
#  [0.96859483]
#  [0.96960043]
#  [0.96976125]
#  [0.97003649]
#  [0.97138704]
#  [0.97300267]
#  [0.97306634]
#  [0.97316116]
#  [0.9733617 ]
#  [0.97456766]
#  [0.97478016]
#  [0.97564808]
#  [0.97649471]
#  [0.9765471 ]
#  [0.98034637]
#  [0.98306749]
#  [0.98499649]
#  [0.98696028]
#  [0.98712391]
#  [0.98950883]
#  [0.99046211]
#  [0.99130232]
#  [0.99139057]
#  [0.99381014]
#  [0.99447759]
#  [0.9952344 ]
#  [0.99568714]
#  [0.99661582]
#  [0.99791405]
#  [0.99824097]
#  [0.99981783]]

# %%
e = np.random.normal(0,1,1000)
e = e.reshape(-1,1)
print(e)
e.shape
# Out:
# [[-4.16548162e-01]
#  [-1.23043750e+00]
#  [ 6.48455670e-02]
#  [-2.13870199e+00]
#  [ 2.02224128e+00]
#  [-8.31250890e-01]
#  [-1.16295594e+00]
#  [ 3.42565733e-01]
#  [-7.16286114e-01]
#  [-2.86211482e+00]
#  [-1.40693590e+00]
#  [ 2.27375318e-01]
#  [-4.87930487e-01]
#  [-8.60893291e-01]
#  [ 4.05064238e-01]
#  [ 6.45922697e-01]
#  [-6.22167121e-01]
#  [ 1.02581418e+00]
#  [ 1.71562343e-01]
#  [-5.71579602e-01]
#  [-3.74955879e-01]
#  [ 2.73447461e-02]
#  [-5.58134791e-02]
#  [ 4.74482485e-01]
#  [ 8.86501330e-01]
#  [ 9.70346146e-01]
#  [ 1.17527974e+00]
#  [ 1.80843614e-01]
#  [-7.24292603e-01]
#  [-6.48299248e-01]
#  [ 1.59099611e-03]
#  [-1.15042540e+00]
#  [ 1.00612223e+00]
#  [-9.47507895e-01]
#  [ 6.71731345e-01]
#  [ 3.86435134e-01]
#  [-7.76071593e-01]
#  [-8.40718126e-01]
#  [ 6.31682928e-01]
#  [ 1.68192935e-01]
#  [-2.17460887e+00]
#  [ 4.49566049e-01]
#  [-5.82486222e-02]
#  [ 7.94574219e-01]
#  [ 6.15657255e-01]
#  [-1.55872930e+00]
#  [ 1.16124490e-01]
#  [-7.92781891e-01]
#  [ 5.20746231e-01]
#  [ 1.95474001e-01]
#  [-6.44158891e-01]
#  [ 6.64355528e-01]
#  [ 2.03317006e-01]
#  [ 4.16782592e-02]
#  [ 1.57599018e+00]
#  [-1.38060241e+00]
#  [ 7.93109103e-02]
#  [-2.98152370e-01]
#  [-1.76281568e+00]
#  [ 5.85804226e-01]
#  [-2.47377807e-01]
#  [ 8.56990287e-01]
#  [-6.81254596e-01]
#  [-1.93886948e+00]
#  [ 3.39376941e-01]
#  [ 2.57636854e-01]
#  [ 1.27601076e+00]
#  [ 1.25377253e+00]
#  [-7.58414706e-01]
#  [ 7.99598001e-01]
#  [ 7.26088993e-01]
#  [-5.62224768e-01]
#  [ 3.81744146e-01]
#  [ 4.44596331e-01]
#  [-8.76449070e-01]
#  [-4.85595783e-01]
#  [-9.37927768e-01]
#  [-1.72238903e+00]
#  [ 2.25576844e-02]
#  [ 1.92202381e+00]
#  [-1.03748251e+00]
#  [ 2.35011342e-02]
#  [ 3.78563608e-01]
#  [ 1.30364145e+00]
#  [-1.78850750e+00]
#  [ 4.03515902e-01]
#  [ 3.84534394e-01]
#  [-2.03136346e+00]
#  [-1.28469167e+00]
#  [-5.47742442e-01]
#  [-1.00860157e+00]
#  [-9.88311873e-02]
#  [ 2.36801506e+00]
#  [ 5.93506789e-01]
#  [-3.71776351e-01]
#  [-2.99288939e-01]
#  [-8.70920341e-01]
#  [-9.38197115e-01]
#  [ 5.60126080e-01]
#  [ 1.16528783e+00]
#  [-1.95328737e+00]
#  [-1.17380181e+00]
#  [-1.20586513e+00]
#  [-2.84636569e-01]
#  [ 2.79060590e-01]
#  [-8.76162182e-02]
#  [ 1.05868670e+00]
#  [-4.23018343e-01]
#  [ 6.08745357e-01]
#  [-2.02315603e+00]
#  [-1.86691022e+00]
#  [-5.52874607e-01]
#  [-1.25285191e+00]
#  [ 1.04699780e+00]
#  [-6.18627395e-01]
#  [-2.08682238e+00]
#  [-1.41458051e+00]
#  [-1.64947095e+00]
#  [-9.18517463e-01]
#  [-5.88890109e-01]
#  [-1.15331882e+00]
#  [ 9.85932465e-02]
#  [-9.90152078e-02]
#  [-2.71056128e+00]
#  [-4.16139166e-01]
#  [ 7.63452885e-01]
#  [ 2.24423417e-01]
#  [ 4.88562178e-02]
#  [-6.47255270e-01]
#  [-4.30607499e-01]
#  [ 1.10634160e+00]
#  [ 1.19500585e+00]
#  [-5.43342205e-01]
#  [-4.32721400e-01]
#  [ 7.37208058e-02]
#  [-3.01568802e-02]
#  [ 2.22234994e-02]
#  [ 1.66123131e+00]
#  [-7.13373159e-01]
#  [-1.30281986e-01]
#  [ 1.39710388e+00]
#  [ 1.05171909e+00]
#  [ 1.56611423e+00]
#  [-1.02957437e-02]
#  [ 6.08464437e-01]
#  [-1.16292516e+00]
#  [-8.20219875e-01]
#  [-6.82003713e-01]
#  [-1.36960073e+00]
#  [ 1.18542866e+00]
#  [ 5.34838331e-01]
#  [ 1.76052805e+00]
#  [ 3.69125228e-01]
#  [-1.02997919e+00]
#  [-6.99773663e-01]
#  [-4.46506998e-01]
#  [ 2.08973384e-01]
#  [ 8.18915571e-02]
#  [ 3.42628561e-01]
#  [-5.33686211e-01]
#  [-1.48738297e+00]
#  [-6.26325582e-01]
#  [-9.33520979e-02]
#  [-2.58554923e+00]
#  [-1.13630711e+00]
#  [-7.48678801e-01]
#  [-7.87576740e-01]
#  [ 3.46253261e-01]
#  [-1.80828271e+00]
#  [-1.91696243e+00]
#  [-1.25375090e+00]
#  [-8.40734962e-01]
#  [-1.52571021e+00]
#  [ 1.86206220e+00]
#  [ 1.35526655e+00]
#  [-6.99352221e-01]
#  [-1.54102015e+00]
#  [-3.78657150e-01]
#  [-1.68398946e+00]
#  [-7.13835229e-01]
#  [ 1.35132414e+00]
#  [ 8.04740313e-01]
#  [ 1.00452016e+00]
#  [-2.36974563e+00]
#  [-2.62666995e-03]
#  [-2.84589003e-03]
#  [-1.21109649e+00]
#  [-6.65491180e-01]
#  [-8.49692209e-01]
#  [ 1.02988538e+00]
#  [ 1.89392071e-01]
#  [ 1.69520902e+00]
#  [-2.31700223e+00]
#  [-1.00309874e+00]
#  [-1.52819016e-02]
#  [ 3.95075259e-01]
#  [ 7.59471679e-01]
#  [-7.67684567e-01]
#  [ 4.96170446e-01]
#  [ 5.04677411e-01]
#  [-7.37762580e-01]
#  [-9.30331586e-01]
#  [-1.27925006e-01]
#  [-1.84964456e-01]
#  [-1.52402040e-01]
#  [ 8.25719448e-01]
#  [-3.26092434e-01]
#  [ 4.81654556e-01]
#  [-5.01209741e-02]
#  [ 4.55840186e-01]
#  [-6.05063642e-01]
#  [ 1.55130803e+00]
#  [ 3.18599534e-01]
#  [-7.06012954e-01]
#  [-1.38622904e+00]
#  [-1.21636124e+00]
#  [-5.62809983e-01]
#  [ 6.80702383e-01]
#  [-7.09240583e-01]
#  [ 3.48377767e-01]
#  [ 5.44380529e-02]
#  [ 3.58643500e-01]
#  [ 1.71676044e+00]
#  [ 3.06643612e-01]
#  [-1.01396801e+00]
#  [-1.46687116e+00]
#  [ 1.94866591e+00]
#  [ 3.56517768e-02]
#  [ 6.81523699e-01]
#  [ 2.26306004e+00]
#  [-4.00818899e-01]
#  [ 2.66386591e-01]
#  [-1.29514290e+00]
#  [-8.57359480e-01]
#  [ 1.51043715e+00]
#  [ 6.42167487e-01]
#  [ 1.30775691e-01]
#  [-6.87864490e-02]
#  [-1.43630526e+00]
#  [-2.70817909e-02]
#  [ 1.24778191e+00]
#  [ 1.20222331e+00]
#  [ 3.54190666e-01]
#  [-9.88709446e-01]
#  [-6.82599848e-01]
#  [-4.22119348e-01]
#  [-6.78566042e-01]
#  [-8.17852788e-01]
#  [-5.18527025e-01]
#  [ 2.40187685e-01]
#  [ 4.90921373e-01]
#  [ 3.29402592e-01]
#  [ 3.25972377e-01]
#  [ 1.20495218e-01]
#  [ 1.47527989e+00]
#  [ 8.69471479e-01]
#  [ 3.54238312e-01]
#  [ 9.38829496e-01]
#  [ 1.79075466e+00]
#  [-1.07625491e+00]
#  [-2.31275937e-01]
#  [-1.18871680e+00]
#  [-7.24462311e-01]
#  [-5.95627248e-01]
#  [ 3.14538456e-01]
#  [-1.51280531e+00]
#  [-5.75383223e-01]
#  [ 1.03201456e+00]
#  [-9.43446009e-02]]
# (1000, 1)

# %% [markdown]
# ### Now, the data generating process is described by the following equation
#
# $
# \begin{equation}
#     Y = \exp{(4W)} + \varepsilon, \quad \varepsilon \sim N(0,1)
# \end{equation}
# $
# #### So, we are sampling $N=1000$ pairs $(W_i,Y_i)_{i=1}^{N}$ from it.

# %%
y = np.exp(4 * W) + e

# %% [markdown]
# #### To perform OLS estimation using sklearn library, we must first initialize a LinearRegression type object. Then, we can call the method .fit("features","data") to calculate parameter estimates and .predict("features") to calculate the fitted equation

# %% [markdown]
# #### First, we are going to fit a first order polynomial to the data. Mathematically
#
# $ \begin{equation}
# m_1(W) = \beta_0 + \beta_1 W
# \end{equation}
# $

# %%
model = LinearRegression()
model.fit(W, y)
y_hat = model.predict(W)

# %% [markdown]
# #### The graph below shows how the predictor fits the data

# %%
fig, ax = plt.subplots(figsize = (6, 6))
ax.scatter(W, y, s = 2)
ax.plot(W, y_hat, color = 'r', linestyle = "-")
ax.set_xlabel("$W_i$")
ax.set_ylabel("$Y_i$")
ax.set_title("$p=2$")
plt.show()

# %% [markdown]
# #### From mere visual inspection, it seems like a bad fit.

# %% [markdown]
# #### Now, What will happen if we add another degree to the polynomial:
#
# $
# \begin{equation}
# m_2(W) = \beta_0+\beta_1W+\beta_2 W^2
# \end{equation}
# $

# %%
W_2 = np.hstack((W, W ** 2))
print(W_2)
W_2.shape
# Out:
# [[1.53723764e-03 2.36309955e-06]
#  [1.63376852e-03 2.66919958e-06]
#  [2.22891189e-03 4.96804821e-06]
#  ...
#  [9.97914049e-01 9.95832449e-01]
#  [9.98240971e-01 9.96485035e-01]
#  [9.99817833e-01 9.99635698e-01]]
# (1000, 2)

# %% [markdown]
# ### We fit and predict the model

# %%
model = LinearRegression()
model.fit(W_2, y)
y_hat = model.predict(W_2)

# %% [markdown]
# #### And generate a graph to see how good it performs

# %%
fig, ax = plt.subplots(figsize = (6, 6))
ax.scatter(W, y, s = 2)
ax.plot(W, y_hat, color = 'r', linestyle = "-")
ax.set_xlabel("$W_i$")
ax.set_ylabel("$Y_i$")
ax.set_title("$p=3$")
plt.show()

# %% [markdown]
# ### And if we add a third degree? Let's see...

# %%
W_3 = np.hstack((W, W ** 2, W ** 3))

# %% [markdown]
# ### Fitting the model

# %%
model = LinearRegression()
model.fit(W_3, y)
y_hat = model.predict(W_3)

# %% [markdown]
# ### And graphing

# %%
fig, ax = plt.subplots(figsize = (6, 6))
ax.scatter(W, y, s =2 )
ax.plot(W, y_hat, color = 'r', linestyle = "-")
ax.set_xlabel("$W_i$")
ax.set_ylabel("$Y_i$")
ax.set_title("$p=4$")
plt.show()

# %% [markdown]
# ### If we kept adding degrees (features) to the predictor function, we will end up fitting the data almost perfectly. However, that is not as good as it sounds: we are actually overfitting. That is something we do not want to do when trying to predict data out of the sample. In the next

# %% [markdown]
# ## 2. Overfitting

# %% [markdown]
# #### In the previous section, we concluded that adding features caused overfitting. Now, we are going to simulate another data generating process so we can assess certain goodnes of fit measures to undestand this phenomena

# %% [markdown]
# #### Let's generate a matrix of 999 features for a sample of 1000 observartions and a vector of 1000 dependent variables.

# %%
X = np.random.normal(0, 1, (1000, 1000 - 1))
y = np.random.normal(0, 1, (1000, 1))
print(X.shape)
print(y.shape)
# Out:
# (1000, 999)
# (1000, 1)

# %% [markdown]
# ### And we fit the data

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# ### There are two important goodness of fit measures: the mean squared error "$MSE$" and the R-squared "$R^2$". They are defined as
#
# $
# \begin{equation}
# MSE = \frac{1}{T}\sum_{i=1}^{N} (Y_i-\hat{Y}_i)^2
# \end{equation}
# $
# $
# \begin{equation}
# R^2 = 1-\frac{\sum_{i=1}^{N} (Y_i-\hat{Y}_i)^2}{\sum_{i=1}^{N} (Y_i-\bar{Y})^2} = 1-\frac{MSE}{TSS}
# \end{equation}
# $

# %% [markdown]
# ### The MSE of the fitted model with 999 features is

# %%
mse = np.mean((y - model.predict(X)) ** 2)
print(mse)
# Out:
# 1.1782976683357926e-26

# %% [markdown]
# ### The MSE is virtually zero. That means that the predictor equals the actual data, so the goodness of fit of the model to the sample is perfect.

# %% [markdown]
# ### Now, we calculate the R-squared

# %%
R_sq = 1 - mse / np.mean((y-np.mean(y)) ** 2)
print(R_sq)
# Out:
# 1.0

# %% [markdown]
# ### The R-squared is a goodnes of fit bounded between 0 and 1. The colser to 1 it is, the better the fit of the model to the sample. In this case, again, we are fitting perfectly the model to the data.

# %% [markdown]
# ### Let's fit the model again, but this time reducing the number of features by 500

# %%
X = np.random.normal(0, 1, (1000, 500 - 1))
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# ### Now we calculate the MSE

# %%
mse = np.mean((y - model.predict(X)) ** 2)
print(mse)
# Out:
# 0.46765641847300876

# %% [markdown]
# ### And the R-squared

# %%
R_sq = 1 - mse / np.mean(y ** 2)
print(R_sq)
# Out:
# 0.5133440903512121

# %% [markdown]
# ### Now, the R-squared has reduced to nearly 0.5. In fact, the R-squared performance is almost equal to the ratio $\frac{p}{n}$, where $p$ is the number of features and $n$ the number of observations. This means that the investigator has a way to manipulate the value of this measure by adding  features at convenience.

# %% [markdown]
# ### To sort this problem out, there exist an R-squared that penalizes the inclusion of irrelevant features. This is called the adjusted R-squared and is defined as
#
# $
# \begin{equation}
# R_{adj}^{2} = 1-\frac{n}{n-p} \frac{MSE}{TSS}
# \end{equation}
# $

# %%
adj_mse = 1000/500*mse
adjR_sq = 1 - adj_mse / np.mean((y-np.mean(y))** 2)
print(adjR_sq)
# Out:
# 0.026143851376528304

# %% [markdown]
# ### Unlike the normal R-square, the adjusted version can be negative, which means really poor performance of the model.

# %% [markdown]
# ### Finally, lets try to reduce the features by 950

# %%
X = np.random.normal(0, 1, (1000, 50 - 1))
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# ### Calculate the MSE

# %%
mse = np.mean((y - model.predict(X)) ** 2)
print(mse)
# Out:
# 0.9037656114295263

# %% [markdown]
# ### The R-squared

# %%
R_sq = 1 - mse / np.mean((y-np.mean(y))** 2)
print(R_sq)
# Out:
# 0.058991106677290794

# %% [markdown]
# ### And the adjusted R-squared

# %%
adj_mse = 1000 / 950 * mse
adjR_sq = 1 - adj_mse / np.mean((y) ** 2)
print(adjR_sq)
# Out:
# 0.01001797503695867

# %% [markdown]
# ## 3. Data splitting

# %% [markdown]
# ### As we have seen so far, overfitting is an issue because we lose predictive accuracy. This is going to be evident in this section by using a technique to measure predictive ability of a model: data splitting. Data splitting consists in dividing the overall sample in two sets: a training sample set and a test sample set. The training sample set is used to "teach" the model about the features (a.k.a estimate the parameters), and the test sample set is used to measure the predictive ability of the model (out of sample performance)

# %% [markdown]
# ### We will use de data generated in the first exercise

# %%
# Features

W = np.random.uniform(0, 1, 1000)
W.sort()
W = W.reshape(-1, 1)

# Noise

e = np.random.normal(0,1,1000)
e = e.reshape(-1,1)

# Dependent variable

y = np.exp(4*W)+e

# %% [markdown]
# ### Now, we are going to use three different predictors to assess out of sample predictive ability: linear, polynomial and sinusoidal
#
# $
# \begin{equation}
# m_1(W) = \beta_0 + \beta_1 W
# \end{equation}
# $
# $
# \begin{equation}
# m_2(W) = \beta_0 + \beta_1 W + \beta_2 W^2 + \beta_3 W^3
# \end{equation}
# $
# $
# \begin{equation}
# m_3(W) = \beta_0 + \beta_1 \sin(W)
# \end{equation}
# $

# %% [markdown]
# ### For each model, we create a matrix of regressors

# %%
W_1 = W
W_2 = np.hstack((W,W**2,W**3))
W_3 = np.sin(W)

# %% [markdown]
# ### And now we construct the sets of test and trainig using sklearn library. To do that we need to import a module called "model_selection"

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Now we can do the splitting. By default, the function train_test_split() splits the sample into 75% for training and 25% for testing, although it can be modified.

# %%
W_1_train,W_1_test,y_1_train,y_1_test = train_test_split(W_1,y)
W_2_train,W_2_test,y_2_train,y_2_test = train_test_split(W_2,y)
W_3_train,W_3_test,y_3_train,y_3_test = train_test_split(W_3,y)

# %% [markdown]
# ### Now, we train the models by fitting them to the data

# %%
model_1 = LinearRegression()
model_1.fit(W_1_train,y_1_train)
# Out:
# LinearRegression()

# %%
model_2 = LinearRegression()
model_2.fit(W_2_train,y_2_train)
# Out:
# LinearRegression()

# %%
model_3 = LinearRegression()
model_3.fit(W_3_train,y_3_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### How do we use the test sample? First, predict the model fitted to the training sample using the test sample

# %%
y_1_hat_test = model_1.predict(W_1_test)
y_2_hat_test = model_2.predict(W_2_test)
y_3_hat_test = model_3.predict(W_3_test)

# %% [markdown]
# ### Now, we can calculate our goodness of fit measures using all the test sample information

# %%
# MSE

mse_1_test = np.mean((y_1_test - y_1_hat_test) ** 2)
mse_2_test = np.mean((y_2_test - y_2_hat_test) ** 2)
mse_3_test = np.mean((y_3_test - y_3_hat_test) ** 2)

print(f'MSE out of sample of predictor 1 is {mse_1_test}')
print(f'MSE out of sample of predictor 2 is {mse_2_test}')
print(f'MSE out of sample of predictor 3 is {mse_3_test}')

# R-squared

R_sq_1_test = 1 - mse_1_test / np.mean((y_1_test-np.mean(y_1_test))** 2)
R_sq_2_test = 1 - mse_2_test / np.mean((y_2_test-np.mean(y_2_test))** 2)
R_sq_3_test = 1 - mse_3_test / np.mean((y_3_test-np.mean(y_3_test))** 2)

print(f'R-squared out of sample of predictor 1 is {R_sq_1_test}')
print(f'R-squared out of sample of predictor 2 is {R_sq_2_test}')
print(f'R-squared out of sample of predictor 3 is {R_sq_3_test}')

# Adjusted R-squared
adj_mse_1_test = 250 / (250-2) * mse_1_test
adjR_sq_1_test = 1 - adj_mse_1_test / np.mean((y_1_test-np.mean(y_1_test))** 2)

adj_mse_2_test = 250 / (250-3) * mse_2_test
adjR_sq_2_test = 1 - adj_mse_2_test / np.mean((y_2_test-np.mean(y_2_test))** 2)

adj_mse_3_test = 250 / (250-2) * mse_3_test
adjR_sq_3_test = 1 - adj_mse_3_test / np.mean((y_3_test-np.mean(y_3_test))** 2)

print(f'Adjusted R-squared out of sample of predictor 1 is {adjR_sq_1_test}')
print(f'Adjusted R-squared out of sample of predictor 2 is {adjR_sq_2_test}')
print(f'Adjusted R-squared out of sample of predictor 3 is {adjR_sq_3_test}')
# Out:
# MSE out of sample of predictor 1 is 41.39320216776995
# MSE out of sample of predictor 2 is 1.244915029207295
# MSE out of sample of predictor 3 is 53.918822412325525
# R-squared out of sample of predictor 1 is 0.8102223990639097
# R-squared out of sample of predictor 2 is 0.9944421496028512
# R-squared out of sample of predictor 3 is 0.7547034325004918
# Adjusted R-squared out of sample of predictor 1 is 0.8086919345402315
# Adjusted R-squared out of sample of predictor 2 is 0.9943746453470154
# Adjusted R-squared out of sample of predictor 3 is 0.7527252343754958
