# %%
# !pip install numpy scikit-learn seaborn matplotlib

# %% [markdown]
# ## 1. Fitting polinomial predictors to data

# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### First, generate the features from $U~(0,1)$

# %%
W = np.random.uniform(0, 1, 1000)
W.sort()
W = W.reshape(-1, 1)
print(W)
# Out:
# [[8.16114893e-04]
#  [1.30771290e-03]
#  [1.79078986e-03]
#  [1.79393003e-03]
#  [3.07303310e-03]
#  [4.50923492e-03]
#  [4.57742722e-03]
#  [5.06142234e-03]
#  [5.63553577e-03]
#  [6.15498403e-03]
#  [6.60034702e-03]
#  [8.85486535e-03]
#  [9.06674935e-03]
#  [1.12450466e-02]
#  [1.27974885e-02]
#  [1.36624329e-02]
#  [1.44989280e-02]
#  [1.45061359e-02]
#  [1.55156743e-02]
#  [1.64381816e-02]
#  [1.76688759e-02]
#  [1.88615941e-02]
#  [1.89110202e-02]
#  [1.94026151e-02]
#  [1.94978472e-02]
#  [2.05362030e-02]
#  [2.50462500e-02]
#  [2.58308486e-02]
#  [2.60358759e-02]
#  [2.89044092e-02]
#  [2.90507422e-02]
#  [3.01429918e-02]
#  [3.08477598e-02]
#  [3.11024212e-02]
#  [3.17098230e-02]
#  [3.17227841e-02]
#  [3.30662381e-02]
#  [3.35253371e-02]
#  [3.47964374e-02]
#  [3.83621544e-02]
#  [3.87572621e-02]
#  [3.91493202e-02]
#  [3.96088600e-02]
#  [3.97952997e-02]
#  [4.16219332e-02]
#  [4.28518422e-02]
#  [4.29138061e-02]
#  [4.39610300e-02]
#  [4.40241590e-02]
#  [4.60234747e-02]
#  [4.85651902e-02]
#  [4.85853943e-02]
#  [4.89678277e-02]
#  [4.97170383e-02]
#  [5.08290084e-02]
#  [5.11082307e-02]
#  [5.23223163e-02]
#  [5.34578379e-02]
#  [5.37346412e-02]
#  [5.42930611e-02]
#  [5.50264005e-02]
#  [5.58806222e-02]
#  [5.68299280e-02]
#  [5.72299893e-02]
#  [5.82513618e-02]
#  [5.84554903e-02]
#  [5.90339917e-02]
#  [6.07780287e-02]
#  [6.16175373e-02]
#  [6.40125981e-02]
#  [6.41819097e-02]
#  [6.48988018e-02]
#  [6.51873386e-02]
#  [6.53049598e-02]
#  [6.55984730e-02]
#  [6.71035695e-02]
#  [6.95057708e-02]
#  [6.95123627e-02]
#  [6.99319563e-02]
#  [7.09032010e-02]
#  [7.14553148e-02]
#  [7.16448924e-02]
#  [7.17911285e-02]
#  [7.28428864e-02]
#  [7.46095273e-02]
#  [7.47246713e-02]
#  [7.50958975e-02]
#  [7.60503954e-02]
#  [7.63384566e-02]
#  [7.69190621e-02]
#  [7.72839282e-02]
#  [7.80300190e-02]
#  [7.92369658e-02]
#  [8.18089271e-02]
#  [8.24087598e-02]
#  [8.28334173e-02]
#  [8.37041844e-02]
#  [8.60844343e-02]
#  [8.71300718e-02]
#  [8.79067048e-02]
#  [8.86364716e-02]
#  [8.88649645e-02]
#  [9.09020609e-02]
#  [9.12056955e-02]
#  [9.14797299e-02]
#  [9.21044105e-02]
#  [9.29611508e-02]
#  [9.40822444e-02]
#  [9.55537465e-02]
#  [9.78638735e-02]
#  [9.79964490e-02]
#  [9.86685149e-02]
#  [9.92760871e-02]
#  [1.01816104e-01]
#  [1.08321709e-01]
#  [1.09255882e-01]
#  [1.11672587e-01]
#  [1.11764680e-01]
#  [1.11917232e-01]
#  [1.12666534e-01]
#  [1.12914488e-01]
#  [1.13125048e-01]
#  [1.14635629e-01]
#  [1.15464901e-01]
#  [1.16272100e-01]
#  [1.16350750e-01]
#  [1.18243650e-01]
#  [1.18574951e-01]
#  [1.18600515e-01]
#  [1.19355915e-01]
#  [1.20284363e-01]
#  [1.20340133e-01]
#  [1.21424958e-01]
#  [1.23903895e-01]
#  [1.24028258e-01]
#  [1.26528558e-01]
#  [1.26902609e-01]
#  [1.27603292e-01]
#  [1.30495395e-01]
#  [1.32125753e-01]
#  [1.32317990e-01]
#  [1.32954666e-01]
#  [1.36625603e-01]
#  [1.38644050e-01]
#  [1.38905119e-01]
#  [1.38998692e-01]
#  [1.40346582e-01]
#  [1.42257473e-01]
#  [1.42811133e-01]
#  [1.43554824e-01]
#  [1.44427034e-01]
#  [1.45873522e-01]
#  [1.46047811e-01]
#  [1.48506622e-01]
#  [1.49686632e-01]
#  [1.52677044e-01]
#  [1.54138037e-01]
#  [1.54612328e-01]
#  [1.55717921e-01]
#  [1.56485332e-01]
#  [1.59539786e-01]
#  [1.60927284e-01]
#  [1.61747773e-01]
#  [1.62345804e-01]
#  [1.64240521e-01]
#  [1.65256073e-01]
#  [1.65897251e-01]
#  [1.68475276e-01]
#  [1.69020556e-01]
#  [1.70122910e-01]
#  [1.71407047e-01]
#  [1.73390403e-01]
#  [1.75689772e-01]
#  [1.75851046e-01]
#  [1.76561457e-01]
#  [1.77416692e-01]
#  [1.77965091e-01]
#  [1.78570177e-01]
#  [1.79039274e-01]
#  [1.81849427e-01]
#  [1.83846077e-01]
#  [1.84166979e-01]
#  [1.84186910e-01]
#  [1.86747824e-01]
#  [1.88835967e-01]
#  [1.89078275e-01]
#  [1.89392164e-01]
#  [1.90192780e-01]
#  [1.91810690e-01]
#  [1.92022369e-01]
#  [1.92739588e-01]
#  [1.94044819e-01]
#  [1.94277826e-01]
#  [1.95476483e-01]
#  [1.95940617e-01]
#  [1.96618797e-01]
#  [1.97463680e-01]
#  [2.00241512e-01]
#  [2.00990680e-01]
#  [2.02097472e-01]
#  [2.03062444e-01]
#  [2.03765780e-01]
#  [2.04488320e-01]
#  [2.04702536e-01]
#  [2.05894578e-01]
#  [2.06582522e-01]
#  [2.07944916e-01]
#  [2.08389372e-01]
#  [2.08446750e-01]
#  [2.08886666e-01]
#  [2.08960072e-01]
#  [2.09453179e-01]
#  [2.15076864e-01]
#  [2.19223910e-01]
#  [2.21034378e-01]
#  [2.23206098e-01]
#  [2.24355266e-01]
#  [2.24740008e-01]
#  [2.25179631e-01]
#  [2.25838678e-01]
#  [2.26339096e-01]
#  [2.27404926e-01]
#  [2.28089926e-01]
#  [2.29194025e-01]
#  [2.30432484e-01]
#  [2.31335224e-01]
#  [2.32328521e-01]
#  [2.32917282e-01]
#  [2.34668104e-01]
#  [2.35827190e-01]
#  [2.36112204e-01]
#  [2.37796388e-01]
#  [2.37893485e-01]
#  [2.38816163e-01]
#  [2.40594527e-01]
#  [2.43967633e-01]
#  [2.45141548e-01]
#  [2.45634304e-01]
#  [2.47163902e-01]
#  [2.48325520e-01]
#  [2.49559472e-01]
#  [2.49594318e-01]
#  [2.50697391e-01]
#  [2.51968817e-01]
#  [2.53952773e-01]
#  [2.54607679e-01]
#  [2.54931620e-01]
#  [2.58493023e-01]
#  [2.58838681e-01]
#  [2.58898266e-01]
#  [2.59490332e-01]
#  [2.60450550e-01]
#  [2.60988048e-01]
#  [2.62169267e-01]
#  [2.63148495e-01]
#  [2.63213266e-01]
#  [2.67075329e-01]
#  [2.67480705e-01]
#  [2.67836034e-01]
#  [2.68331735e-01]
#  [2.69863336e-01]
#  [2.70687601e-01]
#  [2.72897343e-01]
#  [2.75123569e-01]
#  [2.75326884e-01]
#  [2.76516736e-01]
#  [2.77117759e-01]
#  [2.81410114e-01]
#  [2.81641048e-01]
#  [2.84761354e-01]
#  [2.85806719e-01]
#  [2.85832606e-01]
#  [2.86424732e-01]
#  [2.86572268e-01]
#  [2.88836638e-01]
#  [2.89430437e-01]
#  [2.89733243e-01]
#  [2.90232874e-01]
#  [2.91277660e-01]
#  [2.91355219e-01]
#  [2.92634232e-01]
#  [2.93092703e-01]
#  [2.95774527e-01]
#  [2.96349647e-01]
#  [2.96422705e-01]
#  [2.97305969e-01]
#  [2.98307865e-01]
#  [2.98819345e-01]
#  [2.99368975e-01]
#  [2.99972221e-01]
#  [3.00169565e-01]
#  [3.00950123e-01]
#  [3.02700861e-01]
#  [3.02969382e-01]
#  [3.04347541e-01]
#  [3.06907948e-01]
#  [3.07480581e-01]
#  [3.07565292e-01]
#  [3.09327699e-01]
#  [3.11535758e-01]
#  [3.12270786e-01]
#  [3.13837344e-01]
#  [3.14694886e-01]
#  [3.14911691e-01]
#  [3.15712727e-01]
#  [3.16632633e-01]
#  [3.16914121e-01]
#  [3.17063108e-01]
#  [3.18503798e-01]
#  [3.19019906e-01]
#  [3.19601981e-01]
#  [3.21404293e-01]
#  [3.22793893e-01]
#  [3.23126402e-01]
#  [3.24713957e-01]
#  [3.26027168e-01]
#  [3.27626664e-01]
#  [3.28562187e-01]
#  [3.29460569e-01]
#  [3.29978833e-01]
#  [3.30155903e-01]
#  [3.30657615e-01]
#  [3.31928118e-01]
#  [3.32147902e-01]
#  [3.32340784e-01]
#  [3.33339132e-01]
#  [3.33527221e-01]
#  [3.33712026e-01]
#  [3.35326292e-01]
#  [3.36320929e-01]
#  [3.37072224e-01]
#  [3.37493438e-01]
#  [3.41304949e-01]
#  [3.41388922e-01]
#  [3.42287875e-01]
#  [5.77813106e-01]
#  [5.78690186e-01]
#  [5.78848640e-01]
#  [5.79220571e-01]
#  [5.79810764e-01]
#  [5.80123981e-01]
#  [5.80393506e-01]
#  [5.80498595e-01]
#  [5.83634222e-01]
#  [5.84346779e-01]
#  [5.84352563e-01]
#  [5.87153913e-01]
#  [5.89812245e-01]
#  [5.93350620e-01]
#  [5.94238322e-01]
#  [5.96794198e-01]
#  [5.98506164e-01]
#  [5.99763976e-01]
#  [5.99823540e-01]
#  [6.01054259e-01]
#  [6.03293551e-01]
#  [6.05553995e-01]
#  [6.06772021e-01]
#  [6.06822028e-01]
#  [6.08939000e-01]
#  [6.09328603e-01]
#  [6.10287644e-01]
#  [6.10774480e-01]
#  [6.10868140e-01]
#  [6.12971151e-01]
#  [6.14784748e-01]
#  [6.16675793e-01]
#  [6.16992664e-01]
#  [6.18664276e-01]
#  [6.19536148e-01]
#  [6.19991226e-01]
#  [6.21704628e-01]
#  [6.23757093e-01]
#  [6.24000284e-01]
#  [6.24020920e-01]
#  [6.24346961e-01]
#  [6.24801142e-01]
#  [6.24961815e-01]
#  [6.25451911e-01]
#  [6.26240063e-01]
#  [6.27990382e-01]
#  [6.28197854e-01]
#  [6.28749969e-01]
#  [6.31724169e-01]
#  [6.32018222e-01]
#  [6.33335522e-01]
#  [6.33996534e-01]
#  [6.35333866e-01]
#  [6.35799597e-01]
#  [6.38784510e-01]
#  [6.39226617e-01]
#  [6.39591729e-01]
#  [6.40340944e-01]
#  [6.40359616e-01]
#  [6.43157740e-01]
#  [6.43937618e-01]
#  [6.45008267e-01]
#  [6.47688573e-01]
#  [6.47737161e-01]
#  [6.48023801e-01]
#  [6.48122823e-01]
#  [6.50547958e-01]
#  [6.52452427e-01]
#  [6.53058164e-01]
#  [6.53258704e-01]
#  [6.54741669e-01]
#  [6.55039925e-01]
#  [6.55138409e-01]
#  [6.55418702e-01]
#  [6.58979601e-01]
#  [6.60005184e-01]
#  [6.61507565e-01]
#  [6.61973035e-01]
#  [6.63061978e-01]
#  [6.64516597e-01]
#  [6.65632828e-01]
#  [6.66301389e-01]
#  [6.67447577e-01]
#  [6.70301916e-01]
#  [6.70421806e-01]
#  [6.71021409e-01]
#  [6.73941508e-01]
#  [6.75210395e-01]
#  [6.76972654e-01]
#  [6.78626855e-01]
#  [6.78940881e-01]
#  [6.79090618e-01]
#  [6.80308144e-01]
#  [6.81107560e-01]
#  [6.83431746e-01]
#  [6.84823898e-01]
#  [6.85114335e-01]
#  [6.86231523e-01]
#  [6.86976222e-01]
#  [6.90055729e-01]
#  [6.92587841e-01]
#  [6.93052404e-01]
#  [6.93312166e-01]
#  [6.93797948e-01]
#  [6.94353032e-01]
#  [6.96525156e-01]
#  [6.98448079e-01]
#  [6.99095818e-01]
#  [6.99299797e-01]
#  [6.99318160e-01]
#  [6.99683508e-01]
#  [7.00312171e-01]
#  [7.01286059e-01]
#  [7.01697164e-01]
#  [7.02017269e-01]
#  [7.02480887e-01]
#  [8.10379105e-01]
#  [8.10676926e-01]
#  [8.13634589e-01]
#  [8.14531132e-01]
#  [8.16400056e-01]
#  [8.18476320e-01]
#  [8.18665977e-01]
#  [8.20018149e-01]
#  [8.20586000e-01]
#  [8.20691240e-01]
#  [8.20762635e-01]
#  [8.22211833e-01]
#  [8.22237967e-01]
#  [8.22451497e-01]
#  [8.23914379e-01]
#  [8.24504349e-01]
#  [8.25314250e-01]
#  [8.26600635e-01]
#  [8.27028812e-01]
#  [8.27522680e-01]
#  [8.27942434e-01]
#  [8.29651210e-01]
#  [8.30276127e-01]
#  [8.31264653e-01]
#  [8.32098251e-01]
#  [8.32626407e-01]
#  [8.34345037e-01]
#  [8.35513963e-01]
#  [8.36462582e-01]
#  [8.37380130e-01]
#  [8.37640782e-01]
#  [8.38700962e-01]
#  [8.40002772e-01]
#  [8.41247172e-01]
#  [8.42777594e-01]
#  [8.43479151e-01]
#  [8.45004935e-01]
#  [8.45422625e-01]
#  [8.45908618e-01]
#  [8.45963810e-01]
#  [8.46681575e-01]
#  [8.47109709e-01]
#  [8.47424670e-01]
#  [8.49116014e-01]
#  [8.49982874e-01]
#  [8.52047759e-01]
#  [8.52559495e-01]
#  [8.53148015e-01]
#  [8.53943122e-01]
#  [8.54360818e-01]
#  [8.55390499e-01]
#  [8.56167722e-01]
#  [8.57306034e-01]
#  [8.57445340e-01]
#  [8.57947692e-01]
#  [8.59020566e-01]
#  [8.60012285e-01]
#  [8.60123362e-01]
#  [8.60667554e-01]
#  [8.61059354e-01]
#  [8.61914879e-01]
#  [8.62020070e-01]
#  [8.62766470e-01]
#  [8.64156766e-01]
#  [8.66210414e-01]
#  [8.67556644e-01]
#  [8.68981267e-01]
#  [8.69674634e-01]
#  [8.70943469e-01]
#  [8.71946631e-01]
#  [8.72226272e-01]
#  [8.73782231e-01]
#  [8.74818130e-01]
#  [8.75274065e-01]
#  [8.75584499e-01]
#  [8.76529212e-01]
#  [8.77156335e-01]
#  [8.77216864e-01]
#  [8.77332690e-01]
#  [8.77797547e-01]
#  [8.79121242e-01]
#  [8.80858832e-01]
#  [8.81243966e-01]
#  [8.83443063e-01]
#  [8.84211874e-01]
#  [8.84637355e-01]
#  [8.85251835e-01]
#  [8.86848919e-01]
#  [8.86891959e-01]
#  [8.87021047e-01]
#  [8.87571374e-01]
#  [8.88543180e-01]
#  [8.89966846e-01]
#  [8.90303770e-01]
#  [8.91066288e-01]
#  [8.91181568e-01]
#  [8.91859195e-01]
#  [8.94081067e-01]
#  [8.94345058e-01]
#  [8.94523801e-01]
#  [8.95052101e-01]
#  [8.96008672e-01]
#  [8.96431789e-01]
#  [8.97543475e-01]
#  [8.98816852e-01]
#  [8.98819508e-01]
#  [8.98899098e-01]
#  [9.00104956e-01]
#  [9.00432011e-01]
#  [9.00887913e-01]
#  [9.03017361e-01]
#  [9.03239311e-01]
#  [9.03410859e-01]
#  [9.03582576e-01]
#  [9.03627510e-01]
#  [9.03678843e-01]
#  [9.04219489e-01]
#  [9.05946555e-01]
#  [9.07582818e-01]
#  [9.10644573e-01]
#  [9.11080798e-01]
#  [9.11291763e-01]
#  [9.11465794e-01]
#  [9.12999714e-01]
#  [9.14169069e-01]
#  [9.14763582e-01]
#  [9.14993052e-01]
#  [9.15148871e-01]
#  [9.15512141e-01]
#  [9.18100726e-01]
#  [9.18451842e-01]
#  [9.21397974e-01]
#  [9.22101018e-01]
#  [9.22140253e-01]
#  [9.23275710e-01]
#  [9.23588715e-01]
#  [9.26774185e-01]
#  [9.30342617e-01]
#  [9.30455056e-01]
#  [9.30786974e-01]
#  [9.32510392e-01]
#  [9.32798345e-01]
#  [9.32950410e-01]
#  [9.33912661e-01]
#  [9.36712889e-01]
#  [9.38503951e-01]
#  [9.38794461e-01]
#  [9.38935156e-01]
#  [9.41459877e-01]
#  [9.44774004e-01]
#  [9.46523756e-01]
#  [9.46573726e-01]
#  [9.48825229e-01]
#  [9.49847906e-01]
#  [9.51292169e-01]
#  [9.51347156e-01]
#  [9.52398498e-01]
#  [9.54228185e-01]
#  [9.54362766e-01]
#  [9.56224305e-01]
#  [9.56542579e-01]
#  [9.57147566e-01]
#  [9.57857486e-01]
#  [9.58829345e-01]
#  [9.61575244e-01]
#  [9.62076542e-01]
#  [9.62673422e-01]
#  [9.64096723e-01]
#  [9.64147709e-01]
#  [9.65258574e-01]
#  [9.68550340e-01]
#  [9.70006937e-01]
#  [9.70108023e-01]
#  [9.71438642e-01]
#  [9.71592570e-01]
#  [9.73154639e-01]
#  [9.75644787e-01]
#  [9.77955982e-01]
#  [9.78425109e-01]
#  [9.80236716e-01]
#  [9.82794173e-01]
#  [9.83781742e-01]
#  [9.84357248e-01]
#  [9.86388276e-01]
#  [9.88511029e-01]
#  [9.88697170e-01]
#  [9.89265428e-01]
#  [9.89463126e-01]
#  [9.89669540e-01]
#  [9.89802541e-01]
#  [9.90553020e-01]
#  [9.91188016e-01]
#  [9.92030716e-01]
#  [9.92602341e-01]
#  [9.93785491e-01]
#  [9.94610145e-01]
#  [9.94875804e-01]
#  [9.95157409e-01]
#  [9.96175212e-01]
#  [9.96221769e-01]
#  [9.97066547e-01]
#  [9.97508116e-01]]

# %%
e = np.random.normal(0,1,1000)
e = e.reshape(-1,1)
print(e)
e.shape
# Out:
# [[-8.44296145e-01]
#  [ 2.37546889e-01]
#  [ 1.16506105e+00]
#  [ 4.57394469e-01]
#  [ 8.27759688e-01]
#  [-4.26055384e-01]
#  [-6.40008927e-01]
#  [ 6.66675277e-01]
#  [ 1.26344518e+00]
#  [ 5.90200060e-01]
#  [ 9.63754378e-01]
#  [ 3.04561902e+00]
#  [-8.09157368e-01]
#  [-2.93150412e-01]
#  [-7.97673093e-01]
#  [ 9.38051185e-01]
#  [-1.08319212e+00]
#  [ 4.40135237e-03]
#  [-9.35996998e-01]
#  [-6.57224444e-01]
#  [-1.11391923e+00]
#  [ 1.27452102e+00]
#  [ 9.39587296e-01]
#  [ 1.42518594e-01]
#  [-1.07878163e-01]
#  [ 8.19005828e-02]
#  [-1.59689749e-01]
#  [-1.42120142e-01]
#  [-3.86480045e-01]
#  [-2.31708900e+00]
#  [ 7.35536074e-02]
#  [ 1.50364622e+00]
#  [ 2.86726483e-01]
#  [ 1.98344360e+00]
#  [ 4.72360263e-01]
#  [-4.34975897e-03]
#  [-1.10789117e-02]
#  [-3.42447123e-01]
#  [ 5.26040034e-01]
#  [-2.09628784e-01]
#  [-1.67943345e+00]
#  [-1.04561546e+00]
#  [ 1.48810401e+00]
#  [ 4.48862520e-01]
#  [-1.25583636e+00]
#  [ 1.05337941e-01]
#  [-2.80268774e-01]
#  [ 9.41212803e-01]
#  [-8.57634607e-01]
#  [ 8.68658135e-01]
#  [-7.17459976e-01]
#  [-2.00237554e+00]
#  [-1.37533340e-01]
#  [-7.13670515e-01]
#  [ 1.12953724e+00]
#  [-5.74106828e-01]
#  [ 1.15414302e+00]
#  [ 8.47346522e-01]
#  [ 8.57831900e-01]
#  [-3.16528938e-01]
#  [ 1.43088475e-01]
#  [-1.02243316e+00]
#  [-2.77595244e-01]
#  [ 4.80319034e-01]
#  [ 8.21807260e-01]
#  [-1.28226692e+00]
#  [ 7.34290854e-01]
#  [-4.00580873e-01]
#  [-2.04262078e-01]
#  [-2.50866610e-01]
#  [-2.39504723e-01]
#  [-2.66052746e+00]
#  [ 7.20250210e-01]
#  [-4.85073871e-01]
#  [-6.90753934e-01]
#  [-6.18543576e-01]
#  [ 4.16572134e-01]
#  [ 3.47673132e-01]
#  [ 4.79399791e-01]
#  [-4.12407167e-01]
#  [ 5.17050975e-01]
#  [ 2.25885582e-01]
#  [ 6.85651059e-02]
#  [-1.78230210e-01]
#  [ 5.17764000e-01]
#  [ 4.81343031e-01]
#  [-7.78278056e-01]
#  [ 3.77040684e-02]
#  [ 1.43190910e+00]
#  [-6.80394581e-01]
#  [-3.65939368e-01]
#  [-3.36888190e-01]
#  [ 1.61291636e+00]
#  [-5.76921991e-01]
#  [ 2.73184275e-01]
#  [-1.29631017e+00]
#  [ 1.01490302e+00]
#  [-2.61874676e+00]
#  [-9.90568232e-02]
#  [-1.35329074e-01]
#  [-9.58423777e-01]
#  [ 4.37132858e-01]
#  [-1.52771602e-01]
#  [ 6.71283096e-01]
#  [ 3.91696812e-02]
#  [ 1.62998125e+00]
#  [ 8.31084653e-02]
#  [ 1.54448110e+00]
#  [-1.58420235e-01]
#  [ 5.35967284e-01]
#  [-4.11189079e-01]
#  [-3.66432683e-01]
#  [-3.74638318e-01]
#  [-4.56642630e-01]
#  [-5.66605676e-02]
#  [-7.65892702e-01]
#  [-2.29087491e-01]
#  [-2.27562124e-01]
#  [-2.94023238e-01]
#  [-8.35225344e-01]
#  [-4.63021516e-01]
#  [-8.64131711e-01]
#  [ 1.10340780e+00]
#  [ 1.37234720e+00]
#  [-1.00904797e+00]
#  [ 1.23254906e-01]
#  [ 1.37302775e+00]
#  [ 5.22408754e-01]
#  [-1.29073960e+00]
#  [ 1.93878095e-01]
#  [ 1.34783505e-01]
#  [-8.78832194e-01]
#  [-1.72092677e-01]
#  [-1.17642635e-02]
#  [-4.99844408e-01]
#  [ 9.06456046e-01]
#  [-4.75721245e-01]
#  [ 5.03251327e-01]
#  [ 1.28052287e+00]
#  [ 3.85831290e-01]
#  [-1.16362620e+00]
#  [ 1.56023183e+00]
#  [-9.12687980e-01]
#  [ 7.19553376e-01]
#  [ 2.91105097e-01]
#  [-8.24215022e-01]
#  [ 1.87402157e-01]
#  [-8.12878585e-01]
#  [-1.15593883e+00]
#  [ 1.15048192e+00]
#  [-1.90642567e+00]
#  [-1.80501308e+00]
#  [-1.25586796e+00]
#  [-3.29170677e-01]
#  [-7.92557905e-01]
#  [-6.77959040e-01]
#  [ 9.43402426e-01]
#  [ 5.99053909e-02]
#  [ 1.88827736e-01]
#  [ 4.31848440e-01]
#  [-1.86343703e+00]
#  [ 2.04760226e-01]
#  [-2.89406393e-01]
#  [ 4.44601841e-01]
#  [-2.20159746e-01]
#  [ 2.91978853e-02]
#  [-8.28242118e-01]
#  [ 2.14389546e+00]
#  [-1.13926079e+00]
#  [ 7.18877540e-01]
#  [-4.89282223e-01]
#  [ 4.91686370e-01]
#  [-7.87912373e-01]
#  [ 2.51427311e+00]
#  [ 2.18556317e-01]
#  [ 4.51747815e-01]
#  [ 9.49144415e-01]
#  [-4.77016982e-01]
#  [-1.99970159e+00]
#  [ 5.62508114e-01]
#  [ 1.25244518e+00]
#  [-4.76473906e-01]
#  [ 5.37914579e-01]
#  [-8.68834335e-01]
#  [ 2.32709787e-02]
#  [-1.06155947e-01]
#  [-1.09574019e-02]
#  [ 6.30364708e-01]
#  [ 1.67891726e+00]
#  [ 1.44327837e+00]
#  [-8.87087725e-02]
#  [ 1.35104324e+00]
#  [ 1.81237137e+00]
#  [-5.23789869e-04]
#  [ 1.06019391e+00]
#  [ 4.53778304e-01]
#  [-2.28244992e+00]
#  [-2.05373683e-01]
#  [ 4.84634545e-01]
#  [ 1.32297914e-01]
#  [ 5.22813054e-01]
#  [-6.72925973e-01]
#  [-1.22835912e+00]
#  [ 1.19366013e+00]
#  [-5.77473662e-01]
#  [-2.55907920e+00]
#  [ 7.36475457e-01]
#  [ 2.16272200e-01]
#  [ 1.55505723e-01]
#  [ 1.50756730e+00]
#  [ 1.36660148e+00]
#  [ 4.74493247e-01]
#  [ 1.18172989e-01]
#  [-1.90635553e-01]
#  [ 2.04444098e+00]
#  [ 1.93984694e+00]
#  [ 2.31223932e-01]
#  [-2.88734496e+00]
#  [ 4.31102955e-03]
#  [-1.05851341e+00]
#  [ 7.38493429e-01]
#  [-4.71501822e-01]
#  [-7.02264856e-01]
#  [-1.99176412e-01]
#  [ 1.43321431e+00]
#  [ 6.75793770e-01]
#  [ 2.41702838e+00]
#  [-1.21487903e+00]
#  [-9.18865785e-01]
#  [ 1.07785586e+00]
#  [-9.79132761e-01]
#  [-4.81622558e-02]
#  [-1.19477670e+00]
#  [ 4.27375260e-01]
#  [ 1.14846335e+00]
#  [ 1.26674409e+00]
#  [-9.30011906e-01]
#  [ 6.90444282e-02]
#  [ 8.42648026e-01]
#  [ 6.79518075e-01]
#  [ 1.00102558e+00]
#  [ 5.93551034e-01]
#  [ 1.62890594e-01]
#  [ 8.04308065e-02]
#  [-8.13531805e-01]
#  [-6.09339133e-01]
#  [-1.59570775e-01]
#  [ 5.17932389e-01]
#  [-1.68444332e-01]
#  [ 1.03640974e+00]
#  [-9.35944499e-01]
#  [ 1.03576906e+00]
#  [-1.12914275e+00]
#  [ 1.60250195e+00]
#  [ 2.52660086e-02]
#  [-7.75990693e-02]
#  [-7.00167847e-01]
#  [-6.71926021e-01]
#  [-6.12462684e-01]
#  [-1.48161025e+00]
#  [-7.49708058e-01]
#  [-5.82161981e-01]
#  [ 1.28557984e-01]
#  [-1.25038326e+00]
#  [-6.07587182e-01]
#  [ 3.47718683e-01]
#  [ 4.37492923e-01]
#  [-1.28616493e+00]
#  [-4.57030529e-01]
#  [-8.09298044e-01]
#  [-5.14600506e-01]
#  [ 3.90470082e-01]
#  [-5.75398845e-01]
#  [-1.14479795e+00]
#  [ 5.10783577e-03]
#  [-1.00841146e-02]
#  [ 1.23157756e+00]
#  [ 1.82578720e-01]
#  [-3.90841473e-02]
#  [ 1.15436399e+00]
#  [-1.54229948e+00]
#  [-1.17646373e+00]
#  [-7.30109098e-01]
#  [ 7.85979261e-01]
#  [-7.73481864e-01]
#  [-9.56395118e-01]
#  [-2.56030567e-01]
#  [ 7.19160944e-01]
#  [-7.47595261e-01]
#  [-9.79737979e-01]
#  [-8.33368123e-02]
#  [ 1.07462600e+00]
#  [-6.75690247e-01]
#  [ 1.23131071e+00]
#  [ 1.46018694e+00]
#  [-8.08016207e-01]
#  [ 4.16656048e-01]
#  [-8.39532732e-01]
#  [ 8.15548755e-01]
#  [-2.11147924e+00]
#  [-9.57717385e-01]
#  [ 1.87673507e+00]
#  [ 6.80654144e-01]
#  [ 8.22808938e-01]
#  [-4.81039529e-01]
#  [-1.85910211e+00]
#  [-1.91767350e+00]
#  [-4.60174489e-02]
#  [-9.69459982e-01]
#  [-6.87300357e-02]
#  [ 1.11640694e+00]
#  [-7.99535252e-01]
#  [ 9.91065201e-01]
#  [ 2.46153990e-01]
#  [ 1.91648860e+00]
#  [ 3.17086832e-02]
#  [ 1.56228162e+00]
#  [-6.94259323e-01]
#  [-8.89454029e-01]
#  [ 4.31085497e-01]
#  [-1.05106756e-01]
#  [-1.06659064e+00]
#  [-6.83889820e-01]
#  [-1.11682270e+00]
#  [ 2.43959352e-01]
#  [-9.29809367e-02]
#  [ 1.49331816e+00]
#  [-6.09385954e-01]
#  [ 8.04996991e-01]
#  [-6.96027656e-01]
#  [ 5.26426632e-01]
#  [ 6.28277737e-02]
#  [-3.11466162e-01]
#  [ 5.28480326e-01]
#  [-7.06324420e-01]
#  [ 5.93571790e-01]
#  [ 1.84286569e-01]
#  [ 2.50984769e-01]
#  [ 1.40345588e+00]
#  [-6.85339221e-01]
#  [-1.97060739e-01]
#  [-6.80550292e-01]
#  [ 1.15657766e+00]
#  [-8.47486444e-01]
#  [ 4.44700900e-01]
#  [ 2.35707253e+00]
#  [-2.22716309e+00]
#  [-4.89804022e-01]
#  [ 1.85993624e-01]
#  [ 8.40139221e-01]
#  [ 6.17497132e-01]
#  [ 1.13477343e+00]
#  [-5.37225436e-01]
#  [ 1.53218942e+00]
#  [ 2.70620166e-01]
#  [-1.30725089e+00]
#  [ 1.23797299e-01]
#  [ 2.13800687e-01]
#  [ 3.44681064e-01]
#  [-6.50568063e-01]
#  [-1.83664836e-01]
#  [-3.77202797e-01]
#  [-3.81063380e-01]
#  [-3.05847711e-01]
#  [-9.30957846e-01]
#  [ 2.64028844e-01]
#  [ 1.35405259e+00]
#  [ 1.17156307e+00]
#  [-5.93244340e-01]
#  [-7.52280274e-01]
#  [-2.90001348e-01]
#  [-3.37032547e-01]
#  [-1.00996692e+00]
#  [-1.86971173e+00]
#  [ 1.09890272e+00]
#  [ 5.09703876e-01]
#  [ 9.53258835e-02]
#  [ 5.63166237e-01]
#  [ 2.94589687e+00]
#  [-7.53703060e-01]
#  [ 7.72145155e-01]
#  [-2.17149975e+00]
#  [-1.48226730e+00]
#  [-2.05473607e+00]
#  [ 1.63333893e-01]
#  [ 5.97535466e-01]
#  [ 1.34978968e+00]
#  [-1.11196316e+00]
#  [ 4.62513399e-02]
#  [-3.54229356e-01]
#  [ 7.56457889e-02]
#  [-1.13069941e+00]
#  [-3.62641655e-01]
#  [ 5.31232201e-01]
#  [-4.05284138e-02]
#  [ 6.74710626e-01]
#  [-9.43421093e-01]
#  [ 1.81918962e+00]
#  [-3.00661895e-01]
#  [-5.19078068e-01]
#  [-8.26466834e-01]
#  [ 1.35434921e+00]
#  [ 1.89859199e-01]
#  [-1.20092838e+00]
#  [ 4.49627631e-01]
#  [-1.46256684e-01]
#  [ 1.46467854e-01]
#  [-3.69762126e-01]
#  [-3.59961659e-01]
#  [ 7.16563760e-01]
#  [ 6.03513324e-01]
#  [-7.02767368e-02]
#  [ 2.81538535e-01]
#  [ 5.03434185e-01]
#  [ 5.87769876e-01]
#  [ 7.61141188e-01]
#  [ 3.89453527e-01]
#  [-1.25977205e-01]
#  [ 3.62454030e-01]
#  [-3.02544507e-01]
#  [ 4.66493771e-01]
#  [ 4.74100539e-01]
#  [-1.58312722e+00]
#  [ 1.67287816e+00]
#  [ 1.17917297e+00]
#  [-5.96053426e-01]
#  [ 2.51688451e-01]
#  [ 9.38627941e-01]
#  [-1.41247942e+00]
#  [ 1.20736466e+00]
#  [-7.89112329e-01]
#  [-9.45593581e-02]
#  [-2.80737968e-01]
#  [ 1.03757485e+00]
#  [ 1.19662515e+00]
#  [-9.13252567e-01]
#  [ 3.18921444e-01]
#  [ 1.11400509e+00]
#  [-1.38619232e+00]
#  [ 1.40159295e+00]
#  [ 4.57075641e-01]
#  [ 1.16990812e-01]
#  [-1.03788449e+00]
#  [-3.10130333e-01]
#  [ 1.14681343e+00]
#  [-6.25576995e-01]
#  [-1.61583137e+00]
#  [-5.99247409e-01]
#  [ 1.08797589e+00]
#  [ 1.59141774e+00]
#  [-9.08350458e-01]
#  [ 7.70481715e-01]
#  [ 8.70186348e-01]
#  [-1.42624608e+00]
#  [-5.15169990e-01]
#  [ 6.86865421e-01]
#  [ 5.29183475e-01]
#  [-7.78344984e-01]
#  [ 6.61465415e-01]
#  [ 9.17226338e-02]
#  [-1.26643484e+00]
#  [ 1.20785245e+00]
#  [ 1.26869779e+00]
#  [-7.67925135e-01]
#  [-1.25817526e+00]
#  [ 5.61934829e-01]
#  [ 1.17856418e-01]
#  [-7.71338680e-01]
#  [-2.42038287e+00]
#  [-2.37320168e-01]
#  [ 1.63656619e-01]
#  [ 2.00201184e-01]
#  [ 2.96973119e-01]
#  [ 3.03419769e+00]
#  [-1.28754949e+00]
#  [-6.69892760e-01]
#  [ 8.61202035e-01]
#  [-4.44097305e-01]
#  [ 4.17089689e-01]
#  [ 1.86708868e+00]]
# (1000, 1)

# %% [markdown]
# ### Now, the data generating process is described by the following equation
#
# $
# \begin{equation}
#     Y = \exp{(4W)} + \varepsilon, \quad \varepsilon \sim N(0,1)
# \end{equation}
# $
# #### So, we are sampling $N=1000$ pairs $(W_i,Y_i)_{i=1}^{N}$ from it.

# %%
y = np.exp(4 * W) + e

# %% [markdown]
# #### To perform OLS estimation using sklearn library, we must first initialize a LinearRegression type object. Then, we can call the method .fit("features","data") to calculate parameter estimates and .predict("features") to calculate the fitted equation

# %% [markdown]
# #### First, we are going to fit a first order polynomial to the data. Mathematically
#
# $ \begin{equation}
# m_1(W) = \beta_0 + \beta_1 W
# \end{equation}
# $

# %%
model = LinearRegression()
model.fit(W, y)
y_hat = model.predict(W)

# %% [markdown]
# #### The graph below shows how the predictor fits the data

# %%
fig, ax = plt.subplots(figsize = (6, 6))
ax.scatter(W, y, s = 2)
ax.plot(W, y_hat, color = 'r', linestyle = "-")
ax.set_xlabel("$W_i$")
ax.set_ylabel("$Y_i$")
ax.set_title("$p=2$")
plt.show()

# %% [markdown]
# #### From mere visual inspection, it seems like a bad fit.

# %% [markdown]
# #### Now, What will happen if we add another degree to the polynomial:
#
# $
# \begin{equation}
# m_2(W) = \beta_0+\beta_1W+\beta_2 W^2
# \end{equation}
# $

# %%
W_2 = np.hstack((W, W ** 2))
print(W_2)
W_2.shape
# Out:
# [[8.16114893e-04 6.66043519e-07]
#  [1.30771290e-03 1.71011302e-06]
#  [1.79078986e-03 3.20692833e-06]
#  ...
#  [9.96221769e-01 9.92457813e-01]
#  [9.97066547e-01 9.94141699e-01]
#  [9.97508116e-01 9.95022442e-01]]
# (1000, 2)

# %% [markdown]
# ### We fit and predict the model

# %%
model = LinearRegression()
model.fit(W_2, y)
y_hat = model.predict(W_2)

# %% [markdown]
# #### And generate a graph to see how good it performs

# %%
fig, ax = plt.subplots(figsize = (6, 6))
ax.scatter(W, y, s = 2)
ax.plot(W, y_hat, color = 'r', linestyle = "-")
ax.set_xlabel("$W_i$")
ax.set_ylabel("$Y_i$")
ax.set_title("$p=3$")
plt.show()

# %% [markdown]
# ### And if we add a third degree? Let's see...

# %%
W_3 = np.hstack((W, W ** 2, W ** 3))

# %% [markdown]
# ### Fitting the model

# %%
model = LinearRegression()
model.fit(W_3, y)
y_hat = model.predict(W_3)

# %% [markdown]
# ### And graphing

# %%
fig, ax = plt.subplots(figsize = (6, 6))
ax.scatter(W, y, s =2 )
ax.plot(W, y_hat, color = 'r', linestyle = "-")
ax.set_xlabel("$W_i$")
ax.set_ylabel("$Y_i$")
ax.set_title("$p=4$")
plt.show()

# %% [markdown]
# ### If we kept adding degrees (features) to the predictor function, we will end up fitting the data almost perfectly. However, that is not as good as it sounds: we are actually overfitting. That is something we do not want to do when trying to predict data out of the sample. In the next

# %% [markdown]
# ## 2. Overfitting

# %% [markdown]
# #### In the previous section, we concluded that adding features caused overfitting. Now, we are going to simulate another data generating process so we can assess certain goodnes of fit measures to undestand this phenomena

# %% [markdown]
# #### Let's generate a matrix of 999 features for a sample of 1000 observartions and a vector of 1000 dependent variables.

# %%
X = np.random.normal(0, 1, (1000, 1000 - 1))
y = np.random.normal(0, 1, (1000, 1))
print(X.shape)
print(y.shape)
# Out:
# (1000, 999)
# (1000, 1)

# %% [markdown]
# ### And we fit the data

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# ### There are two important goodness of fit measures: the mean squared error "$MSE$" and the R-squared "$R^2$". They are defined as
#
# $
# \begin{equation}
# MSE = \frac{1}{T}\sum_{i=1}^{N} (Y_i-\hat{Y}_i)^2
# \end{equation}
# $
# $
# \begin{equation}
# R^2 = 1-\frac{\sum_{i=1}^{N} (Y_i-\hat{Y}_i)^2}{\sum_{i=1}^{N} (Y_i-\bar{Y})^2} = 1-\frac{MSE}{TSS}
# \end{equation}
# $

# %% [markdown]
# ### The MSE of the fitted model with 999 features is

# %%
mse = np.mean((y - model.predict(X)) ** 2)
print(mse)
# Out:
# 2.0020061702564436e-25

# %% [markdown]
# ### The MSE is virtually zero. That means that the predictor equals the actual data, so the goodness of fit of the model to the sample is perfect.

# %% [markdown]
# ### Now, we calculate the R-squared

# %%
R_sq = 1 - mse / np.mean((y-np.mean(y)) ** 2)
print(R_sq)
# Out:
# 1.0

# %% [markdown]
# ### The R-squared is a goodnes of fit bounded between 0 and 1. The colser to 1 it is, the better the fit of the model to the sample. In this case, again, we are fitting perfectly the model to the data.

# %% [markdown]
# ### Let's fit the model again, but this time reducing the number of features by 500

# %%
X = np.random.normal(0, 1, (1000, 500 - 1))
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# ### Now we calculate the MSE

# %%
mse = np.mean((y - model.predict(X)) ** 2)
print(mse)
# Out:
# 0.489099410494673

# %% [markdown]
# ### And the R-squared

# %%
R_sq = 1 - mse / np.mean(y ** 2)
print(R_sq)
# Out:
# 0.5401143808642408

# %% [markdown]
# ### Now, the R-squared has reduced to nearly 0.5. In fact, the R-squared performance is almost equal to the ratio $\frac{p}{n}$, where $p$ is the number of features and $n$ the number of observations. This means that the investigator has a way to manipulate the value of this measure by adding  features at convenience.

# %% [markdown]
# ### To sort this problem out, there exist an R-squared that penalizes the inclusion of irrelevant features. This is called the adjusted R-squared and is defined as
#
# $
# \begin{equation}
# R_{adj}^{2} = 1-\frac{n}{n-p} \frac{MSE}{TSS}
# \end{equation}
# $

# %%
adj_mse = 1000/500*mse
adjR_sq = 1 - adj_mse / np.mean((y-np.mean(y))** 2)
print(adjR_sq)
# Out:
# 0.08015164641506434

# %% [markdown]
# ### Unlike the normal R-square, the adjusted version can be negative, which means really poor performance of the model.

# %% [markdown]
# ### Finally, lets try to reduce the features by 950

# %%
X = np.random.normal(0, 1, (1000, 50 - 1))
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# ### Calculate the MSE

# %%
mse = np.mean((y - model.predict(X)) ** 2)
print(mse)
# Out:
# 1.0236011534794291

# %% [markdown]
# ### The R-squared

# %%
R_sq = 1 - mse / np.mean((y-np.mean(y))** 2)
print(R_sq)
# Out:
# 0.0374576051897032

# %% [markdown]
# ### And the adjusted R-squared

# %%
adj_mse = 1000 / 950 * mse
adjR_sq = 1 - adj_mse / np.mean((y) ** 2)
print(adjR_sq)
# Out:
# -0.013117579210502495

# %% [markdown]
# ## 3. Data splitting

# %% [markdown]
# ### As we have seen so far, overfitting is an issue because we lose predictive accuracy. This is going to be evident in this section by using a technique to measure predictive ability of a model: data splitting. Data splitting consists in dividing the overall sample in two sets: a training sample set and a test sample set. The training sample set is used to "teach" the model about the features (a.k.a estimate the parameters), and the test sample set is used to measure the predictive ability of the model (out of sample performance)

# %% [markdown]
# ### We will use de data generated in the first exercise

# %%
# Features

W = np.random.uniform(0, 1, 1000)
W.sort()
W = W.reshape(-1, 1)

# Noise

e = np.random.normal(0,1,1000)
e = e.reshape(-1,1)

# Dependent variable

y = np.exp(4*W)+e

# %% [markdown]
# ### Now, we are going to use three different predictors to assess out of sample predictive ability: linear, polynomial and sinusoidal
#
# $
# \begin{equation}
# m_1(W) = \beta_0 + \beta_1 W
# \end{equation}
# $
# $
# \begin{equation}
# m_2(W) = \beta_0 + \beta_1 W + \beta_2 W^2 + \beta_3 W^3
# \end{equation}
# $
# $
# \begin{equation}
# m_3(W) = \beta_0 + \beta_1 \sin(W)
# \end{equation}
# $

# %% [markdown]
# ### For each model, we create a matrix of regressors

# %%
W_1 = W
W_2 = np.hstack((W,W**2,W**3))
W_3 = np.sin(W)

# %% [markdown]
# ### And now we construct the sets of test and trainig using sklearn library. To do that we need to import a module called "model_selection"

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Now we can do the splitting. By default, the function train_test_split() splits the sample into 75% for training and 25% for testing, although it can be modified.

# %%
W_1_train,W_1_test,y_1_train,y_1_test = train_test_split(W_1,y)
W_2_train,W_2_test,y_2_train,y_2_test = train_test_split(W_2,y)
W_3_train,W_3_test,y_3_train,y_3_test = train_test_split(W_3,y)

# %% [markdown]
# ### Now, we train the models by fitting them to the data

# %%
model_1 = LinearRegression()
model_1.fit(W_1_train,y_1_train)
# Out:
# LinearRegression()

# %%
model_2 = LinearRegression()
model_2.fit(W_2_train,y_2_train)
# Out:
# LinearRegression()

# %%
model_3 = LinearRegression()
model_3.fit(W_3_train,y_3_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### How do we use the test sample? First, predict the model fitted to the training sample using the test sample

# %%
y_1_hat_test = model_1.predict(W_1_test)
y_2_hat_test = model_2.predict(W_2_test)
y_3_hat_test = model_3.predict(W_3_test)

# %% [markdown]
# ### Now, we can calculate our goodness of fit measures using all the test sample information

# %%
# MSE

mse_1_test = np.mean((y_1_test - y_1_hat_test) ** 2)
mse_2_test = np.mean((y_2_test - y_2_hat_test) ** 2)
mse_3_test = np.mean((y_3_test - y_3_hat_test) ** 2)

print(f'MSE out of sample of predictor 1 is {mse_1_test}')
print(f'MSE out of sample of predictor 2 is {mse_2_test}')
print(f'MSE out of sample of predictor 3 is {mse_3_test}')

# R-squared

R_sq_1_test = 1 - mse_1_test / np.mean((y_1_test-np.mean(y_1_test))** 2)
R_sq_2_test = 1 - mse_2_test / np.mean((y_2_test-np.mean(y_2_test))** 2)
R_sq_3_test = 1 - mse_3_test / np.mean((y_3_test-np.mean(y_3_test))** 2)

print(f'R-squared out of sample of predictor 1 is {R_sq_1_test}')
print(f'R-squared out of sample of predictor 2 is {R_sq_2_test}')
print(f'R-squared out of sample of predictor 3 is {R_sq_3_test}')

# Adjusted R-squared
adj_mse_1_test = 1000 / 2 * mse_1_test
adjR_sq_1_test = 1 - adj_mse_1_test / np.mean((y_1_test-np.mean(y_1_test))** 2)

adj_mse_2_test = 1000 / 4 * mse_2_test
adjR_sq_2_test = 1 - adj_mse_2_test / np.mean((y_2_test-np.mean(y_2_test))** 2)

adj_mse_3_test = 1000 / 2 * mse_3_test
adjR_sq_3_test = 1 - adj_mse_3_test / np.mean((y_3_test-np.mean(y_3_test))** 2)

print(f'Adjusted R-squared out of sample of predictor 1 is {adjR_sq_1_test}')
print(f'Adjusted R-squared out of sample of predictor 2 is {adjR_sq_2_test}')
print(f'Adjusted R-squared out of sample of predictor 3 is {adjR_sq_3_test}')
# Out:
# MSE out of sample of predictor 1 is 34.46812545845973
# MSE out of sample of predictor 2 is 0.9729657143867096
# MSE out of sample of predictor 3 is 49.80072427943985
# R-squared out of sample of predictor 1 is 0.8051652657723185
# R-squared out of sample of predictor 2 is 0.9941105272065331
# R-squared out of sample of predictor 3 is 0.726924943048979
# Adjusted R-squared out of sample of predictor 1 is -96.41736711384073
# Adjusted R-squared out of sample of predictor 2 is -0.4723681983667134
# Adjusted R-squared out of sample of predictor 3 is -135.53752847551053
