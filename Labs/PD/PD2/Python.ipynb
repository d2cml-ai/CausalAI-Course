# %%
# !pip install numpy scikit-learn seaborn matplotlib
# Out:
# Requirement already satisfied: numpy in c:\users\work\documents\personal\work\classes\pucp 2024-ii\repo\.venv\lib\site-packages (2.1.0)
# Requirement already satisfied: scikit-learn in c:\users\work\documents\personal\work\classes\pucp 2024-ii\repo\.venv\lib\site-packages (1.5.1)
# Requirement already satisfied: seaborn in c:\users\work\documents\personal\work\classes\pucp 2024-ii\repo\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: matplotlib in c:\users\work\documents\personal\work\classes\pucp 2024-ii\repo\.venv\lib\site-packages (3.9.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\work\documents\personal\work\classes\pucp 2024-ii\repo\.venv\lib\site-packages (from scikit-learn) (1.14.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\work\documents\personal\work\classes\pucp 2024-ii\repo\.venv\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\work\documents\personal\work\classes\pucp 2024-ii\repo\.venv\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\work\documents\personal\work\classes\pucp 2024-ii\repo\.venv\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\work\documents\personal\work\classes\pucp 2024-ii\repo\.venv\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\work\documents\personal\work\classes\pucp 2024-ii\repo\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\work\documents\personal\work\classes\pucp 2024-ii\repo\.venv\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\work\documents\personal\work\classes\pucp 2024-ii\repo\.venv\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\work\documents\personal\work\classes\pucp 2024-ii\repo\.venv\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\work\documents\personal\work\classes\pucp 2024-ii\repo\.venv\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\work\documents\personal\work\classes\pucp 2024-ii\repo\.venv\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\work\documents\personal\work\classes\pucp 2024-ii\repo\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\work\documents\personal\work\classes\pucp 2024-ii\repo\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\work\documents\personal\work\classes\pucp 2024-ii\repo\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\work\documents\personal\work\classes\pucp 2024-ii\repo\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# ## 1. Approximating a Smooth Function with a Polynomial Dictionary

# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
W = np.random.uniform(0, 1, 1000)
W.sort()
W = W.reshape(-1, 1)

# %%
y = np.exp(4 * W)

# %%
model = LinearRegression()

# %%
model.fit(W, y)
# Out:
# LinearRegression()

# %%
y_hat = model.predict(W)

# %%
fig, ax = plt.subplots(figsize = (6, 6))
ax.plot(W, y)
ax.plot(W, y_hat, linestyle = "--")
ax.set_xlabel("W")
ax.set_ylabel("Values")
ax.set_title("$p=2$")
plt.show()

# %%
W_2 = np.hstack((W, W ** 2))

# %%
model = LinearRegression()
model.fit(W_2, y)
# Out:
# LinearRegression()

# %%
y_hat = model.predict(W_2)

# %%
fig, ax = plt.subplots(figsize = (6, 6))
ax.plot(W, y)
ax.plot(W, y_hat, linestyle = "--")
ax.set_xlabel("W")
ax.set_ylabel("Values")
ax.set_title("$p=3$")
plt.show()

# %%
W_3 = np.hstack((W, W ** 2, W ** 3))

# %%
model = LinearRegression()
model.fit(W_3, y)
# Out:
# LinearRegression()

# %%
y_hat = model.predict(W_3)

# %%
fig, ax = plt.subplots(figsize = (6, 6))
ax.plot(W, y)
ax.plot(W, y_hat, linestyle = "--")
ax.set_xlabel("W")
ax.set_ylabel("Values")
ax.set_title("$p=4$")
plt.show()

# %% [markdown]
# ## 2. Overfitting

# %%
X = np.random.normal(0, 1, (1000, 1000 - 1))

# %%
y = np.random.normal(0, 1, (1000, 1))

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
mse = np.mean((y - model.predict(X)) ** 2)
mse
# Out:
# np.float64(2.8697172640756994e-26)

# %%
R_sq = 1 - mse / np.mean(y ** 2)
R_sq
# Out:
# np.float64(1.0)

# %%
X = np.random.normal(0, 1, (1000, 500 - 1))
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
mse = np.mean((y - model.predict(X)) ** 2)
mse
# Out:
# np.float64(0.5015571697950457)

# %%
R_sq = 1 - mse / np.mean(y ** 2)
R_sq
# Out:
# np.float64(0.505894217713458)

# %%
adj_mse = 1000 / 500 * mse
adj_mse
# Out:
# np.float64(1.0031143395900914)

# %%
adjR_sq = 1 - adj_mse / np.mean(y ** 2)
adjR_sq
# Out:
# np.float64(0.011788435426915989)

# %%
X = np.random.normal(0, 1, (1000, 50 - 1))
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
mse = np.mean((y - model.predict(X)) ** 2)
mse
# Out:
# np.float64(0.9608326689146365)

# %%
R_sq = 1 - mse / np.mean(y ** 2)
R_sq
# Out:
# np.float64(0.05344194817405645)

# %%
adj_mse = 1000 / 950 * mse
adj_mse
# Out:
# np.float64(1.0114028093838279)

# %%
adjR_sq = 1 - adj_mse / np.mean(y ** 2)
adjR_sq
# Out:
# np.float64(0.003623103341112044)
