# %%
# !pip install numpy scikit-learn seaborn matplotlib

# %% [markdown]
# ## 1. Fitting polinomial predictors to data

# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
W = np.random.uniform(0, 1, 1000)
W.sort()
W = W.reshape(-1, 1)
print(W)
# Out:
# [[0.00117101]
#  [0.00180494]
#  [0.00295424]
#  [0.00351339]
#  [0.00672881]
#  [0.00764784]
#  [0.0081057 ]
#  [0.00847677]
#  [0.00891124]
#  [0.01078523]
#  [0.01185382]
#  [0.01200358]
#  [0.01263327]
#  [0.01402837]
#  [0.01448939]
#  [0.01465734]
#  [0.0163808 ]
#  [0.01800196]
#  [0.01968955]
#  [0.02077835]
#  [0.02137952]
#  [0.02176823]
#  [0.02437464]
#  [0.02552203]
#  [0.02609203]
#  [0.02633549]
#  [0.02648214]
#  [0.02710748]
#  [0.02991044]
#  [0.03000367]
#  [0.03016162]
#  [0.0341515 ]
#  [0.03420308]
#  [0.03464246]
#  [0.03627562]
#  [0.03691641]
#  [0.0374807 ]
#  [0.0381116 ]
#  [0.0384436 ]
#  [0.03851899]
#  [0.03922125]
#  [0.03944875]
#  [0.03984712]
#  [0.04293705]
#  [0.04318658]
#  [0.04416708]
#  [0.0451737 ]
#  [0.04553296]
#  [0.04563286]
#  [0.04671807]
#  [0.04792019]
#  [0.04796279]
#  [0.04848185]
#  [0.04852339]
#  [0.04884232]
#  [0.04953937]
#  [0.05019039]
#  [0.0512617 ]
#  [0.05132496]
#  [0.05272573]
#  [0.05274959]
#  [0.05381718]
#  [0.05432499]
#  [0.05453807]
#  [0.05506053]
#  [0.05554917]
#  [0.05574509]
#  [0.05757851]
#  [0.05805535]
#  [0.06024221]
#  [0.06079726]
#  [0.06424589]
#  [0.06536391]
#  [0.06795072]
#  [0.06888496]
#  [0.06975522]
#  [0.07014976]
#  [0.07044662]
#  [0.07054695]
#  [0.07055533]
#  [0.07267823]
#  [0.07439114]
#  [0.07516506]
#  [0.07844587]
#  [0.07849927]
#  [0.07885104]
#  [0.07888802]
#  [0.07957083]
#  [0.08299577]
#  [0.08371262]
#  [0.08455089]
#  [0.08655797]
#  [0.08764995]
#  [0.08806526]
#  [0.08865612]
#  [0.08881173]
#  [0.09036113]
#  [0.09450373]
#  [0.09549486]
#  [0.09742676]
#  [0.09846005]
#  [0.10009513]
#  [0.1015996 ]
#  [0.10287993]
#  [0.10536231]
#  [0.1058506 ]
#  [0.10647471]
#  [0.10723377]
#  [0.10966371]
#  [0.11045767]
#  [0.11052156]
#  [0.11142823]
#  [0.1114477 ]
#  [0.11265812]
#  [0.11320923]
#  [0.11339518]
#  [0.11411404]
#  [0.11423617]
#  [0.11603378]
#  [0.11642763]
#  [0.11810662]
#  [0.119852  ]
#  [0.12006342]
#  [0.12301547]
#  [0.1232372 ]
#  [0.12398538]
#  [0.12435556]
#  [0.12529029]
#  [0.12533294]
#  [0.12558352]
#  [0.12615373]
#  [0.12855665]
#  [0.12886418]
#  [0.12983211]
#  [0.13134076]
#  [0.13141432]
#  [0.13576999]
#  [0.13763515]
#  [0.13871297]
#  [0.14065769]
#  [0.14081376]
#  [0.14242528]
#  [0.14247182]
#  [0.14381048]
#  [0.14428178]
#  [0.1453204 ]
#  [0.1456798 ]
#  [0.14857686]
#  [0.15248287]
#  [0.15292264]
#  [0.15315794]
#  [0.153378  ]
#  [0.1535682 ]
#  [0.15412549]
#  [0.15549093]
#  [0.15644102]
#  [0.15645761]
#  [0.15656276]
#  [0.15760748]
#  [0.15804615]
#  [0.15998476]
#  [0.16201378]
#  [0.16218335]
#  [0.16253779]
#  [0.16281756]
#  [0.16374281]
#  [0.16525888]
#  [0.16694293]
#  [0.16710338]
#  [0.16859502]
#  [0.16924009]
#  [0.16956075]
#  [0.1716399 ]
#  [0.17235539]
#  [0.17236871]
#  [0.17246473]
#  [0.18035   ]
#  [0.18039409]
#  [0.18104219]
#  [0.18465272]
#  [0.18584245]
#  [0.18652402]
#  [0.18660962]
#  [0.1867877 ]
#  [0.1870673 ]
#  [0.18863974]
#  [0.19584719]
#  [0.19595604]
#  [0.19602513]
#  [0.19703231]
#  [0.1973094 ]
#  [0.19786303]
#  [0.19829732]
#  [0.19895794]
#  [0.19968862]
#  [0.20072174]
#  [0.20082063]
#  [0.20264433]
#  [0.20271085]
#  [0.2029369 ]
#  [0.20388445]
#  [0.20441491]
#  [0.20773847]
#  [0.20884871]
#  [0.2107267 ]
#  [0.21259071]
#  [0.21259472]
#  [0.21278891]
#  [0.21281357]
#  [0.21410557]
#  [0.21524815]
#  [0.21655377]
#  [0.21677939]
#  [0.2205218 ]
#  [0.22292955]
#  [0.22345455]
#  [0.22607208]
#  [0.22717801]
#  [0.22756488]
#  [0.22781543]
#  [0.2280368 ]
#  [0.2296791 ]
#  [0.23022238]
#  [0.23084075]
#  [0.23106437]
#  [0.23197774]
#  [0.23228645]
#  [0.23538929]
#  [0.23557237]
#  [0.23648378]
#  [0.23802977]
#  [0.23825862]
#  [0.23912937]
#  [0.23986545]
#  [0.24031047]
#  [0.24224394]
#  [0.2437652 ]
#  [0.24425519]
#  [0.24516904]
#  [0.2462454 ]
#  [0.24626642]
#  [0.24657067]
#  [0.24671863]
#  [0.24774328]
#  [0.24826829]
#  [0.24931372]
#  [0.25030994]
#  [0.25036552]
#  [0.25214288]
#  [0.25403691]
#  [0.25445886]
#  [0.25610866]
#  [0.25693585]
#  [0.25864542]
#  [0.25905149]
#  [0.25999494]
#  [0.2626271 ]
#  [0.26382927]
#  [0.26452982]
#  [0.26474113]
#  [0.2653629 ]
#  [0.26545098]
#  [0.26694394]
#  [0.26694908]
#  [0.2682772 ]
#  [0.26851675]
#  [0.26856771]
#  [0.26950937]
#  [0.27004808]
#  [0.27077396]
#  [0.27105495]
#  [0.27110708]
#  [0.27132444]
#  [0.27138332]
#  [0.2725507 ]
#  [0.27307037]
#  [0.27366612]
#  [0.27511596]
#  [0.27526295]
#  [0.27691978]
#  [0.27789042]
#  [0.27886435]
#  [0.27924252]
#  [0.27941626]
#  [0.57754569]
#  [0.58133563]
#  [0.58166761]
#  [0.58587506]
#  [0.58631372]
#  [0.58759707]
#  [0.58774331]
#  [0.5879863 ]
#  [0.58921829]
#  [0.58964887]
#  [0.5902526 ]
#  [0.59030693]
#  [0.59088405]
#  [0.59130402]
#  [0.59140331]
#  [0.59208602]
#  [0.59226351]
#  [0.59305525]
#  [0.59338215]
#  [0.59365537]
#  [0.59396523]
#  [0.59590691]
#  [0.59659015]
#  [0.59663937]
#  [0.59688385]
#  [0.59724722]
#  [0.59835286]
#  [0.59984906]
#  [0.59996642]
#  [0.60286415]
#  [0.60423213]
#  [0.60459954]
#  [0.6057322 ]
#  [0.60685173]
#  [0.60933112]
#  [0.61046352]
#  [0.61110113]
#  [0.6126163 ]
#  [0.61266509]
#  [0.61279926]
#  [0.61290957]
#  [0.6144053 ]
#  [0.61677484]
#  [0.61719268]
#  [0.61757384]
#  [0.61757912]
#  [0.61765817]
#  [0.6185379 ]
#  [0.61855698]
#  [0.61963371]
#  [0.62088308]
#  [0.6212561 ]
#  [0.62397068]
#  [0.62486375]
#  [0.62511711]
#  [0.62810357]
#  [0.63016005]
#  [0.63037715]
#  [0.63132624]
#  [0.6350338 ]
#  [0.63620355]
#  [0.63636984]
#  [0.6364301 ]
#  [0.63733507]
#  [0.63735138]
#  [0.63768618]
#  [0.63963586]
#  [0.64020186]
#  [0.64022505]
#  [0.6422776 ]
#  [0.64258416]
#  [0.64541271]
#  [0.64617003]
#  [0.64800173]
#  [0.64954543]
#  [0.64989193]
#  [0.65038198]
#  [0.65045077]
#  [0.65099274]
#  [0.65267943]
#  [0.6545134 ]
#  [0.65457822]
#  [0.65503596]
#  [0.65636376]
#  [0.6564993 ]
#  [0.65766163]
#  [0.65805588]
#  [0.65810905]
#  [0.65860169]
#  [0.65879548]
#  [0.65898979]
#  [0.66247659]
#  [0.66505186]
#  [0.6661971 ]
#  [0.66625102]
#  [0.66670263]
#  [0.66985698]
#  [0.67287571]
#  [0.67341901]
#  [0.67430068]
#  [0.67548377]
#  [0.67558641]
#  [0.67730473]
#  [0.67811119]
#  [0.67832618]
#  [0.67840575]
#  [0.67885321]
#  [0.6806219 ]
#  [0.68078361]
#  [0.68108522]
#  [0.68255736]
#  [0.68285543]
#  [0.68286375]
#  [0.68327361]
#  [0.68518442]
#  [0.68527046]
#  [0.68590229]
#  [0.68651682]
#  [0.68748317]
#  [0.68762862]
#  [0.68775251]
#  [0.68776398]
#  [0.68821972]
#  [0.68876469]
#  [0.6894476 ]
#  [0.69003453]
#  [0.69128762]
#  [0.69226682]
#  [0.69447743]
#  [0.69584437]
#  [0.69792406]
#  [0.69826784]
#  [0.69964711]
#  [0.70144633]
#  [0.70205886]
#  [0.70321641]
#  [0.70456714]
#  [0.70465797]
#  [0.70536123]
#  [0.71325406]
#  [0.71328296]
#  [0.71567306]
#  [0.71752117]
#  [0.71905269]
#  [0.72057293]
#  [0.72304289]
#  [0.72523027]
#  [0.72796948]
#  [0.73079443]
#  [0.8800181 ]
#  [0.88077819]
#  [0.88415453]
#  [0.8853769 ]
#  [0.88608091]
#  [0.88634998]
#  [0.88831475]
#  [0.88849982]
#  [0.88896909]
#  [0.89091038]
#  [0.89224498]
#  [0.89295871]
#  [0.89434785]
#  [0.89537701]
#  [0.89584988]
#  [0.89621814]
#  [0.89775114]
#  [0.89969717]
#  [0.90045118]
#  [0.90137658]
#  [0.9017795 ]
#  [0.90197884]
#  [0.90274721]
#  [0.90406419]
#  [0.9042698 ]
#  [0.90491704]
#  [0.90537977]
#  [0.90575651]
#  [0.90861227]
#  [0.90902455]
#  [0.91004147]
#  [0.91106084]
#  [0.91121233]
#  [0.91347569]
#  [0.91718476]
#  [0.91771374]
#  [0.9194949 ]
#  [0.91951483]
#  [0.92071946]
#  [0.92128135]
#  [0.92189314]
#  [0.92590908]
#  [0.92785812]
#  [0.92793567]
#  [0.92878968]
#  [0.92901454]
#  [0.92910727]
#  [0.92931256]
#  [0.93143127]
#  [0.93529408]
#  [0.93645629]
#  [0.93671176]
#  [0.93709319]
#  [0.93774242]
#  [0.93876779]
#  [0.94050894]
#  [0.941236  ]
#  [0.94132519]
#  [0.94376615]
#  [0.94394306]
#  [0.94584134]
#  [0.94609757]
#  [0.94740098]
#  [0.9489713 ]
#  [0.94917835]
#  [0.95281425]
#  [0.95464534]
#  [0.95574299]
#  [0.95795292]
#  [0.95809346]
#  [0.95846804]
#  [0.95851193]
#  [0.95902096]
#  [0.96047067]
#  [0.9608054 ]
#  [0.96111451]
#  [0.96114847]
#  [0.96227963]
#  [0.96335539]
#  [0.96451748]
#  [0.96513407]
#  [0.96584325]
#  [0.96890992]
#  [0.96895425]
#  [0.96922799]
#  [0.96960066]
#  [0.96962859]
#  [0.97021114]
#  [0.97023965]
#  [0.97042272]
#  [0.97085103]
#  [0.97149047]
#  [0.97230687]
#  [0.9725201 ]
#  [0.97265478]
#  [0.97321738]
#  [0.97448764]
#  [0.97585576]
#  [0.97638491]
#  [0.97638666]
#  [0.97825055]
#  [0.97994475]
#  [0.9816669 ]
#  [0.98299702]
#  [0.98361865]
#  [0.98379566]
#  [0.98521082]
#  [0.98604434]
#  [0.98786528]
#  [0.98871551]
#  [0.98932056]
#  [0.98993925]
#  [0.99043312]
#  [0.99238492]
#  [0.99517612]
#  [0.99536891]
#  [0.99573413]
#  [0.99619199]
#  [0.99711153]
#  [0.99781441]
#  [0.99796504]
#  [0.99819258]]

# %%
e = np.random.normal(0,1,1000)
e = e.reshape(-1,1)
print(e)
e.shape
# Out:
# [[-9.93136418e-01]
#  [-1.96324441e+00]
#  [ 6.25351396e-02]
#  [-1.97051573e+00]
#  [-1.13547162e+00]
#  [-8.08181271e-01]
#  [-3.90061835e-01]
#  [ 1.17360425e+00]
#  [ 7.84834330e-01]
#  [-8.13655576e-02]
#  [-1.77899885e+00]
#  [ 2.85464081e-01]
#  [ 6.76776177e-02]
#  [ 3.35858109e-01]
#  [-9.48878315e-01]
#  [ 1.51761120e+00]
#  [-9.05599234e-02]
#  [-8.50539035e-01]
#  [ 1.17343475e+00]
#  [ 3.51266059e-01]
#  [ 2.79997771e-02]
#  [-4.85978331e-01]
#  [-1.38160269e-01]
#  [ 8.63696189e-01]
#  [ 1.58216019e+00]
#  [-2.97406666e-01]
#  [ 1.53878281e+00]
#  [-6.47291547e-01]
#  [-6.79435762e-01]
#  [ 1.70132371e+00]
#  [ 7.96083848e-01]
#  [ 3.28627997e-01]
#  [ 6.38741590e-01]
#  [ 5.68729751e-01]
#  [ 5.92330993e-01]
#  [ 1.25843584e+00]
#  [-3.02857977e-01]
#  [-1.55863258e+00]
#  [ 2.89235023e-01]
#  [ 2.86400860e-01]
#  [ 8.43562589e-01]
#  [-9.83472337e-01]
#  [ 1.69989183e+00]
#  [-1.79795552e-01]
#  [-1.37798988e+00]
#  [ 4.85762942e-01]
#  [ 1.68383110e+00]
#  [ 9.28375587e-01]
#  [-1.93558836e+00]
#  [-1.63807050e+00]
#  [-5.31330136e-01]
#  [-4.24706947e-01]
#  [ 2.68063269e-01]
#  [-1.11703824e-02]
#  [ 1.24524922e-01]
#  [-1.58789173e+00]
#  [ 1.15836706e+00]
#  [ 1.79629034e-01]
#  [-1.59974631e-02]
#  [-7.93073436e-01]]
# (1000, 1)

# %% [markdown]
# #### Now, the data generating process is described by the following equation
#
# $
# \begin{equation}
#     Y = \exp{(4W)} + \varepsilon, \quad \varepsilon \sim N(0,1)
# \end{equation}
# $
# #### So, we are sampling $N=1000$ pairs $(W_i,Y_i)_{i=1}^{N}$ from it.

# %%
y = np.exp(4 * W) + e

# %% [markdown]
# #### To perform OLS estimation using sklearn library, we must first initialize a LinearRegression type object. Then, we can call the method .fit("features","data") to calculate parameter estimates and .predict("features") to calculate the fitted equation

# %% [markdown]
# #### First, we are going to fit a first order polynomial to the data. Mathematically
#
# $ \begin{equation}
# m_1(W) = \beta_0 + \beta_1 W
# \end{equation}
# $

# %%
model = LinearRegression()
model.fit(W, y)
y_hat = model.predict(W)

# %% [markdown]
# #### The graph below shows how the predictor fits the data

# %%
fig, ax = plt.subplots(figsize = (6, 6))
ax.scatter(W, y, s = 2)
ax.plot(W, y_hat, color = 'r', linestyle = "-")
ax.set_xlabel("$W_i$")
ax.set_ylabel("$Y_i$")
ax.set_title("$p=2$")
plt.show()

# %% [markdown]
# #### From mere visual inspection, it seems like a bad fit.

# %% [markdown]
# #### Now, What will happen if we add another degree to the polynomial:
#
# $
# \begin{equation}
# m_2(W) = \beta_0+\beta_1W+\beta_2 W^2
# \end{equation}
# $

# %%
W_2 = np.hstack((W, W ** 2))
print(W_2)
W_2.shape
# Out:
# [[1.17101397e-03 1.37127371e-06]
#  [1.80494101e-03 3.25781206e-06]
#  [2.95423798e-03 8.72752202e-06]
#  ...
#  [9.97814414e-01 9.95633604e-01]
#  [9.97965042e-01 9.95934225e-01]
#  [9.98192579e-01 9.96388424e-01]]
# (1000, 2)

# %% [markdown]
# ### We fit and predict the model

# %%
model = LinearRegression()
model.fit(W_2, y)
y_hat = model.predict(W_2)

# %% [markdown]
# #### And generate a graph to see how good it performs

# %%
fig, ax = plt.subplots(figsize = (6, 6))
ax.scatter(W, y, s = 2)
ax.plot(W, y_hat, color = 'r', linestyle = "-")
ax.set_xlabel("$W_i$")
ax.set_ylabel("$Y_i$")
ax.set_title("$p=3$")
plt.show()

# %% [markdown]
# ### And if we add a third degree? Let's see...

# %%
W_3 = np.hstack((W, W ** 2, W ** 3))

# %% [markdown]
# ### Fitting the model

# %%
model = LinearRegression()
model.fit(W_3, y)
y_hat = model.predict(W_3)

# %% [markdown]
# ### And graphing

# %%
fig, ax = plt.subplots(figsize = (6, 6))
ax.scatter(W, y, s =2 )
ax.plot(W, y_hat, color = 'r', linestyle = "-")
ax.set_xlabel("$W_i$")
ax.set_ylabel("$Y_i$")
ax.set_title("$p=4$")
plt.show()

# %% [markdown]
# ### If we kept adding degrees (features) to the predictor function, we will end up fitting the data almost perfectly. However, that is not as good as it sounds: we are actually overfitting. That is something we do not want to do when trying to predict data out of the sample. In the next

# %% [markdown]
# ## 2. Overfitting

# %% [markdown]
# #### In the previous section, we concluded that adding features caused overfitting. Now, we are going to simulate another data generating process so we can assess certain goodnes of fit measures to undestand this phenomena

# %% [markdown]
# #### Let's generate a matrix of 999 features for a sample of 1000 observartions and a vector of 1000 dependent variables.

# %%
X = np.random.normal(0, 1, (1000, 1000 - 1))
y = np.random.normal(0, 1, (1000, 1))
print(X.shape)
print(y.shape)
# Out:
# (1000, 999)
# (1000, 1)

# %% [markdown]
# ### And we fit the data

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# ### There are two important goodness of fit measures: the mean squared error "$MSE$" and the R-squared "$R^2$". They are defined as
#
# $
# \begin{equation}
# MSE = \frac{1}{T}\sum_{i=1}^{N} (Y_i-\hat{Y}_i)^2
# \end{equation}
# $
# $
# \begin{equation}
# R^2 = 1-\frac{\sum_{i=1}^{N} (Y_i-\hat{Y}_i)^2}{\sum_{i=1}^{N} (Y_i-\bar{Y})^2} = 1-\frac{MSE}{TSS}
# \end{equation}
# $

# %% [markdown]
# ### The MSE of the fitted model with 999 features is

# %%
mse = np.mean((y - model.predict(X)) ** 2)
print(mse)
# Out:
# 3.018794894258857e-27

# %% [markdown]
# ### The MSE is virtually zero. That means that the predictor equals the actual data, so the goodness of fit of the model to the sample is perfect.

# %% [markdown]
# ### Now, we calculate the R-squared

# %%
R_sq = 1 - mse / np.mean((y-np.mean(y)) ** 2)
print(R_sq)
# Out:
# 1.0

# %% [markdown]
# ### The R-squared is a goodnes of fit bounded between 0 and 1. The colser to 1 it is, the better the fit of the model to the sample. In this case, again, we are fitting perfectly the model to the data.

# %% [markdown]
# ### Let's fit the model again, but this time reducing the number of features by 500

# %%
X = np.random.normal(0, 1, (1000, 500 - 1))
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# ### Now we calculate the MSE

# %%
mse = np.mean((y - model.predict(X)) ** 2)
print(mse)
# Out:
# 0.5322155469777577

# %% [markdown]
# ### And the R-squared

# %%
R_sq = 1 - mse / np.mean(y ** 2)
print(R_sq)
# Out:
# 0.4888365812082025

# %% [markdown]
# ### Now, the R-squared has reduced to nearly 0.5. In fact, the R-squared performance is almost equal to the ratio $\frac{p}{n}$, where $p$ is the number of features and $n$ the number of observations. This means that the investigator has a way to manipulate the value of this measure by adding  features at convenience.

# %% [markdown]
# ### To sort this problem out, there exist an R-squared that penalizes the inclusion of irrelevant features. This is called the adjusted R-squared and is defined as
#
# $
# \begin{equation}
# R_{adj}^{2} = 1-\frac{n}{n-p} \frac{MSE}{TSS}
# \end{equation}
# $

# %%
adj_mse = 1000/500*mse
adjR_sq = 1 - adj_mse / np.mean((y-np.mean(y))** 2)
print(adjR_sq)
# Out:
# -0.02368111483379942

# %% [markdown]
# ### Unlike the normal R-square, the adjusted version can be negative, which means really poor performance of the model.

# %% [markdown]
# ### Finally, lets try to reduce the features by 950

# %%
X = np.random.normal(0, 1, (1000, 50 - 1))
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# ### Calculate the MSE

# %%
mse = np.mean((y - model.predict(X)) ** 2)
print(mse)
# Out:
# 0.9812200701460906

# %% [markdown]
# ### The R-squared

# %%
R_sq = 1 - mse / np.mean((y-np.mean(y))** 2)
print(R_sq)
# Out:
# 0.05634431293076547

# %% [markdown]
# ### And the adjusted R-squared

# %%
adj_mse = 1000 / 950 * mse
adjR_sq = 1 - adj_mse / np.mean((y) ** 2)
print(adjR_sq)
# Out:
# 0.9974296552837852

# %% [markdown]
# ## 3. Data splitting

# %% [markdown]
# ### As we have seen so far, overfitting is an issue because we lose predictive accuracy. This is going to be evident in this section by using a technique to measure predictive ability of a model: data splitting. Data splitting consists in dividing the overall sample in two sets: a training sample set and a test sample set. The training sample set is used to "teach" the model about the features (a.k.a estimate the parameters), and the test sample set is used to measure the predictive ability of the model (out of sample performance)

# %% [markdown]
# ### We will use de data generated in the first exercise

# %%
# Features

W = np.random.uniform(0, 1, 1000)
W.sort()
W = W.reshape(-1, 1)

# Noise

e = np.random.normal(0,1,1000)
e = e.reshape(-1,1)

# Dependent variable

y = np.exp(4*W)+e

# %% [markdown]
# ### Now, we are going to use three different predictors to assess out of sample predictive ability: linear, polynomial and sinusoidal
#
# $
# \begin{equation}
# m_1(W) = \beta_0 + \beta_1 W
# \end{equation}
# $
# $
# \begin{equation}
# m_2(W) = \beta_0 + \beta_1 W + \beta_2 W^2 + \beta_3 W^3
# \end{equation}
# $
# $
# \begin{equation}
# m_3(W) = \beta_0 + \beta_1 \sin(W)
# \end{equation}
# $

# %% [markdown]
# ### For each model, we create a matrix of regressors

# %%
W_1 = W
W_2 = np.hstack((W,W**2,W**3))
W_3 = np.sin(W)

# %% [markdown]
# ### And now we construct the sets of test and trainig using sklearn library. To do that we need to import a module called "model_selection"

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Now we can do the splitting. By default, the function train_test_split() splits the sample into 75% for training and 25% for testing, although it can be modified.

# %%
W_1_train,W_1_test,y_1_train,y_1_test = train_test_split(W_1,y)
W_2_train,W_2_test,y_2_train,y_2_test = train_test_split(W_2,y)
W_3_train,W_3_test,y_3_train,y_3_test = train_test_split(W_3,y)

# %% [markdown]
# ### Now, we train the models by fitting them to the data

# %%
model_1 = LinearRegression()
model_1.fit(W_1_train,y_1_train)
# Out:
# LinearRegression()

# %%
model_2 = LinearRegression()
model_2.fit(W_2_train,y_2_train)
# Out:
# LinearRegression()

# %%
model_3 = LinearRegression()
model_3.fit(W_3_train,y_3_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### How do we use the test sample? First, predict the model fitted to the training sample using the test sample

# %%
y_1_hat_test = model_1.predict(W_1_test)
y_2_hat_test = model_2.predict(W_2_test)
y_3_hat_test = model_3.predict(W_3_test)

# %% [markdown]
# ### Now, we can calculate our goodness of fit measures using all the test sample information

# %%
# MSE

mse_1_test = np.mean((y_1_test - y_1_hat_test) ** 2)
mse_2_test = np.mean((y_2_test - y_2_hat_test) ** 2)
mse_3_test = np.mean((y_3_test - y_3_hat_test) ** 2)

print(f'MSE out of sample of predictor 1 is {mse_1_test}')
print(f'MSE out of sample of predictor 2 is {mse_2_test}')
print(f'MSE out of sample of predictor 3 is {mse_3_test}')

# R-squared

R_sq_1_test = 1 - mse_1_test / np.mean((y_1_test-np.mean(y_1_test))** 2)
R_sq_2_test = 1 - mse_2_test / np.mean((y_2_test-np.mean(y_2_test))** 2)
R_sq_3_test = 1 - mse_3_test / np.mean((y_3_test-np.mean(y_3_test))** 2)

print(f'R-squared out of sample of predictor 1 is {R_sq_1_test}')
print(f'R-squared out of sample of predictor 2 is {R_sq_2_test}')
print(f'R-squared out of sample of predictor 3 is {R_sq_3_test}')

# Adjusted R-squared
adj_mse_1_test = 1000 / 2 * mse_1_test
adjR_sq_1_test = 1 - adj_mse_1_test / np.mean((y_1_test-np.mean(y_1_test))** 2)

adj_mse_2_test = 1000 / 4 * mse_2_test
adjR_sq_2_test = 1 - adj_mse_2_test / np.mean((y_2_test-np.mean(y_2_test))** 2)

adj_mse_3_test = 1000 / 2 * mse_3_test
adjR_sq_3_test = 1 - adj_mse_3_test / np.mean((y_3_test-np.mean(y_3_test))** 2)

print(f'Adjusted R-squared out of sample of predictor 1 is {adjR_sq_1_test}')
print(f'Adjusted R-squared out of sample of predictor 2 is {adjR_sq_2_test}')
print(f'Adjusted R-squared out of sample of predictor 3 is {adjR_sq_3_test}')
# Out:
# MSE out of sample of predictor 1 is 34.59526422384407
# MSE out of sample of predictor 2 is 1.2751461462532374
# MSE out of sample of predictor 3 is 42.717211402584155
# R-squared out of sample of predictor 1 is 0.8101042167746093
# R-squared out of sample of predictor 2 is 0.9932074485559268
# R-squared out of sample of predictor 3 is 0.7405037053055123
# Adjusted R-squared out of sample of predictor 1 is -93.94789161269537
# Adjusted R-squared out of sample of predictor 2 is -0.6981378610183142
# Adjusted R-squared out of sample of predictor 3 is -128.74814734724382
