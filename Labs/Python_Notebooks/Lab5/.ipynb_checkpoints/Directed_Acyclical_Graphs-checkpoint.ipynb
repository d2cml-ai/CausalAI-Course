# %% [markdown]
# ## Welcome
#
# This is material for the **Directed Acyclical Graphs** chapter in Scott Cunningham's book, [Causal Inference: The Mixtape.](https://mixtape.scunning.com/)

# %%
# !pip install Stargazer
# Out:
# Collecting Stargazer
#   Downloading stargazer-0.0.5-py3-none-any.whl (9.7 kB)
# Installing collected packages: Stargazer
# Successfully installed Stargazer-0.0.5

# %%
# !pip install plotnine
# Out:
# Collecting plotnine
#   Downloading plotnine-0.8.0-py3-none-any.whl (4.7 MB)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\roberto\anaconda3\lib\site-packages (from plotnine) (1.20.3)
# Requirement already satisfied: matplotlib>=3.1.1 in c:\users\roberto\anaconda3\lib\site-packages (from plotnine) (3.4.3)
# Requirement already satisfied: pandas>=1.1.0 in c:\users\roberto\anaconda3\lib\site-packages (from plotnine) (1.3.4)
# Collecting descartes>=1.1.0
#   Downloading descartes-1.1.0-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\roberto\anaconda3\lib\site-packages (from plotnine) (1.7.1)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\roberto\anaconda3\lib\site-packages (from plotnine) (0.5.2)
# Collecting mizani>=0.7.3
#   Downloading mizani-0.7.4-py3-none-any.whl (63 kB)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\roberto\anaconda3\lib\site-packages (from plotnine) (0.12.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\roberto\anaconda3\lib\site-packages (from matplotlib>=3.1.1->plotnine) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\roberto\anaconda3\lib\site-packages (from matplotlib>=3.1.1->plotnine) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\roberto\anaconda3\lib\site-packages (from matplotlib>=3.1.1->plotnine) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\roberto\anaconda3\lib\site-packages (from matplotlib>=3.1.1->plotnine) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\roberto\anaconda3\lib\site-packages (from matplotlib>=3.1.1->plotnine) (0.10.0)
# Requirement already satisfied: six in c:\users\roberto\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib>=3.1.1->plotnine) (1.16.0)
# Collecting matplotlib>=3.1.1
#   Downloading matplotlib-3.5.2-cp39-cp39-win_amd64.whl (7.2 MB)
# Collecting palettable
#   Downloading palettable-3.3.0-py2.py3-none-any.whl (111 kB)
# Collecting pandas>=1.1.0
#   Downloading pandas-1.4.2-cp39-cp39-win_amd64.whl (10.5 MB)
# Requirement already satisfied: packaging>=20.0 in c:\users\roberto\anaconda3\lib\site-packages (from matplotlib>=3.1.1->plotnine) (21.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\roberto\anaconda3\lib\site-packages (from matplotlib>=3.1.1->plotnine) (4.25.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\roberto\anaconda3\lib\site-packages (from pandas>=1.1.0->plotnine) (2021.3)
# Installing collected packages: pandas, palettable, matplotlib, mizani, descartes, plotnine
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.4
#     Uninstalling pandas-1.3.4:
#       Successfully uninstalled pandas-1.3.4
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.4.3
#     Uninstalling matplotlib-3.4.3:
#       Successfully uninstalled matplotlib-3.4.3
# Successfully installed descartes-1.1.0 matplotlib-3.5.2 mizani-0.7.4 palettable-3.3.0 pandas-1.4.2 plotnine-0.8.0

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from stargazer.stargazer import Stargazer

import plotnine as p

# %%
# read data
def read_data(file):
    return pd.read_csv("https://raw.github.com/scunning1975/mixtape/master/" + file)

# %% [markdown]
# ## Collider - Discrimination

# %%
tb = pd.DataFrame({
    'female': np.random.binomial(1, .5, size=10000),
    'ability': np.random.normal(size=10000)})
tb['discrimination'] = tb.female.copy()
tb['occupation'] = 1 + 2*tb['ability'] + 0*tb['female'] - 2*tb['discrimination'] + np.random.normal(size=10000)
tb['wage'] = 1 - 1*tb['discrimination'] + 1*tb['occupation'] + 2*tb['ability'] + np.random.normal(size=10000)

# %%
lm_1 = sm.OLS.from_formula('wage ~ female', data=tb).fit()
lm_2 = sm.OLS.from_formula('wage ~ female + occupation', data=tb).fit()
lm_3 = sm.OLS.from_formula('wage ~ female + occupation + ability', data=tb).fit()


st = Stargazer((lm_1,lm_2,lm_3))
st.custom_columns(["Biased Unconditional", "Biased", "Unbiased Conditional"], [1, 1, 1])
st
# Out:
# <table style="text-align:center"><tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left"></td><td colspan="3"><em>Dependent variable:wage</em></td></tr><tr><td style="text-align:left"></td><tr><td></td><td colspan="1">Biased Unconditional</td><td colspan="1">Biased</td><td colspan="1">Unbiased Conditional</td></tr><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td></tr><tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left">Intercept</td><td>2.024<sup>***</sup></td><td>0.182<sup>***</sup></td><td>1.002<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(0.061)</td><td>(0.020)</td><td>(0.018)</td></tr><tr><td style="text-align:left">ability</td><td></td><td></td><td>2.014<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td></td><td>(0.023)</td></tr><tr><td style="text-align:left">female</td><td>-3.009<sup>***</sup></td><td>0.621<sup>***</sup></td><td>-1.009<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(0.085)</td><td>(0.030)</td><td>(0.029)</td></tr><tr><td style="text-align:left">occupation</td><td></td><td>1.801<sup>***</sup></td><td>0.998<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.006)</td><td>(0.010)</td></tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Observations</td><td>10,000</td><td>10,000</td><td>10,000</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.111</td><td>0.909</td><td>0.949</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>0.111</td><td>0.909</td><td>0.949</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>4.260 (df=9998)</td><td>1.363 (df=9997)</td><td>1.019 (df=9996)</td></tr><tr><td style="text-align: left">F Statistic</td><td>1247.009<sup>***</sup> (df=1; 9998)</td><td>49895.028<sup>***</sup> (df=2; 9997)</td><td>62221.039<sup>***</sup> (df=3; 9996)</td></tr><tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td>
#  <td colspan="3" style="text-align: right">
#   <sup>*</sup>p&lt;0.1;
#   <sup>**</sup>p&lt;0.05;
#   <sup>***</sup>p&lt;0.01
#  </td></tr></table>

# %% [markdown]
# #### QUESTIONS
# - What is the true direct effect of discrimination on wages?
# - Explain the channels by which discrimination impacts wages.
# - What makes occupation a collider?
# - What controls are necessary to eliminate this collider bias?
#
#
#
# ## Movie Star

# %%
start_is_born = pd.DataFrame({
    'beauty': np.random.normal(size=2500),
    'talent': np.random.normal(size=2500)})
    
start_is_born['score'] = start_is_born['beauty'] + start_is_born['talent']
start_is_born['c85'] = np.percentile(start_is_born['score'], q=85)
start_is_born['star'] = 0
start_is_born.loc[start_is_born['score']>start_is_born['c85'], 'star'] = 1
start_is_born.head()
# Out:
#      beauty    talent     score      c85  star
# 0  0.943889 -0.092690  0.851199  1.52974     0
# 1  1.883071  1.416844  3.299915  1.52974     1
# 2  0.211299  1.129394  1.340693  1.52974     0
# 3  1.004988  1.109732  2.114720  1.52974     1
# 4  1.263941 -0.435670  0.828271  1.52974     0

# %%
lm = sm.OLS.from_formula('beauty ~ talent', data=start_is_born).fit()

p.ggplot(start_is_born, p.aes(x='talent', y='beauty')) +\
    p.geom_point(size = 0.5) +\
    p.xlim(-4, 4) +\
    p.ylim(-4, 4)
# Out:
# <ggplot: (77997021922)>

# %%
p.ggplot(start_is_born[start_is_born.star==1], p.aes(x='talent', y='beauty')) +\
    p.geom_point(size = 0.5) +\
    p.xlim(-4, 4) +\
    p.ylim(-4, 4)
# Out:
# <ggplot: (77997760729)>

# %%
p.ggplot(start_is_born[start_is_born.star==0], p.aes(x='talent', y='beauty')) +\
    p.geom_point(size = 0.5) +\
    p.xlim(-4, 4) +\
    p.ylim(-4, 4)
# Out:
# <ggplot: (77997802632)>

# %% [markdown]
# #### QUESTIONS
# - What is the correlation between talent and beauty among stars?  Non-stars?
# - But what is the correlation between talent and beauty in the population?
