# %% [markdown]
# ### 1 Loading the data

# %%
setwd("//your_directory")

# Load the data
data <- read.csv('wage2015_subsample_inference.csv')

# Separate the features and the target variable
X <- data[, !(names(data) %in% c('wage', 'lwage'))]  # Drop columns 'wage' and 'lwage'
y <- data['lwage']

# %%
# Load necessary package
library(stats)

# Create the design matrix
X_flexible <- model.matrix(~ 0 + sex + (exp1 + exp2 + exp3 + exp4 + hsg + scl + clg + ad + so + we + ne + 
                                         factor(occ2) + factor(ind2))^2, data = X)

# %%
y <- as.matrix(y)

X_flexible <- as.matrix(X_flexible)

# %% [markdown]
# ### 2 Creating the Lasso Cross-Validation Procedure

# %% [markdown]
# 4. The `log_grid` function is pretty straight forward

# %%
log_grid <- function(lower, upper, log_step) {
  log_grid <- seq(lower, upper, length.out = 1 / log_step)
  return(exp(log_grid))
}

# %% [markdown]
# 5. To code the `k_folds` function, there are many different approaches. We exploited the kronecker product operation and block matrices to build the $k$-folds. Also, we addressed the issue of divisibility between the sample size $n$ and $k$ using an if-else statement depending on the module of $n/k$

# %%
k_folds <- function(data, k = 5) {
  
  module <- nrow(data) %% k
  floor <- nrow(data) %/% k 
  
  if (module == 0) {
    trues <- matrix(1, nrow = floor, ncol = 1)
    split_matrix <- kronecker(diag(k), trues)
  } else {
    trues_g1 <- matrix(1, nrow = floor + 1, ncol = 1)
    split_matrix_g1 <- kronecker(diag(module), trues_g1)
    
    trues_g2 <- matrix(1, nrow = floor, ncol = 1)
    split_matrix_g2 <- kronecker(diag(k - module), trues_g2)
    
    split_matrix <- rbind(
      cbind(split_matrix_g1, matrix(0, nrow = nrow(split_matrix_g1), ncol = ncol(split_matrix_g2))),
      cbind(matrix(0, nrow = nrow(split_matrix_g2), ncol = ncol(split_matrix_g1)), split_matrix_g2)
    )
  }
  
  sm_bool <- split_matrix == 1
  splits <- lapply(1:k, function(x) sm_bool[, x])
  
  return(splits)
}

# %% [markdown]
# 6. For the `optimal_lambda` search function, we basically adapted the code provided in the labs so it can use the functions of log-grid and our own $k$-folds function

# %%
optimal_lambda <- function(Y, X, lambda_bounds, k = 5, niter = 100) {
  
  library(glmnet)
  
  Y <- drop(Y)
  
  if (is.vector(X)) {
    X <- matrix(X, ncol = 1)
  }
  
  folds <- k_folds(X, k)
  all_lambdas <- exp(seq(lambda_bounds[1], lambda_bounds[2], length.out = niter))
  all_mse <- numeric(niter)
  
  for (l in all_lambdas) {
    split_pes <- numeric(k)
    
    for (i in seq_len(k)) {
      X_train <- X[!folds[[i]], ]
      X_test <- X[folds[[i]], ]
      y_train <- Y[!folds[[i]]]
      y_test <- Y[folds[[i]]]
      
      model <- glmnet(X_train, y_train, alpha = 1, lambda = l,standardize = FALSE)
      predict <- predict(model, X_test, s = l)
      
      pe <- sum((y_test - predict)^2)
      split_pes[i] <- pe
    }
    
    all_mse[which(all_lambdas == l)] <- mean(split_pes)
  }
  
  selected <- which.min(all_mse)
  optimal_lambda <- all_lambdas[selected]
  optimal_model <- glmnet(X, Y, alpha = 1, lambda = optimal_lambda)
  optimal_coef <- coef(optimal_model, s = optimal_lambda)
  
  output <- list(
    optimal_lambda = optimal_lambda,
    optimal_coef = optimal_coef,
    all_lambdas = all_lambdas,
    all_mse = all_mse
  )
  
  return(output)
}

# %% [markdown]
# 7. The `predict_model` function can be easily implemented using the results of `optimal_function`

# %%
predict_model <- function(optimal_model, X) {
  
  intercept <- matrix(1, nrow = nrow(X), ncol = 1)
  Z <- cbind(intercept, X)
  
  return(Z %*% optimal_model$optimal_coef)
}

# %% [markdown]
# ### 3 Applying the Lasso Cross-Validation Procedure

# %% [markdown]
# We split the sample in train and test

# %%
library(caTools)


split <- sample.split(y, SplitRatio = 0.75)
X_flexible_train <- subset(X_flexible, split == TRUE)
X_flexible_test <- subset(X_flexible, split == FALSE)
y_train <- y[split]
y_test <- y[!split]
# Out:
# Warning message:
# "package 'caTools' was built under R version 4.3.3"

# %% [markdown]
# 8. We perform the OLS fitting

# %%
model_ls <- lm(y_train ~ ., data = data.frame(y_train = y_train, X_flexible_train))

# %% [markdown]
# 9. Npw we search the optimal lambda using our `optimal_lambda` function

# %%
model_lasso <- optimal_lambda(y_train, X_flexible_train, c(-7, 7))
# Out:
# Warning message:
# "package 'glmnet' was built under R version 4.3.3"
# Loading required package: Matrix
#
# Loaded glmnet 4.1-8

# %%
print(model_lasso$optimal_lambda)
# Out:
# [1] 0.001605462

# %%
print(model_lasso$optimal_coef)
# Out:
# 981 x 1 sparse Matrix of class "dgCMatrix"
#                                          s1
# (Intercept)                    2.721740e+00
# sex                           -6.289675e-02
# exp1                           6.384099e-03
# exp2                           .
# exp3                           .
# exp4                           .
# hsg                            .
# scl                            .
# clg                            3.080748e-01
# ad                             3.982615e-01
# so                             .
# we                             5.575766e-02
# ne                             .
# factor(occ2)1                  2.427481e-01
# factor(occ2)2                  1.546268e-01
# factor(occ2)3                  9.047187e-02
# factor(occ2)4                  3.834206e-02
# factor(occ2)5                  .
# factor(occ2)6                 -1.108579e-02
# factor(occ2)7                  .
# factor(occ2)8                 -6.299655e-02
# factor(occ2)9                  .
# factor(occ2)10                 8.296521e-02
# factor(occ2)11                -9.881469e-02
# factor(occ2)12                 .
# factor(occ2)13                 .
# factor(occ2)14                -5.043923e-02
# factor(occ2)15                -7.765751e-02
# factor(occ2)16                 5.538745e-02
# factor(occ2)17                -1.135753e-01
# factor(occ2)18                 .
# factor(occ2)19                 2.323926e-01
# factor(occ2)20                 .
# factor(occ2)21                 .
# factor(occ2)22                -1.607306e-01
# factor(ind2)3                  .
# factor(ind2)4                  .
# factor(ind2)5                  .
# factor(ind2)6                  .
# factor(ind2)7                  .
# factor(ind2)8                  .
# factor(ind2)9                  .
# factor(ind2)10                 .
# factor(ind2)11                 .
# factor(ind2)12                 1.822829e-01
# factor(ind2)13                 .
# factor(ind2)14                 1.252503e-02
# factor(ind2)15                 .
# factor(ind2)16                -6.833795e-02
# factor(ind2)17                -2.196524e-02
# factor(ind2)18                -1.093446e-01
# factor(ind2)19                -2.530845e-02
# factor(ind2)20                -2.326176e-01
# factor(ind2)21                 .
# factor(ind2)22                 .
# exp1:exp2                      .
# exp1:exp3                      .
# exp1:exp4                      .
# exp1:hsg                       .
# exp1:scl                       3.516553e-03
# exp1:clg                       1.698791e-03
# exp1:ad                        4.574399e-03
# exp1:so                        3.708360e-03
# exp1:we                        2.966863e-03
# exp1:ne                        3.990058e-03
# exp1:factor(occ2)2             .
# exp1:factor(occ2)3             .
# exp1:factor(occ2)4             .
# exp1:factor(occ2)5             8.597347e-03
# exp1:factor(occ2)6             .
# exp1:factor(occ2)7             9.038849e-04
# exp1:factor(occ2)8             2.642503e-03
# exp1:factor(occ2)9             5.467912e-03
# exp1:factor(occ2)10            7.178772e-03
# exp1:factor(occ2)11           -2.243057e-03
# exp1:factor(occ2)12            9.867969e-03
# exp1:factor(occ2)13           -4.939603e-03
# exp1:factor(occ2)14           -6.875796e-03
# exp1:factor(occ2)15           -3.030515e-03
# exp1:factor(occ2)16            1.029578e-02
# exp1:factor(occ2)17            .
# exp1:factor(occ2)18            .
# exp1:factor(occ2)19            .
# exp1:factor(occ2)20            .
# exp1:factor(occ2)21            .
# exp1:factor(occ2)22            .
# exp1:factor(ind2)3             .
# exp1:factor(ind2)4            -3.472577e-03
# exp1:factor(ind2)5             .
# exp1:factor(ind2)6             .
# exp1:factor(ind2)7             .
# exp1:factor(ind2)8            -1.300873e-03
# exp1:factor(ind2)9             4.773326e-05
# exp1:factor(ind2)10            6.200447e-03
# exp1:factor(ind2)11            .
# exp1:factor(ind2)12            2.192518e-03
# exp1:factor(ind2)13            .
# exp1:factor(ind2)14            3.335481e-03
# exp1:factor(ind2)15            7.870520e-03
# exp1:factor(ind2)16            .
# exp1:factor(ind2)17            .
# exp1:factor(ind2)18            .
# exp1:factor(ind2)19            .
# exp1:factor(ind2)20            .
# exp1:factor(ind2)21           -1.692997e-03
# exp1:factor(ind2)22            4.013746e-03
# exp2:exp3                      .
# exp2:exp4                      .
# exp2:hsg                       .
# exp2:scl                       .
# exp2:clg                       .
# exp2:ad                        .
# exp2:so                        .
# exp2:we                        .
# exp2:ne                        .
# exp2:factor(occ2)2             .
# exp2:factor(occ2)3             .
# exp2:factor(occ2)4            -8.642838e-03
# exp2:factor(occ2)5             .
# exp2:factor(occ2)6             .
# exp2:factor(occ2)7             .
# exp2:factor(occ2)8             .
# exp2:factor(occ2)9             .
# exp2:factor(occ2)10            .
# exp2:factor(occ2)11            .
# exp2:factor(occ2)12            .
# exp2:factor(occ2)13           -3.351487e-03
# exp2:factor(occ2)14            .
# exp2:factor(occ2)15            .
# exp2:factor(occ2)16            .
# exp2:factor(occ2)17            .
# exp2:factor(occ2)18            .
# exp2:factor(occ2)19            .
# exp2:factor(occ2)20            .
# exp2:factor(occ2)21            .
# exp2:factor(occ2)22           -1.778776e-03
# exp2:factor(ind2)3             .
# exp2:factor(ind2)4             .
# exp2:factor(ind2)5             .
# exp2:factor(ind2)6             .
# exp2:factor(ind2)7             .
# exp2:factor(ind2)8            -1.293001e-02
# exp2:factor(ind2)9             .
# exp2:factor(ind2)10            .
# exp2:factor(ind2)11            .
# exp2:factor(ind2)12            .
# exp2:factor(ind2)13            .
# exp2:factor(ind2)14            3.448026e-03
# exp2:factor(ind2)15            .
# exp2:factor(ind2)16            .
# exp2:factor(ind2)17            .
# exp2:factor(ind2)18            .
# exp2:factor(ind2)19            1.438421e-02
# exp2:factor(ind2)20           -1.457126e-02
# exp2:factor(ind2)21            .
# exp2:factor(ind2)22            .
# exp3:exp4                      .
# exp3:hsg                       .
# exp3:scl                       .
# exp3:clg                       .
# exp3:ad                        .
# exp3:so                        .
# exp3:we                        .
# exp3:ne                        .
# exp3:factor(occ2)2             .
# exp3:factor(occ2)3             .
# exp3:factor(occ2)4             .
# exp3:factor(occ2)5             .
# exp3:factor(occ2)6             .
# exp3:factor(occ2)7             .
# exp3:factor(occ2)8             .
# exp3:factor(occ2)9             .
# exp3:factor(occ2)10            .
# exp3:factor(occ2)11            .
# exp3:factor(occ2)12            .
# exp3:factor(occ2)13            .
# exp3:factor(occ2)14            .
# exp3:factor(occ2)15            .
# exp3:factor(occ2)16            .
# exp3:factor(occ2)17            .
# exp3:factor(occ2)18            .
# exp3:factor(occ2)19            .
# exp3:factor(occ2)20            .
# exp3:factor(occ2)21            .
# exp3:factor(occ2)22            .
# exp3:factor(ind2)3             .
# exp3:factor(ind2)4             .
# exp3:factor(ind2)5             .
# exp3:factor(ind2)6             .
# exp3:factor(ind2)7             .
# exp3:factor(ind2)8             .
# exp3:factor(ind2)9             .
# exp3:factor(ind2)10            .
# exp3:factor(ind2)11            .
# exp3:factor(ind2)12            .
# exp3:factor(ind2)13           -1.874213e-03
# exp3:factor(ind2)14            .
# exp3:factor(ind2)15            .
# exp3:factor(ind2)16            .
# exp3:factor(ind2)17            .
# exp3:factor(ind2)18            .
# exp3:factor(ind2)19            .
# exp3:factor(ind2)20           -1.316045e-03
# exp3:factor(ind2)21            .
# exp3:factor(ind2)22            .
# exp4:hsg                       4.309909e-04
# exp4:scl                      -5.283311e-04
# exp4:clg                      -3.508950e-04
# exp4:ad                       -1.217002e-03
# exp4:so                        .
# exp4:we                       -2.967888e-04
# exp4:ne                        1.151059e-04
# exp4:factor(occ2)2            -1.842401e-03
# exp4:factor(occ2)3             8.420658e-04
# exp4:factor(occ2)4             .
# exp4:factor(occ2)5             .
# exp4:factor(occ2)6            -4.758418e-04
# exp4:factor(occ2)7            -1.723747e-03
# exp4:factor(occ2)8             .
# exp4:factor(occ2)9            -2.856776e-04
# exp4:factor(occ2)10           -7.237189e-04
# exp4:factor(occ2)11            .
# exp4:factor(occ2)12           -1.056571e-03
# exp4:factor(occ2)13            .
# exp4:factor(occ2)14            .
# exp4:factor(occ2)15            .
# exp4:factor(occ2)16           -2.522708e-03
# exp4:factor(occ2)17           -4.199039e-04
# exp4:factor(occ2)18            .
# exp4:factor(occ2)19            .
# exp4:factor(occ2)20            .
# exp4:factor(occ2)21           -1.334588e-03
# exp4:factor(occ2)22            .
# exp4:factor(ind2)3             1.569412e-04
# exp4:factor(ind2)4             1.007550e-03
# exp4:factor(ind2)5             2.015502e-04
# exp4:factor(ind2)6             .
# exp4:factor(ind2)7             1.931378e-04
# exp4:factor(ind2)8             .
# exp4:factor(ind2)9             .
# exp4:factor(ind2)10            .
# exp4:factor(ind2)11            .
# exp4:factor(ind2)12           -5.059716e-04
# exp4:factor(ind2)13            .
# exp4:factor(ind2)14            .
# exp4:factor(ind2)15            .
# exp4:factor(ind2)16           -8.833354e-04
# exp4:factor(ind2)17            .
# exp4:factor(ind2)18           -3.432136e-04
# exp4:factor(ind2)19            3.776608e-04
# exp4:factor(ind2)20            .
# exp4:factor(ind2)21           -1.160979e-03
# exp4:factor(ind2)22           -1.644428e-03
# hsg:scl                        .
# hsg:clg                        .
# hsg:ad                         .
# hsg:so                        -2.516573e-02
# hsg:we                         .
# hsg:ne                         2.285352e-02
# hsg:factor(occ2)2             -2.007162e-01
# hsg:factor(occ2)3             -4.367672e-03
# hsg:factor(occ2)4              .
# hsg:factor(occ2)5              .
# hsg:factor(occ2)6              .
# hsg:factor(occ2)7             -3.668880e-03
# hsg:factor(occ2)8             -4.931622e-01
# hsg:factor(occ2)9             -3.037608e-02
# hsg:factor(occ2)10            -1.123221e-01
# hsg:factor(occ2)11            -1.605994e-02
# hsg:factor(occ2)12            -2.444887e-01
# hsg:factor(occ2)13            -5.058348e-02
# hsg:factor(occ2)14             .
# hsg:factor(occ2)15            -4.969590e-02
# hsg:factor(occ2)16            -2.929247e-01
# hsg:factor(occ2)17            -5.545450e-02
# hsg:factor(occ2)18             .
# hsg:factor(occ2)19             3.160538e-02
# hsg:factor(occ2)20             1.434912e-01
# hsg:factor(occ2)21             3.203858e-02
# hsg:factor(occ2)22             .
# hsg:factor(ind2)3              .
# hsg:factor(ind2)4              1.250608e-03
# hsg:factor(ind2)5              4.729692e-02
# hsg:factor(ind2)6             -2.096833e-02
# hsg:factor(ind2)7              4.135211e-02
# hsg:factor(ind2)8              1.419412e-01
# hsg:factor(ind2)9             -1.774551e-02
# hsg:factor(ind2)10             2.328027e-02
# hsg:factor(ind2)11             2.542983e-01
# hsg:factor(ind2)12             .
# hsg:factor(ind2)13            -6.614966e-02
# hsg:factor(ind2)14            -1.326709e-01
# hsg:factor(ind2)15             .
# hsg:factor(ind2)16             1.048868e-01
# hsg:factor(ind2)17             .
# hsg:factor(ind2)18             .
# hsg:factor(ind2)19            -1.640082e-01
# hsg:factor(ind2)20             .
# hsg:factor(ind2)21            -2.132707e-01
# hsg:factor(ind2)22             3.415485e-02
# scl:clg                        .
# scl:ad                         .
# scl:so                         5.615560e-02
# scl:we                         8.167453e-02
# scl:ne                         .
# scl:factor(occ2)2              1.812439e-01
# scl:factor(occ2)3              1.423052e-02
# scl:factor(occ2)4              .
# scl:factor(occ2)5              5.432044e-01
# scl:factor(occ2)6              .
# scl:factor(occ2)7             -1.255012e-01
# scl:factor(occ2)8             -2.663952e-01
# scl:factor(occ2)9              .
# scl:factor(occ2)10             .
# scl:factor(occ2)11             .
# scl:factor(occ2)12             2.228140e-02
# scl:factor(occ2)13             3.212605e-03
# scl:factor(occ2)14             .
# scl:factor(occ2)15             .
# scl:factor(occ2)16            -2.116212e-01
# scl:factor(occ2)17            -2.345651e-02
# scl:factor(occ2)18             .
# scl:factor(occ2)19             3.460204e-02
# scl:factor(occ2)20             1.462097e-01
# scl:factor(occ2)21             .
# scl:factor(occ2)22             4.791903e-02
# scl:factor(ind2)3              .
# scl:factor(ind2)4              .
# scl:factor(ind2)5             -8.838143e-02
# scl:factor(ind2)6              9.765462e-02
# scl:factor(ind2)7              1.221226e-01
# scl:factor(ind2)8              .
# scl:factor(ind2)9             -1.386948e-01
# scl:factor(ind2)10            -4.555475e-02
# scl:factor(ind2)11             1.003793e-01
# scl:factor(ind2)12             3.412392e-02
# scl:factor(ind2)13            -4.276780e-02
# scl:factor(ind2)14             1.720745e-02
# scl:factor(ind2)15            -1.865870e-01
# scl:factor(ind2)16             1.813824e-01
# scl:factor(ind2)17             .
# scl:factor(ind2)18            -5.060880e-02
# scl:factor(ind2)19             .
# scl:factor(ind2)20            -2.607790e-02
# scl:factor(ind2)21             .
# scl:factor(ind2)22             .
# clg:ad                         .
# clg:so                         1.938575e-02
# clg:we                        -5.168297e-02
# clg:ne                        -3.636305e-02
# clg:factor(occ2)2              .
# clg:factor(occ2)3              1.842470e-02
# clg:factor(occ2)4              1.731374e-01
# clg:factor(occ2)5              .
# clg:factor(occ2)6             -1.276951e-01
# clg:factor(occ2)7             -6.542569e-02
# clg:factor(occ2)8              .
# clg:factor(occ2)9              .
# clg:factor(occ2)10             8.315470e-02
# clg:factor(occ2)11             7.762647e-02
# clg:factor(occ2)12             5.592268e-02
# clg:factor(occ2)13             .
# clg:factor(occ2)14             2.327566e-01
# clg:factor(occ2)15             1.731738e-02
# clg:factor(occ2)16             .
# clg:factor(occ2)17             .
# clg:factor(occ2)18             .
# clg:factor(occ2)19             1.413216e-01
# clg:factor(occ2)20            -6.068457e-02
# clg:factor(occ2)21            -1.022610e-01
# clg:factor(occ2)22            -3.158480e-02
# clg:factor(ind2)3              3.473934e-01
# clg:factor(ind2)4             -8.867885e-02
# clg:factor(ind2)5              2.997788e-02
# clg:factor(ind2)6              1.034710e-01
# clg:factor(ind2)7             -3.464925e-01
# clg:factor(ind2)8             -4.178881e-02
# clg:factor(ind2)9             -3.125443e-01
# clg:factor(ind2)10             .
# clg:factor(ind2)11             .
# clg:factor(ind2)12             .
# clg:factor(ind2)13             1.960686e-01
# clg:factor(ind2)14             .
# clg:factor(ind2)15             .
# clg:factor(ind2)16             .
# clg:factor(ind2)17            -1.100885e-01
# clg:factor(ind2)18            -3.458646e-02
# clg:factor(ind2)19            -8.313259e-02
# clg:factor(ind2)20            -9.593299e-02
# clg:factor(ind2)21             .
# clg:factor(ind2)22             4.314664e-02
# ad:so                          6.793672e-02
# ad:we                          1.166538e-02
# ad:ne                         -6.655964e-02
# ad:factor(occ2)2               .
# ad:factor(occ2)3               .
# ad:factor(occ2)4              -4.522276e-02
# ad:factor(occ2)5               .
# ad:factor(occ2)6              -2.474120e-01
# ad:factor(occ2)7               4.221426e-01
# ad:factor(occ2)8               .
# ad:factor(occ2)9              -3.155627e-01
# ad:factor(occ2)10              3.143114e-03
# ad:factor(occ2)11              .
# ad:factor(occ2)12             -2.493051e-01
# ad:factor(occ2)13             -5.020822e-01
# ad:factor(occ2)14              .
# ad:factor(occ2)15              6.367527e-02
# ad:factor(occ2)16              .
# ad:factor(occ2)17              4.823876e-02
# ad:factor(occ2)18              .
# ad:factor(occ2)19             -6.884142e-01
# ad:factor(occ2)20              .
# ad:factor(occ2)21             -3.036955e-01
# ad:factor(occ2)22             -8.474681e-01
# ad:factor(ind2)3              -3.089133e-01
# ad:factor(ind2)4               2.648605e-01
# ad:factor(ind2)5               2.313817e-01
# ad:factor(ind2)6               .
# ad:factor(ind2)7               .
# ad:factor(ind2)8               3.253281e-01
# ad:factor(ind2)9               4.841730e-02
# ad:factor(ind2)10             -1.553541e-01
# ad:factor(ind2)11             -6.811757e-02
# ad:factor(ind2)12              .
# ad:factor(ind2)13              1.048142e-01
# ad:factor(ind2)14              8.792699e-02
# ad:factor(ind2)15              .
# ad:factor(ind2)16              2.524938e-01
# ad:factor(ind2)17             -6.162114e-02
# ad:factor(ind2)18              9.825564e-02
# ad:factor(ind2)19              3.190798e-02
# ad:factor(ind2)20              1.035022e-01
# ad:factor(ind2)21             -1.394629e-01
# ad:factor(ind2)22              .
# so:we                          .
# so:ne                          .
# so:factor(occ2)2              -1.524503e-02
# so:factor(occ2)3               8.259696e-02
# so:factor(occ2)4               .
# so:factor(occ2)5              -7.179611e-02
# so:factor(occ2)6               5.145782e-02
# so:factor(occ2)7              -2.478972e-01
# so:factor(occ2)8               .
# so:factor(occ2)9               5.507492e-02
# so:factor(occ2)10              .
# so:factor(occ2)11             -1.024387e-01
# so:factor(occ2)12             -3.175707e-01
# so:factor(occ2)13              .
# so:factor(occ2)14              .
# so:factor(occ2)15             -3.626977e-02
# so:factor(occ2)16             -1.049117e-01
# so:factor(occ2)17             -1.376452e-02
# so:factor(occ2)18              .
# so:factor(occ2)19             -2.182413e-01
# so:factor(occ2)20             -8.692494e-02
# so:factor(occ2)21              3.749925e-02
# so:factor(occ2)22             -1.001629e-01
# so:factor(ind2)3              -7.820304e-02
# so:factor(ind2)4               .
# so:factor(ind2)5               .
# so:factor(ind2)6              -1.240945e-01
# so:factor(ind2)7               .
# so:factor(ind2)8               8.774828e-02
# so:factor(ind2)9               .
# so:factor(ind2)10              .
# so:factor(ind2)11             -2.072600e-02
# so:factor(ind2)12             -4.797659e-02
# so:factor(ind2)13              1.043124e-01
# so:factor(ind2)14              8.432383e-04
# so:factor(ind2)15              .
# so:factor(ind2)16             -1.514545e-01
# so:factor(ind2)17             -8.839320e-02
# so:factor(ind2)18              .
# so:factor(ind2)19             -7.321917e-02
# so:factor(ind2)20             -9.435589e-02
# so:factor(ind2)21              8.437665e-02
# so:factor(ind2)22              1.512232e-01
# we:ne                          .
# we:factor(occ2)2              -3.337715e-02
# we:factor(occ2)3               4.262207e-02
# we:factor(occ2)4               9.594276e-03
# we:factor(occ2)5               1.621426e-01
# we:factor(occ2)6               .
# we:factor(occ2)7              -1.784206e-01
# we:factor(occ2)8              -7.953604e-03
# we:factor(occ2)9              -2.664447e-01
# we:factor(occ2)10              .
# we:factor(occ2)11              .
# we:factor(occ2)12             -7.924228e-02
# we:factor(occ2)13             -2.717791e-02
# we:factor(occ2)14             -5.022441e-02
# we:factor(occ2)15             -6.375667e-02
# we:factor(occ2)16              6.459154e-02
# we:factor(occ2)17              .
# we:factor(occ2)18             -3.054490e-01
# we:factor(occ2)19              6.311011e-03
# we:factor(occ2)20             -7.262266e-02
# we:factor(occ2)21             -6.473496e-02
# we:factor(occ2)22              3.750497e-02
# we:factor(ind2)3               9.133069e-02
# we:factor(ind2)4               1.664938e-02
# we:factor(ind2)5               1.135682e-02
# we:factor(ind2)6              -1.768339e-01
# we:factor(ind2)7               1.294833e-01
# we:factor(ind2)8               1.907109e-01
# we:factor(ind2)9               4.218300e-02
# we:factor(ind2)10             -3.070231e-01
# we:factor(ind2)11              8.213426e-02
# we:factor(ind2)12             -7.812351e-02
# we:factor(ind2)13              .
# we:factor(ind2)14             -4.352894e-02
# we:factor(ind2)15              1.615208e-01
# we:factor(ind2)16             -2.135682e-01
# we:factor(ind2)17             -2.297434e-02
# we:factor(ind2)18             -3.236691e-03
# we:factor(ind2)19              .
# we:factor(ind2)20              .
# we:factor(ind2)21              .
# we:factor(ind2)22              1.494379e-02
# ne:factor(occ2)2               .
# ne:factor(occ2)3               .
# ne:factor(occ2)4               7.091848e-03
# ne:factor(occ2)5               3.685505e-02
# ne:factor(occ2)6               5.697443e-02
# ne:factor(occ2)7               2.431491e-01
# ne:factor(occ2)8               6.789543e-02
# ne:factor(occ2)9               1.496361e-01
# ne:factor(occ2)10              1.810487e-01
# ne:factor(occ2)11             -4.066886e-02
# ne:factor(occ2)12              5.632577e-02
# ne:factor(occ2)13              1.194878e-02
# ne:factor(occ2)14              .
# ne:factor(occ2)15              1.061028e-01
# ne:factor(occ2)16             -4.443274e-02
# ne:factor(occ2)17              9.574205e-03
# ne:factor(occ2)18              7.045891e-01
# ne:factor(occ2)19             -7.540848e-02
# ne:factor(occ2)20             -1.348832e-01
# ne:factor(occ2)21             -6.626310e-02
# ne:factor(occ2)22             -4.477199e-02
# ne:factor(ind2)3               .
# ne:factor(ind2)4               .
# ne:factor(ind2)5              -7.540698e-02
# ne:factor(ind2)6              -9.208292e-02
# ne:factor(ind2)7               2.404301e-02
# ne:factor(ind2)8              -1.638644e-02
# ne:factor(ind2)9               .
# ne:factor(ind2)10             -1.705255e-01
# ne:factor(ind2)11              1.047958e-01
# ne:factor(ind2)12              .
# ne:factor(ind2)13              1.315940e-01
# ne:factor(ind2)14              5.306485e-02
# ne:factor(ind2)15              6.829926e-01
# ne:factor(ind2)16              4.230213e-03
# ne:factor(ind2)17              .
# ne:factor(ind2)18             -9.535672e-02
# ne:factor(ind2)19              .
# ne:factor(ind2)20             -1.441706e-02
# ne:factor(ind2)21              .
# ne:factor(ind2)22              1.038599e-01
# factor(occ2)2:factor(ind2)3   -2.252995e-01
# factor(occ2)3:factor(ind2)3    .
# factor(occ2)4:factor(ind2)3    .
# factor(occ2)5:factor(ind2)3    .
# factor(occ2)6:factor(ind2)3    .
# factor(occ2)7:factor(ind2)3    .
# factor(occ2)8:factor(ind2)3    .
# factor(occ2)9:factor(ind2)3    .
# factor(occ2)10:factor(ind2)3   .
# factor(occ2)11:factor(ind2)3   .
# factor(occ2)12:factor(ind2)3   .
# factor(occ2)13:factor(ind2)3   .
# factor(occ2)14:factor(ind2)3   .
# factor(occ2)15:factor(ind2)3   .
# factor(occ2)16:factor(ind2)3   .
# factor(occ2)17:factor(ind2)3  -1.507660e-01
# factor(occ2)18:factor(ind2)3   .
# factor(occ2)19:factor(ind2)3  -2.434989e-01
# factor(occ2)20:factor(ind2)3   2.335204e-01
# factor(occ2)21:factor(ind2)3   1.591234e-01
# factor(occ2)22:factor(ind2)3   4.693773e-03
# factor(occ2)2:factor(ind2)4    2.159472e-02
# factor(occ2)3:factor(ind2)4    .
# factor(occ2)4:factor(ind2)4    .
# factor(occ2)5:factor(ind2)4    .
# factor(occ2)6:factor(ind2)4    .
# factor(occ2)7:factor(ind2)4    .
# factor(occ2)8:factor(ind2)4   -3.754624e-02
# factor(occ2)9:factor(ind2)4    .
# factor(occ2)10:factor(ind2)4   .
# factor(occ2)11:factor(ind2)4   .
# factor(occ2)12:factor(ind2)4   .
# factor(occ2)13:factor(ind2)4   .
# factor(occ2)14:factor(ind2)4   .
# factor(occ2)15:factor(ind2)4   .
# factor(occ2)16:factor(ind2)4   4.142856e-01
# factor(occ2)17:factor(ind2)4   2.230235e-02
# factor(occ2)18:factor(ind2)4   .
# factor(occ2)19:factor(ind2)4  -2.142942e-01
# factor(occ2)20:factor(ind2)4   .
# factor(occ2)21:factor(ind2)4   3.279274e-01
# factor(occ2)22:factor(ind2)4   3.176714e-01
# factor(occ2)2:factor(ind2)5    6.513571e-02
# factor(occ2)3:factor(ind2)5    .
# factor(occ2)4:factor(ind2)5    2.261746e-01
# factor(occ2)5:factor(ind2)5   -1.125481e-01
# factor(occ2)6:factor(ind2)5    .
# factor(occ2)7:factor(ind2)5    .
# factor(occ2)8:factor(ind2)5    .
# factor(occ2)9:factor(ind2)5   -7.978311e-02
# factor(occ2)10:factor(ind2)5   6.831302e-01
# factor(occ2)11:factor(ind2)5   .
# factor(occ2)12:factor(ind2)5   .
# factor(occ2)13:factor(ind2)5  -1.051730e-01
# factor(occ2)14:factor(ind2)5  -2.833253e-02
# factor(occ2)15:factor(ind2)5   .
# factor(occ2)16:factor(ind2)5   .
# factor(occ2)17:factor(ind2)5   .
# factor(occ2)18:factor(ind2)5  -3.310332e-01
# factor(occ2)19:factor(ind2)5   .
# factor(occ2)20:factor(ind2)5  -1.163681e-01
# factor(occ2)21:factor(ind2)5  -9.383421e-02
# factor(occ2)22:factor(ind2)5  -2.315121e-01
# factor(occ2)2:factor(ind2)6    7.469942e-02
# factor(occ2)3:factor(ind2)6    3.578899e-01
# factor(occ2)4:factor(ind2)6    1.320034e-01
# factor(occ2)5:factor(ind2)6    3.635294e-01
# factor(occ2)6:factor(ind2)6   -1.263628e-01
# factor(occ2)7:factor(ind2)6    .
# factor(occ2)8:factor(ind2)6    .
# factor(occ2)9:factor(ind2)6   -1.647287e-01
# factor(occ2)10:factor(ind2)6   .
# factor(occ2)11:factor(ind2)6   .
# factor(occ2)12:factor(ind2)6   .
# factor(occ2)13:factor(ind2)6   .
# factor(occ2)14:factor(ind2)6  -1.115414e-01
# factor(occ2)15:factor(ind2)6   .
# factor(occ2)16:factor(ind2)6   2.642463e-01
# factor(occ2)17:factor(ind2)6   .
# factor(occ2)18:factor(ind2)6   .
# factor(occ2)19:factor(ind2)6   .
# factor(occ2)20:factor(ind2)6  -1.449823e-01
# factor(occ2)21:factor(ind2)6  -1.637579e-02
# factor(occ2)22:factor(ind2)6   .
# factor(occ2)2:factor(ind2)7    1.534669e-01
# factor(occ2)3:factor(ind2)7    5.499430e-01
# factor(occ2)4:factor(ind2)7    6.992520e-02
# factor(occ2)5:factor(ind2)7    .
# factor(occ2)6:factor(ind2)7    .
# factor(occ2)7:factor(ind2)7    .
# factor(occ2)8:factor(ind2)7    .
# factor(occ2)9:factor(ind2)7    1.159327e-01
# factor(occ2)10:factor(ind2)7   .
# factor(occ2)11:factor(ind2)7   .
# factor(occ2)12:factor(ind2)7   .
# factor(occ2)13:factor(ind2)7   1.433127e-01
# factor(occ2)14:factor(ind2)7   .
# factor(occ2)15:factor(ind2)7   .
# factor(occ2)16:factor(ind2)7   3.255594e-01
# factor(occ2)17:factor(ind2)7  -2.481712e-01
# factor(occ2)18:factor(ind2)7   .
# factor(occ2)19:factor(ind2)7   .
# factor(occ2)20:factor(ind2)7   2.372116e-01
# factor(occ2)21:factor(ind2)7  -1.081577e-01
# factor(occ2)22:factor(ind2)7   .
# factor(occ2)2:factor(ind2)8   -2.216585e-01
# factor(occ2)3:factor(ind2)8   -3.713523e-01
# factor(occ2)4:factor(ind2)8    .
# factor(occ2)5:factor(ind2)8    .
# factor(occ2)6:factor(ind2)8    .
# factor(occ2)7:factor(ind2)8    .
# factor(occ2)8:factor(ind2)8    .
# factor(occ2)9:factor(ind2)8    .
# factor(occ2)10:factor(ind2)8   .
# factor(occ2)11:factor(ind2)8   .
# factor(occ2)12:factor(ind2)8   2.661532e-01
# factor(occ2)13:factor(ind2)8   .
# factor(occ2)14:factor(ind2)8   .
# factor(occ2)15:factor(ind2)8   .
# factor(occ2)16:factor(ind2)8   .
# factor(occ2)17:factor(ind2)8  -3.157167e-01
# factor(occ2)18:factor(ind2)8   .
# factor(occ2)19:factor(ind2)8   .
# factor(occ2)20:factor(ind2)8   7.509113e-01
# factor(occ2)21:factor(ind2)8   .
# factor(occ2)22:factor(ind2)8   .
# factor(occ2)2:factor(ind2)9    3.033502e-01
# factor(occ2)3:factor(ind2)9   -1.906661e-02
# factor(occ2)4:factor(ind2)9    .
# factor(occ2)5:factor(ind2)9    .
# factor(occ2)6:factor(ind2)9    .
# factor(occ2)7:factor(ind2)9    1.342295e-01
# factor(occ2)8:factor(ind2)9    .
# factor(occ2)9:factor(ind2)9    .
# factor(occ2)10:factor(ind2)9   1.197476e-01
# factor(occ2)11:factor(ind2)9   .
# factor(occ2)12:factor(ind2)9  -1.237918e-01
# factor(occ2)13:factor(ind2)9  -1.575522e-01
# factor(occ2)14:factor(ind2)9  -4.337908e-01
# factor(occ2)15:factor(ind2)9   .
# factor(occ2)16:factor(ind2)9   .
# factor(occ2)17:factor(ind2)9   .
# factor(occ2)18:factor(ind2)9   .
# factor(occ2)19:factor(ind2)9  -5.774269e-02
# factor(occ2)20:factor(ind2)9  -5.022601e-02
# factor(occ2)21:factor(ind2)9  -5.018862e-02
# factor(occ2)22:factor(ind2)9   .
# factor(occ2)2:factor(ind2)10  -2.653198e-01
# factor(occ2)3:factor(ind2)10   .
# factor(occ2)4:factor(ind2)10   .
# factor(occ2)5:factor(ind2)10   .
# factor(occ2)6:factor(ind2)10   .
# factor(occ2)7:factor(ind2)10   .
# factor(occ2)8:factor(ind2)10   .
# factor(occ2)9:factor(ind2)10  -7.215595e-02
# factor(occ2)10:factor(ind2)10  .
# factor(occ2)11:factor(ind2)10  .
# factor(occ2)12:factor(ind2)10 -6.745718e-01
# factor(occ2)13:factor(ind2)10  .
# factor(occ2)14:factor(ind2)10  2.699460e-01
# factor(occ2)15:factor(ind2)10 -5.376348e-01
# factor(occ2)16:factor(ind2)10  .
# factor(occ2)17:factor(ind2)10 -8.987406e-03
# factor(occ2)18:factor(ind2)10  .
# factor(occ2)19:factor(ind2)10  .
# factor(occ2)20:factor(ind2)10  .
# factor(occ2)21:factor(ind2)10  7.077141e-01
# factor(occ2)22:factor(ind2)10  1.225554e-01
# factor(occ2)2:factor(ind2)11   3.563639e-01
# factor(occ2)3:factor(ind2)11  -2.652032e-01
# factor(occ2)4:factor(ind2)11   .
# factor(occ2)5:factor(ind2)11   .
# factor(occ2)6:factor(ind2)11   .
# factor(occ2)7:factor(ind2)11   6.918399e-01
# factor(occ2)8:factor(ind2)11  -1.666457e-01
# factor(occ2)9:factor(ind2)11  -7.918556e-02
# factor(occ2)10:factor(ind2)11  .
# factor(occ2)11:factor(ind2)11  .
# factor(occ2)12:factor(ind2)11  .
# factor(occ2)13:factor(ind2)11  .
# factor(occ2)14:factor(ind2)11 -5.215148e-01
# factor(occ2)15:factor(ind2)11  .
# factor(occ2)16:factor(ind2)11  1.156406e-01
# factor(occ2)17:factor(ind2)11 -3.494448e-02
# factor(occ2)18:factor(ind2)11  .
# factor(occ2)19:factor(ind2)11 -1.006404e+00
# factor(occ2)20:factor(ind2)11 -4.449326e-02
# factor(occ2)21:factor(ind2)11  .
# factor(occ2)22:factor(ind2)11  .
# factor(occ2)2:factor(ind2)12   4.040845e-02
# factor(occ2)3:factor(ind2)12   7.653144e-02
# factor(occ2)4:factor(ind2)12   .
# factor(occ2)5:factor(ind2)12   .
# factor(occ2)6:factor(ind2)12   .
# factor(occ2)7:factor(ind2)12   7.676315e-01
# factor(occ2)8:factor(ind2)12  -5.924036e-01
# factor(occ2)9:factor(ind2)12   1.564862e-01
# factor(occ2)10:factor(ind2)12  9.660558e-02
# factor(occ2)11:factor(ind2)12  .
# factor(occ2)12:factor(ind2)12  3.855485e-01
# factor(occ2)13:factor(ind2)12  .
# factor(occ2)14:factor(ind2)12 -3.407999e-01
# factor(occ2)15:factor(ind2)12  .
# factor(occ2)16:factor(ind2)12  9.695745e-02
# factor(occ2)17:factor(ind2)12 -1.512088e-01
# factor(occ2)18:factor(ind2)12  .
# factor(occ2)19:factor(ind2)12  .
# factor(occ2)20:factor(ind2)12 -1.433920e-01
# factor(occ2)21:factor(ind2)12  .
# factor(occ2)22:factor(ind2)12  .
# factor(occ2)2:factor(ind2)13  -1.232719e-01
# factor(occ2)3:factor(ind2)13   .
# factor(occ2)4:factor(ind2)13   .
# factor(occ2)5:factor(ind2)13   .
# factor(occ2)6:factor(ind2)13   .
# factor(occ2)7:factor(ind2)13   .
# factor(occ2)8:factor(ind2)13   .
# factor(occ2)9:factor(ind2)13   .
# factor(occ2)10:factor(ind2)13  .
# factor(occ2)11:factor(ind2)13  .
# factor(occ2)12:factor(ind2)13  .
# factor(occ2)13:factor(ind2)13  .
# factor(occ2)14:factor(ind2)13  .
# factor(occ2)15:factor(ind2)13  .
# factor(occ2)16:factor(ind2)13 -1.240277e-01
# factor(occ2)17:factor(ind2)13  .
# factor(occ2)18:factor(ind2)13  .
# factor(occ2)19:factor(ind2)13  .
# factor(occ2)20:factor(ind2)13  1.604543e-01
# factor(occ2)21:factor(ind2)13  .
# factor(occ2)22:factor(ind2)13  .
# factor(occ2)2:factor(ind2)14   .
# factor(occ2)3:factor(ind2)14   7.080004e-02
# factor(occ2)4:factor(ind2)14   .
# factor(occ2)5:factor(ind2)14  -1.485453e-01
# factor(occ2)6:factor(ind2)14   .
# factor(occ2)7:factor(ind2)14  -5.255886e-02
# factor(occ2)8:factor(ind2)14   .
# factor(occ2)9:factor(ind2)14   1.416855e-01
# factor(occ2)10:factor(ind2)14  3.450640e-01
# factor(occ2)11:factor(ind2)14 -3.021977e-01
# factor(occ2)12:factor(ind2)14  .
# factor(occ2)13:factor(ind2)14 -7.879115e-01
# factor(occ2)14:factor(ind2)14 -7.388627e-01
# factor(occ2)15:factor(ind2)14  .
# factor(occ2)16:factor(ind2)14  2.410291e-01
# factor(occ2)17:factor(ind2)14  2.582571e-02
# factor(occ2)18:factor(ind2)14  .
# factor(occ2)19:factor(ind2)14 -1.402315e-01
# factor(occ2)20:factor(ind2)14 -1.055338e+00
# factor(occ2)21:factor(ind2)14  .
# factor(occ2)22:factor(ind2)14  .
# factor(occ2)2:factor(ind2)15  -1.290028e-01
# factor(occ2)3:factor(ind2)15   .
# factor(occ2)4:factor(ind2)15   .
# factor(occ2)5:factor(ind2)15   .
# factor(occ2)6:factor(ind2)15   .
# factor(occ2)7:factor(ind2)15   .
# factor(occ2)8:factor(ind2)15   .
# factor(occ2)9:factor(ind2)15   .
# factor(occ2)10:factor(ind2)15  .
# factor(occ2)11:factor(ind2)15  .
# factor(occ2)12:factor(ind2)15  .
# factor(occ2)13:factor(ind2)15  .
# factor(occ2)14:factor(ind2)15  .
# factor(occ2)15:factor(ind2)15  .
# factor(occ2)16:factor(ind2)15  .
# factor(occ2)17:factor(ind2)15  .
# factor(occ2)18:factor(ind2)15  .
# factor(occ2)19:factor(ind2)15  .
# factor(occ2)20:factor(ind2)15  .
# factor(occ2)21:factor(ind2)15  .
# factor(occ2)22:factor(ind2)15  .
# factor(occ2)2:factor(ind2)16   1.486459e-01
# factor(occ2)3:factor(ind2)16   1.277431e-01
# factor(occ2)4:factor(ind2)16   .
# factor(occ2)5:factor(ind2)16   3.662579e-01
# factor(occ2)6:factor(ind2)16   .
# factor(occ2)7:factor(ind2)16   2.358820e-02
# factor(occ2)8:factor(ind2)16   .
# factor(occ2)9:factor(ind2)16   1.779763e-01
# factor(occ2)10:factor(ind2)16  1.912302e-01
# factor(occ2)11:factor(ind2)16  .
# factor(occ2)12:factor(ind2)16 -1.810036e-01
# factor(occ2)13:factor(ind2)16  .
# factor(occ2)14:factor(ind2)16 -1.775789e-01
# factor(occ2)15:factor(ind2)16  .
# factor(occ2)16:factor(ind2)16  2.245020e-01
# factor(occ2)17:factor(ind2)16  .
# factor(occ2)18:factor(ind2)16  .
# factor(occ2)19:factor(ind2)16  .
# factor(occ2)20:factor(ind2)16 -1.660670e-02
# factor(occ2)21:factor(ind2)16  6.201556e-02
# factor(occ2)22:factor(ind2)16 -1.519390e-01
# factor(occ2)2:factor(ind2)17   3.374505e-02
# factor(occ2)3:factor(ind2)17  -2.514706e-02
# factor(occ2)4:factor(ind2)17  -1.969036e-01
# factor(occ2)5:factor(ind2)17  -2.015885e-01
# factor(occ2)6:factor(ind2)17   3.168688e-01
# factor(occ2)7:factor(ind2)17   3.133627e-01
# factor(occ2)8:factor(ind2)17   .
# factor(occ2)9:factor(ind2)17   1.241506e-01
# factor(occ2)10:factor(ind2)17 -1.766671e-01
# factor(occ2)11:factor(ind2)17  .
# factor(occ2)12:factor(ind2)17  .
# factor(occ2)13:factor(ind2)17 -7.329953e-01
# factor(occ2)14:factor(ind2)17  .
# factor(occ2)15:factor(ind2)17  1.807632e-01
# factor(occ2)16:factor(ind2)17  5.296067e-01
# factor(occ2)17:factor(ind2)17 -9.136916e-03
# factor(occ2)18:factor(ind2)17  .
# factor(occ2)19:factor(ind2)17  .
# factor(occ2)20:factor(ind2)17  2.608490e-01
# factor(occ2)21:factor(ind2)17  .
# factor(occ2)22:factor(ind2)17 -1.005804e-01
# factor(occ2)2:factor(ind2)18   5.106031e-02
# factor(occ2)3:factor(ind2)18   4.280779e-01
# factor(occ2)4:factor(ind2)18   .
# factor(occ2)5:factor(ind2)18   .
# factor(occ2)6:factor(ind2)18   .
# factor(occ2)7:factor(ind2)18   .
# factor(occ2)8:factor(ind2)18   .
# factor(occ2)9:factor(ind2)18   .
# factor(occ2)10:factor(ind2)18  7.070844e-02
# factor(occ2)11:factor(ind2)18  .
# factor(occ2)12:factor(ind2)18  4.414475e-02
# factor(occ2)13:factor(ind2)18 -1.693000e-02
# factor(occ2)14:factor(ind2)18  1.189945e-02
# factor(occ2)15:factor(ind2)18 -4.324269e-02
# factor(occ2)16:factor(ind2)18  .
# factor(occ2)17:factor(ind2)18  8.948596e-02
# factor(occ2)18:factor(ind2)18  .
# factor(occ2)19:factor(ind2)18  .
# factor(occ2)20:factor(ind2)18  .
# factor(occ2)21:factor(ind2)18 -1.302246e-01
# factor(occ2)22:factor(ind2)18 -9.064552e-02
# factor(occ2)2:factor(ind2)19  -2.366306e-01
# factor(occ2)3:factor(ind2)19   3.198498e-03
# factor(occ2)4:factor(ind2)19   .
# factor(occ2)5:factor(ind2)19   .
# factor(occ2)6:factor(ind2)19   .
# factor(occ2)7:factor(ind2)19  -4.154364e-01
# factor(occ2)8:factor(ind2)19  -3.598792e-01
# factor(occ2)9:factor(ind2)19  -7.084080e-02
# factor(occ2)10:factor(ind2)19  .
# factor(occ2)11:factor(ind2)19  7.032566e-03
# factor(occ2)12:factor(ind2)19 -7.605665e-01
# factor(occ2)13:factor(ind2)19 -6.309207e-02
# factor(occ2)14:factor(ind2)19  .
# factor(occ2)15:factor(ind2)19 -3.626685e-01
# factor(occ2)16:factor(ind2)19 -2.463316e-01
# factor(occ2)17:factor(ind2)19  .
# factor(occ2)18:factor(ind2)19  .
# factor(occ2)19:factor(ind2)19  .
# factor(occ2)20:factor(ind2)19 -4.768496e-01
# factor(occ2)21:factor(ind2)19  .
# factor(occ2)22:factor(ind2)19  .
# factor(occ2)2:factor(ind2)20  -2.181158e-01
# factor(occ2)3:factor(ind2)20  -5.840172e-01
# factor(occ2)4:factor(ind2)20   .
# factor(occ2)5:factor(ind2)20   .
# factor(occ2)6:factor(ind2)20   .
# factor(occ2)7:factor(ind2)20   .
# factor(occ2)8:factor(ind2)20   3.749803e-01
# factor(occ2)9:factor(ind2)20   .
# factor(occ2)10:factor(ind2)20  .
# factor(occ2)11:factor(ind2)20  .
# factor(occ2)12:factor(ind2)20  8.290923e-02
# factor(occ2)13:factor(ind2)20  2.200916e-02
# factor(occ2)14:factor(ind2)20 -3.058376e-02
# factor(occ2)15:factor(ind2)20  6.447384e-01
# factor(occ2)16:factor(ind2)20 -1.981003e-01
# factor(occ2)17:factor(ind2)20  8.502014e-02
# factor(occ2)18:factor(ind2)20  .
# factor(occ2)19:factor(ind2)20  .
# factor(occ2)20:factor(ind2)20  .
# factor(occ2)21:factor(ind2)20 -8.585539e-02
# factor(occ2)22:factor(ind2)20 -4.626054e-03
# factor(occ2)2:factor(ind2)21  -1.090221e-02
# factor(occ2)3:factor(ind2)21   .
# factor(occ2)4:factor(ind2)21   5.606312e-01
# factor(occ2)5:factor(ind2)21   7.690620e-02
# factor(occ2)6:factor(ind2)21  -1.023891e-01
# factor(occ2)7:factor(ind2)21  -2.157767e-02
# factor(occ2)8:factor(ind2)21   .
# factor(occ2)9:factor(ind2)21   .
# factor(occ2)10:factor(ind2)21  .
# factor(occ2)11:factor(ind2)21  .
# factor(occ2)12:factor(ind2)21  .
# factor(occ2)13:factor(ind2)21 -3.635169e-01
# factor(occ2)14:factor(ind2)21 -1.442889e-01
# factor(occ2)15:factor(ind2)21  .
# factor(occ2)16:factor(ind2)21  .
# factor(occ2)17:factor(ind2)21  .
# factor(occ2)18:factor(ind2)21  .
# factor(occ2)19:factor(ind2)21  .
# factor(occ2)20:factor(ind2)21  5.736277e-02
# factor(occ2)21:factor(ind2)21  2.922235e-03
# factor(occ2)22:factor(ind2)21 -3.608037e-02
# factor(occ2)2:factor(ind2)22   .
# factor(occ2)3:factor(ind2)22   .
# factor(occ2)4:factor(ind2)22  -1.482539e-01
# factor(occ2)5:factor(ind2)22   1.252770e-01
# factor(occ2)6:factor(ind2)22  -7.891099e-02
# factor(occ2)7:factor(ind2)22   2.050356e-01
# factor(occ2)8:factor(ind2)22   .
# factor(occ2)9:factor(ind2)22  -3.563148e-01
# factor(occ2)10:factor(ind2)22 -5.773776e-01
# factor(occ2)11:factor(ind2)22  .
# factor(occ2)12:factor(ind2)22  .
# factor(occ2)13:factor(ind2)22  .
# factor(occ2)14:factor(ind2)22  .
# factor(occ2)15:factor(ind2)22 -1.161951e+00
# factor(occ2)16:factor(ind2)22 -2.548958e-01
# factor(occ2)17:factor(ind2)22 -3.650671e-03
# factor(occ2)18:factor(ind2)22  .
# factor(occ2)19:factor(ind2)22  .
# factor(occ2)20:factor(ind2)22  .
# factor(occ2)21:factor(ind2)22  1.409739e-01
# factor(occ2)22:factor(ind2)22  1.880052e-01

# %% [markdown]
# 10. Now we use HDM for R (hdm) to estimate the model using the theoretically optimal penalty parameter.

# %%
install.packages("hdm")
library(hdm)

model_rlasso <- rlasso(X_flexible_train, y_train)
# Out:
# Installing package into 'C:/Users/User/AppData/Local/R/win-library/4.3'
# (as 'lib' is unspecified)
# package 'hdm' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\User\AppData\Local\Temp\RtmpQPC3XQ\downloaded_packages
# Warning message:
# "package 'hdm' was built under R version 4.3.3"

# %% [markdown]
# As you may notice, the optimal penalty parameter resulting from this procedure is not comparable in size to the cross validation result. This is due to the fact that this penalty is the theoretically optimal parameter for the Lasso estimator under data-driven penalty loadings. That is:
#
# \begin{equation*}
#
# \hat{\beta} = \arg \ \underset{\beta}{\min} \sum_{i=1}^n (y_i - x_{i}^{\prime}\beta)^2 + \frac{\lambda}{n} \lVert \hat{\Psi}\beta \rVert_1
#
# \end{equation*}
#
# Where $\hat{\Psi} = diag(\hat{\psi_1},\hat{\psi_2},\dots,\hat{\psi_p})$ are the data-driven penalty loadings chosen to be a function of the data depending on the setting. For more detail, you can check the [package documentation](https://arxiv.org/pdf/1608.00354)

# %%
rlambda = model_rlasso$lambda0
rlambda
# Out:
# [1] 616.2187

# %% [markdown]
# 11. The predictive capability of each model (OLS, Lasso and RLasso) is reported via $MSE$ and $R^2$ out of sample

# %%
y_predict_ols <- predict(model_ls, data.frame(X_flexible_test))

MSE_ols <- mean((y_test - y_predict_ols)^2)

R2_test_ols <- 1 - MSE_ols / var(y_test)

print(R2_test_ols)
# Out:
# Warning message in predict.lm(model_ls, data.frame(X_flexible_test)):
# "prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases"
# [1] 0.08568767

# %%
# Lasso CV

y_predict_lasso <- predict_model(model_lasso, X_flexible_test)
MSE_lasso <- mean((y_test - y_predict_lasso)^2)
R2_test_lasso <- 1 - MSE_lasso / var(y_test)

print(R2_test_lasso)
# Out:
# [1] 0.2807233

# %%
# Rigurous Lasso

y_predict_rlasso <- predict(model_rlasso, newdata = X_flexible_test)
MSE_rlasso <- mean((y_test - y_predict_rlasso)^2)
R2_test_rlasso <- 1 - MSE_rlasso / var(y_test)

print(R2_test_rlasso)
# Out:
# [1] 0.3111814
