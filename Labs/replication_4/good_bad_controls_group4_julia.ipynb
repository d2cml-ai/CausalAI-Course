# %% [markdown]
# # Good and Bad Controls
# ## Integrants:
# * Rick Chuquilin
# * Luciana Álvarez
# * Kenia Moscoso

# %% [markdown]
# ## MODEL 1, 2 AND 3

# %%
using Pkg
Pkg.add("SpecialFunctions")
Pkg.add("HTTP")
Pkg.add("CSV")
Pkg.add("DataFrames")
# Out:
#     Updating registry at `C:\Users\User\.julia\registries\General.toml`
#    Resolving package versions...
#    Installed IrrationalConstants ─ v0.1.1
#    Installed InverseFunctions ──── v0.1.4
#    Installed OpenSpecFun_jll ───── v0.5.5+0
#    Installed DocStringExtensions ─ v0.8.6
#    Installed ChangesOfVariables ── v0.1.3
#    Installed LogExpFunctions ───── v0.3.15
#    Installed Compat ────────────── v3.43.0
#    Installed SpecialFunctions ──── v2.1.4
#    Installed ChainRulesCore ────── v1.14.0
#     Updating `C:\Users\User\.julia\environments\v1.7\Project.toml`
#   [276daf66] + SpecialFunctions v2.1.4
#     Updating `C:\Users\User\.julia\environments\v1.7\Manifest.toml`
#   [d360d2e6] + ChainRulesCore v1.14.0
#   [9e997f8a] + ChangesOfVariables v0.1.3
#   [34da2185] + Compat v3.43.0
#   [ffbed154] + DocStringExtensions v0.8.6
#   [3587e190] + InverseFunctions v0.1.4
#   [92d709cd] + IrrationalConstants v0.1.1
#   [2ab3a3ac] + LogExpFunctions v0.3.15
# ...

# %%
using SpecialFunctions
using HTTP, CSV, DataFrames

# %%
# Generate some sample data to use with the PC algorithm

N = 1000 # number of data points

# define simple linear model with added noise
Z = randn(N)
X = 2*Z + randn(N)*0.25
Y = X + 0.1*Z + randn(N)*0.25
df = DataFrame(x =[X[:,1],Y[:,1],Z[:,1]])
# Out:
# 3×1 DataFrame
#  Row │ x
#      │ Array…
# ─────┼───────────────────────────────────
#    1 │ [-2.23216, 3.93191, -1.58409, 0.…
#    2 │ [-2.59243, 4.25417, -1.33716, 0.…
#    3 │ [-0.905021, 1.7751, -0.829343, 0…

# %%
Pkg.status("Graphs")
Pkg.add(name="Graphs", version="0.10.0")
# Out:
#       Status `C:\Users\Kenia\.julia\environments\v1.7\Project.toml`
#   [86223c79] Graphs v1.6.0
#    Resolving package versions...
#    Installed MetaGraphs ───────────── v0.6.8
#    Installed StatsFuns ────────────── v0.9.7
#    Installed OffsetArrays ─────────── v1.11.0
#    Installed Polynomials ──────────── v1.2.1
#    Installed DSP ──────────────────── v0.6.10
#    Installed DataFrames ───────────── v0.21.8
#    Installed StructuralCausalModels ─ v1.0.8
#    Installed SpecialFunctions ─────── v1.8.4
#    Installed Compat ───────────────── v2.2.1
#    Installed Lasso ────────────────── v0.6.1
#    Installed CausalInference ──────── v0.7.0
#    Installed Intervals ────────────── v1.5.0
#    Installed TikzGraphs ───────────── v1.2.0
#    Installed StructTypes ──────────── v1.8.1
#    Installed Graphs ───────────────── v0.10.0
#    Installed Parsers ──────────────── v1.1.2
#    Installed CategoricalArrays ────── v0.8.3
#    Installed PooledArrays ─────────── v0.5.3
# ...

# %%
Pkg.add("Graphs")
# Out:
#    Resolving package versions...
#    Installed Inflate ─────── v0.1.2
#    Installed SimpleTraits ── v0.9.4
#    Installed MacroTools ──── v0.5.9
#    Installed ArnoldiMethod ─ v0.2.0
#    Installed StaticArrays ── v1.4.4
#    Installed Graphs ──────── v1.6.0
#     Updating `C:\Users\User\.julia\environments\v1.7\Project.toml`
#   [86223c79] + Graphs v1.6.0
#     Updating `C:\Users\User\.julia\environments\v1.7\Manifest.toml`
#   [ec485272] + ArnoldiMethod v0.2.0
#   [86223c79] + Graphs v1.6.0
#   [d25df0c9] + Inflate v0.1.2
#   [1914dd2f] + MacroTools v0.5.9
#   [699a6c99] + SimpleTraits v0.9.4
#   [90137ffa] + StaticArrays v1.4.4
# Precompiling project...
#   ✓ Inflate
#   ✓ MacroTools
#   ✓ SimpleTraits
#   ✓ StaticArrays
#   ✓ ArnoldiMethod
#   ✓ Graphs
#   6 dependencies successfully precompiled in 20 seconds (54 already precompiled)

# %%
Pkg.add("Combinatorics")
# Out:
#    Resolving package versions...
#    Installed Combinatorics ─ v1.0.2
#     Updating `C:\Users\User\.julia\environments\v1.7\Project.toml`
#   [861a8166] + Combinatorics v1.0.2
#     Updating `C:\Users\User\.julia\environments\v1.7\Manifest.toml`
#   [861a8166] + Combinatorics v1.0.2
# Precompiling project...
#   ✓ Combinatorics
#   1 dependency successfully precompiled in 1 seconds (60 already precompiled)

# %%
Pkg.add("NearestNeighbors")
# Out:
#    Resolving package versions...
#    Installed StatsAPI ───────── v1.3.0
#    Installed Distances ──────── v0.10.7
#    Installed NearestNeighbors ─ v0.4.10
#     Updating `C:\Users\User\.julia\environments\v1.7\Project.toml`
#   [b8a86587] + NearestNeighbors v0.4.10
#     Updating `C:\Users\User\.julia\environments\v1.7\Manifest.toml`
#   [b4f34e82] + Distances v0.10.7
#   [b8a86587] + NearestNeighbors v0.4.10
#   [82ae8749] + StatsAPI v1.3.0
# Precompiling project...
#   ✓ StatsAPI
#   ✓ Distances
#   ✓ NearestNeighbors
#   3 dependencies successfully precompiled in 3 seconds (61 already precompiled)

# %%
Pkg.add("Distances")
# Out:
#    Resolving package versions...
#     Updating `C:\Users\User\.julia\environments\v1.7\Project.toml`
#   [b4f34e82] + Distances v0.10.7
#   No Changes to `C:\Users\User\.julia\environments\v1.7\Manifest.toml`

# %%
Pkg.add("Distributions")
# Out:
#    Resolving package versions...
#    Installed DualNumbers ───────────── v0.6.8
#    Installed Calculus ──────────────── v0.5.1
#    Installed NaNMath ───────────────── v1.0.0
#    Installed Rmath ─────────────────── v0.7.0
#    Installed PDMats ────────────────── v0.11.10
#    Installed HypergeometricFunctions ─ v0.3.8
#    Installed FillArrays ────────────── v0.13.2
#    Installed StatsFuns ─────────────── v1.0.0
#    Installed QuadGK ────────────────── v2.4.2
#    Installed Rmath_jll ─────────────── v0.3.0+0
#    Installed DensityInterface ──────── v0.4.0
#    Installed StatsBase ─────────────── v0.33.16
#    Installed Distributions ─────────── v0.25.58
#     Updating `C:\Users\User\.julia\environments\v1.7\Project.toml`
#   [31c24e10] + Distributions v0.25.58
#     Updating `C:\Users\User\.julia\environments\v1.7\Manifest.toml`
#   [49dc2e85] + Calculus v0.5.1
#   [b429d917] + DensityInterface v0.4.0
#   [31c24e10] + Distributions v0.25.58
#   [fa6b7ba4] + DualNumbers v0.6.8
# ...

# %%
Pkg.add("Tables")
# Out:
#    Resolving package versions...
#     Updating `C:\Users\User\.julia\environments\v1.7\Project.toml`
#   [bd369af6] + Tables v1.7.0
#   No Changes to `C:\Users\User\.julia\environments\v1.7\Manifest.toml`

# %%
Pkg.add("TikzGraphs")
# Out:
#    Resolving package versions...
#    Installed XML2_jll ────────────────── v2.9.12+0
#    Installed JpegTurbo_jll ───────────── v2.1.2+0
#    Installed TikzPictures ────────────── v3.4.2
#    Installed Gettext_jll ─────────────── v0.21.0+0
#    Installed Xorg_libXext_jll ────────── v1.3.4+4
#    Installed LERC_jll ────────────────── v3.0.0+1
#    Installed Pixman_jll ──────────────── v0.40.1+0
#    Installed Libmount_jll ────────────── v2.35.0+0
#    Installed Zstd_jll ────────────────── v1.5.2+0
#    Installed Xorg_xtrans_jll ─────────── v1.4.0+3
#    Installed OpenJpeg_jll ────────────── v2.4.0+0
#    Installed Poppler_jll ─────────────── v0.87.0+2
#    Installed Libgcrypt_jll ───────────── v1.8.7+0
#    Installed Expat_jll ───────────────── v2.4.8+0
#    Installed Bzip2_jll ───────────────── v1.0.8+0
#    Installed Libtiff_jll ─────────────── v4.3.0+1
#    Installed PCRE_jll ────────────────── v8.44.0+0
#    Installed Libiconv_jll ────────────── v1.16.1+1
# ...

# %%
Pkg.add("MetaGraphs")
# Out:
#    Resolving package versions...
#    Installed MetaGraphs ─ v0.7.1
#    Installed JLD2 ─────── v0.4.22
#    Installed FileIO ───── v1.14.0
#     Updating `C:\Users\User\.julia\environments\v1.7\Project.toml`
#   [626554b9] + MetaGraphs v0.7.1
#     Updating `C:\Users\User\.julia\environments\v1.7\Manifest.toml`
#   [5789e2e9] + FileIO v1.14.0
#   [033835bb] + JLD2 v0.4.22
#   [626554b9] + MetaGraphs v0.7.1
# Precompiling project...
#   ✓ FileIO
#   ✓ JLD2
#   ✓ MetaGraphs
#   3 dependencies successfully precompiled in 20 seconds (116 already precompiled)

# %%
include("CausalInference.jl/CausalInference.jl-master/src/CausalInference.jl")
# Out:
# WARNING: replacing module CausalInference.
# Main.CausalInference

# %%
include("CausalInference.jl/CausalInference.jl-master/src/skeleton.jl")
# Out:
# falsetest (generic function with 1 method)

# %%
include("CausalInference.jl/CausalInference.jl-master/src/pc.jl")
# Out:
# plot_pc_graph

# %%
est_g = pcalg(df, 0.01, gausscitest)
# Out:
# {1, 0} directed simple Int64 graph

# %%
df = Dict("X" => df[1,:], "Y" => df[2,:] , "Z" => df[3,:])
# Out:
# Dict{String, DataFrameRow{DataFrame, DataFrames.Index}} with 3 entries:
#   "Y" => DataFrameRow…
#   "Z" => DataFrameRow…
#   "X" => DataFrameRow…

# %%
tp = plot_pc_graph(est_g, [String(k) for k in keys(df)])
# Out:
# TikzPictures.TikzPicture("\\graph [layered layout, ] {\n1/\"1\" [draw, rounded corners, fill=blue!10],\n;\n};\n", "scale=2", "\\usepackage{fontspec}\n\\setmainfont{Latin Modern Math}\n\\usetikzlibrary{arrows}\n\\usetikzlibrary{graphs}\n\\usetikzlibrary{graphdrawing}\n\n% from: https://tex.stackexchange.com/questions/453132/fresh-install-of-tl2018-no-tikz-graph-drawing-libraries-found\n\\usepackage{luacode}\n\\begin{luacode*}\n\tfunction pgf_lookup_and_require(name)\n\tlocal sep = package.config:sub(1,1)\n\tlocal function lookup(name)\n\tlocal sub = name:gsub('%.',sep)  \n\tif kpse.find_file(sub, 'lua') then\n\trequire(name)\n\telseif kpse.find_file(sub, 'clua') then\n\tcollectgarbage('stop') \n\trequire(name)\n\tcollectgarbage('restart')\n\telse\n\treturn false\n\tend\n\treturn true\n\tend\n\treturn\n\tlookup('pgf.gd.' .. name .. '.library') or\n\tlookup('pgf.gd.' .. name) or\n\tlookup(name .. '.library') or\n\tlookup(name) \n\tend\n\\end{luacode*}\n\n\\usegdlibrary{layered}", "tikzp
# ...

# %% [markdown]
# ## MODEL 4, 5 AND 6

# %%
# Generate some sample data to use with the PC algorithm

N = 1000 # number of data points

# define simple linear model with added noise
Z = randn(N)
X = 2*Z+randn(N)*0.7
M = 2*X + 0.5*Z + randn(N)*0.25
Y = 0.1*M + randn(N)*0.25
df = DataFrame(x =[Z[:,1],X[:,1],M[:,1],Y[:,1]])
# Out:
# 4×1 DataFrame
#  Row │ x
#      │ Array…
# ─────┼───────────────────────────────────
#    1 │ [0.79621, 0.418867, 1.38906, 0.5…
#    2 │ [1.5746, 1.05631, 3.58819, -0.12…
#    3 │ [3.6978, 2.10657, 7.63179, -0.06…
#    4 │ [0.716544, 0.134146, 0.265473, 0…

# %%
est_g = pcalg(df, 0.01, gausscitest)
# Out:
# {1, 0} directed simple Int64 graph

# %%
df = Dict("Z" => df[1,:], "X" => df[2,:] , "M" => df[3,:], "Y" => df[4,:])
# Out:
# Dict{String, DataFrameRow{DataFrame, DataFrames.Index}} with 4 entries:
#   "Z" => DataFrameRow…
#   "Y" => DataFrameRow…
#   "X" => DataFrameRow…
#   "M" => DataFrameRow…

# %%
tp = plot_pc_graph(est_g, [String(k) for k in keys(df)])
# Out:
# TikzPictures.TikzPicture("\\graph [layered layout, ] {\n1/\"1\" [draw, rounded corners, fill=blue!10],\n;\n};\n", "scale=2", "\\usepackage{fontspec}\n\\setmainfont{Latin Modern Math}\n\\usetikzlibrary{arrows}\n\\usetikzlibrary{graphs}\n\\usetikzlibrary{graphdrawing}\n\n% from: https://tex.stackexchange.com/questions/453132/fresh-install-of-tl2018-no-tikz-graph-drawing-libraries-found\n\\usepackage{luacode}\n\\begin{luacode*}\n\tfunction pgf_lookup_and_require(name)\n\tlocal sep = package.config:sub(1,1)\n\tlocal function lookup(name)\n\tlocal sub = name:gsub('%.',sep)  \n\tif kpse.find_file(sub, 'lua') then\n\trequire(name)\n\telseif kpse.find_file(sub, 'clua') then\n\tcollectgarbage('stop') \n\trequire(name)\n\tcollectgarbage('restart')\n\telse\n\treturn false\n\tend\n\treturn true\n\tend\n\treturn\n\tlookup('pgf.gd.' .. name .. '.library') or\n\tlookup('pgf.gd.' .. name) or\n\tlookup(name .. '.library') or\n\tlookup(name) \n\tend\n\\end{luacode*}\n\n\\usegdlibrary{layered}", "tikzp
# ...

# %% [markdown]
# ## MODEL 7

# %%
# Generate some sample data to use with the PC algorithm

N = 1000 # number of data points

# define simple linear model with added noise
U_1 = randn(N)
U_2 = randn(N)*0.7
Z = 2*U_1 + U_2 + randn(N)*0.25
X = 0.1*U_1 + randn(N)*0.25
Y = X + 3*U_2 + randn(N)*0.25
df = DataFrame(x =[X[:,1],Y[:,1],Z[:,1],U_1[:,1],U_2[:,1]])
# Out:
# 5×1 DataFrame
#  Row │ x
#      │ Array…
# ─────┼───────────────────────────────────
#    1 │ [0.413294, 0.16959, -0.0328452, …
#    2 │ [-0.323145, 1.98943, -0.63264, -…
#    3 │ [-1.20226, 3.82863, -0.472962, -…
#    4 │ [-0.637124, 1.55334, -0.45223, 0…
#    5 │ [-0.284, 0.516594, -0.0843657, -…

# %%
        est_g = pcalg(df, 0.01, gausscitest)
# Out:
# {1, 0} directed simple Int64 graph

# %%
df = Dict("X" => df[1,:], "Y" => df[2,:] , "Z" => df[3,:], "U_1" => df[4,:] , "U_2" => df[5,:])
# Out:
# Dict{String, DataFrameRow{DataFrame, DataFrames.Index}} with 5 entries:
#   "Y"   => DataFrameRow…
#   "Z"   => DataFrameRow…
#   "X"   => DataFrameRow…
#   "U_1" => DataFrameRow…
#   "U_2" => DataFrameRow…

# %%
tp = plot_pc_graph(est_g, [String(k) for k in keys(df)])
# Out:
# TikzPictures.TikzPicture("\\graph [layered layout, ] {\n1/\"1\" [draw, rounded corners, fill=blue!10],\n;\n};\n", "scale=2", "\\usepackage{fontspec}\n\\setmainfont{Latin Modern Math}\n\\usetikzlibrary{arrows}\n\\usetikzlibrary{graphs}\n\\usetikzlibrary{graphdrawing}\n\n% from: https://tex.stackexchange.com/questions/453132/fresh-install-of-tl2018-no-tikz-graph-drawing-libraries-found\n\\usepackage{luacode}\n\\begin{luacode*}\n\tfunction pgf_lookup_and_require(name)\n\tlocal sep = package.config:sub(1,1)\n\tlocal function lookup(name)\n\tlocal sub = name:gsub('%.',sep)  \n\tif kpse.find_file(sub, 'lua') then\n\trequire(name)\n\telseif kpse.find_file(sub, 'clua') then\n\tcollectgarbage('stop') \n\trequire(name)\n\tcollectgarbage('restart')\n\telse\n\treturn false\n\tend\n\treturn true\n\tend\n\treturn\n\tlookup('pgf.gd.' .. name .. '.library') or\n\tlookup('pgf.gd.' .. name) or\n\tlookup(name .. '.library') or\n\tlookup(name) \n\tend\n\\end{luacode*}\n\n\\usegdlibrary{layered}", "tikzp
# ...

# %% [markdown]
# ## MODEL 8

# %%
# Generate some sample data to use with the PC algorithm

N = 1000 # number of data points

# define simple linear model with added noise
Z = randn(N)
X = randn(N)*0.7
Y = 2*X + Z + randn(N)*0.25
df = DataFrame(x =[Z[:,1],X[:,1],Y[:,1]])
# Out:
# 3×1 DataFrame
#  Row │ x
#      │ Array…
# ─────┼───────────────────────────────────
#    1 │ [1.51224, 0.950849, -0.935994, 0…
#    2 │ [0.467902, 0.652082, -0.398417, …
#    3 │ [2.35702, 2.18087, -1.54804, -1.…

# %%
 est_g = pcalg(df, 0.01, gausscitest)
# Out:
# {1, 0} directed simple Int64 graph

# %%
df = Dict("Z" => df[1,:], "X" => df[2,:] , "Y" => df[3,:])
# Out:
# Dict{String, DataFrameRow{DataFrame, DataFrames.Index}} with 3 entries:
#   "Z" => DataFrameRow…
#   "Y" => DataFrameRow…
#   "X" => DataFrameRow…

# %%
tp = plot_pc_graph(est_g, [String(k) for k in keys(df)])
# Out:
# TikzPictures.TikzPicture("\\graph [layered layout, ] {\n1/\"1\" [draw, rounded corners, fill=blue!10],\n;\n};\n", "scale=2", "\\usepackage{fontspec}\n\\setmainfont{Latin Modern Math}\n\\usetikzlibrary{arrows}\n\\usetikzlibrary{graphs}\n\\usetikzlibrary{graphdrawing}\n\n% from: https://tex.stackexchange.com/questions/453132/fresh-install-of-tl2018-no-tikz-graph-drawing-libraries-found\n\\usepackage{luacode}\n\\begin{luacode*}\n\tfunction pgf_lookup_and_require(name)\n\tlocal sep = package.config:sub(1,1)\n\tlocal function lookup(name)\n\tlocal sub = name:gsub('%.',sep)  \n\tif kpse.find_file(sub, 'lua') then\n\trequire(name)\n\telseif kpse.find_file(sub, 'clua') then\n\tcollectgarbage('stop') \n\trequire(name)\n\tcollectgarbage('restart')\n\telse\n\treturn false\n\tend\n\treturn true\n\tend\n\treturn\n\tlookup('pgf.gd.' .. name .. '.library') or\n\tlookup('pgf.gd.' .. name) or\n\tlookup(name .. '.library') or\n\tlookup(name) \n\tend\n\\end{luacode*}\n\n\\usegdlibrary{layered}", "tikzp
# ...

# %% [markdown]
# ## MODEL 9

# %%
# Generate some sample data to use with the PC algorithm

N = 1000 # number of data points

# define simple linear model with added noise
Z = randn(N)
X = Z + randn(N)*0.7
Y = 2.7*X + randn(N)*0.25
df = DataFrame(x =[Z[:,1],X[:,1],Y[:,1]])
# Out:
# 3×1 DataFrame
#  Row │ x
#      │ Array…
# ─────┼───────────────────────────────────
#    1 │ [0.397113, -1.12431, 0.740192, -…
#    2 │ [-1.5098, -1.79109, 0.233677, -0…
#    3 │ [-4.46592, -5.07261, 0.89944, -1…

# %%
est_g = pcalg(df, 0.01, gausscitest)
# Out:
# {1, 0} directed simple Int64 graph

# %%
df = Dict("Z" => df[1,:], "X" => df[2,:] , "Y" => df[3,:])
# Out:
# Dict{String, DataFrameRow{DataFrame, DataFrames.Index}} with 3 entries:
#   "Z" => DataFrameRow…
#   "Y" => DataFrameRow…
#   "X" => DataFrameRow…

# %%
tp = plot_pc_graph(est_g, [String(k) for k in keys(df)])
# Out:
# TikzPictures.TikzPicture("\\graph [layered layout, ] {\n1/\"1\" [draw, rounded corners, fill=blue!10],\n;\n};\n", "scale=2", "\\usepackage{fontspec}\n\\setmainfont{Latin Modern Math}\n\\usetikzlibrary{arrows}\n\\usetikzlibrary{graphs}\n\\usetikzlibrary{graphdrawing}\n\n% from: https://tex.stackexchange.com/questions/453132/fresh-install-of-tl2018-no-tikz-graph-drawing-libraries-found\n\\usepackage{luacode}\n\\begin{luacode*}\n\tfunction pgf_lookup_and_require(name)\n\tlocal sep = package.config:sub(1,1)\n\tlocal function lookup(name)\n\tlocal sub = name:gsub('%.',sep)  \n\tif kpse.find_file(sub, 'lua') then\n\trequire(name)\n\telseif kpse.find_file(sub, 'clua') then\n\tcollectgarbage('stop') \n\trequire(name)\n\tcollectgarbage('restart')\n\telse\n\treturn false\n\tend\n\treturn true\n\tend\n\treturn\n\tlookup('pgf.gd.' .. name .. '.library') or\n\tlookup('pgf.gd.' .. name) or\n\tlookup(name .. '.library') or\n\tlookup(name) \n\tend\n\\end{luacode*}\n\n\\usegdlibrary{layered}", "tikzp
# ...

# %% [markdown]
# ## MODEL 10

# %%
# Generate some sample data to use with the PC algorithm

N = 1000 # number of data points

# define simple linear model with added noise
Z = randn(N)
U = 0.3*randn(N)
X = 0.9*U + Z + randn(N)*0.7
Y = 0.6*U + 2.7*X + randn(N)*0.25
df = DataFrame(x =[Z[:,1],U[:,1],X[:,1],Y[:,1]])
# Out:
# 4×1 DataFrame
#  Row │ x
#      │ Array…
# ─────┼───────────────────────────────────
#    1 │ [1.17315, -1.4667, -1.0767, -1.9…
#    2 │ [0.638152, -0.101347, 0.042243, …
#    3 │ [1.78129, -2.29402, -0.372647, -…
#    4 │ [5.30647, -6.35301, -0.87626, -4…

# %%
est_g = pcalg(df, 0.01, gausscitest)
# Out:
# {1, 0} directed simple Int64 graph

# %%
df = Dict("Z" => df[1,:], "U" => df[2,:] , "X" => df[3,:], "Y" => df[4,:])
# Out:
# Dict{String, DataFrameRow{DataFrame, DataFrames.Index}} with 4 entries:
#   "Z" => DataFrameRow…
#   "Y" => DataFrameRow…
#   "U" => DataFrameRow…
#   "X" => DataFrameRow…

# %%
tp = plot_pc_graph(est_g, [String(k) for k in keys(df)])
# Out:
# TikzPictures.TikzPicture("\\graph [layered layout, ] {\n1/\"1\" [draw, rounded corners, fill=blue!10],\n;\n};\n", "scale=2", "\\usepackage{fontspec}\n\\setmainfont{Latin Modern Math}\n\\usetikzlibrary{arrows}\n\\usetikzlibrary{graphs}\n\\usetikzlibrary{graphdrawing}\n\n% from: https://tex.stackexchange.com/questions/453132/fresh-install-of-tl2018-no-tikz-graph-drawing-libraries-found\n\\usepackage{luacode}\n\\begin{luacode*}\n\tfunction pgf_lookup_and_require(name)\n\tlocal sep = package.config:sub(1,1)\n\tlocal function lookup(name)\n\tlocal sub = name:gsub('%.',sep)  \n\tif kpse.find_file(sub, 'lua') then\n\trequire(name)\n\telseif kpse.find_file(sub, 'clua') then\n\tcollectgarbage('stop') \n\trequire(name)\n\tcollectgarbage('restart')\n\telse\n\treturn false\n\tend\n\treturn true\n\tend\n\treturn\n\tlookup('pgf.gd.' .. name .. '.library') or\n\tlookup('pgf.gd.' .. name) or\n\tlookup(name .. '.library') or\n\tlookup(name) \n\tend\n\\end{luacode*}\n\n\\usegdlibrary{layered}", "tikzp
# ...

# %% [markdown]
# ## MODEL 11 AND 12

# %%
# MODEL 11
# Generate some sample data to use with the PC algorithm

N = 1000 # number of data points

# define simple linear model with added noise
X = randn(N)
Z = X + 0.3*randn(N)
Y = 0.9*Z + randn(N)*0.7
df = DataFrame(x =[X[:,1],Z[:,1],Y[:,1]])
# Out:
# 3×1 DataFrame
#  Row │ x
#      │ Array…
# ─────┼───────────────────────────────────
#    1 │ [-0.609675, 0.606523, -1.40707, …
#    2 │ [-0.684036, 0.33488, -1.63712, 0…
#    3 │ [-0.751381, 0.311712, -2.76425, …

# %%
est_g = pcalg(df, 0.01, gausscitest)
# Out:
# {1, 0} directed simple Int64 graph

# %%
df = Dict("X" => df[1,:], "Z" => df[2,:] , "Y" => df[3,:])
# Out:
# Dict{String, DataFrameRow{DataFrame, DataFrames.Index}} with 3 entries:
#   "Z" => DataFrameRow…
#   "Y" => DataFrameRow…
#   "X" => DataFrameRow…

# %%
tp = plot_pc_graph(est_g, [String(k) for k in keys(df)])
# Out:
# TikzPictures.TikzPicture("\\graph [layered layout, ] {\n1/\"1\" [draw, rounded corners, fill=blue!10],\n;\n};\n", "scale=2", "\\usepackage{fontspec}\n\\setmainfont{Latin Modern Math}\n\\usetikzlibrary{arrows}\n\\usetikzlibrary{graphs}\n\\usetikzlibrary{graphdrawing}\n\n% from: https://tex.stackexchange.com/questions/453132/fresh-install-of-tl2018-no-tikz-graph-drawing-libraries-found\n\\usepackage{luacode}\n\\begin{luacode*}\n\tfunction pgf_lookup_and_require(name)\n\tlocal sep = package.config:sub(1,1)\n\tlocal function lookup(name)\n\tlocal sub = name:gsub('%.',sep)  \n\tif kpse.find_file(sub, 'lua') then\n\trequire(name)\n\telseif kpse.find_file(sub, 'clua') then\n\tcollectgarbage('stop') \n\trequire(name)\n\tcollectgarbage('restart')\n\telse\n\treturn false\n\tend\n\treturn true\n\tend\n\treturn\n\tlookup('pgf.gd.' .. name .. '.library') or\n\tlookup('pgf.gd.' .. name) or\n\tlookup(name .. '.library') or\n\tlookup(name) \n\tend\n\\end{luacode*}\n\n\\usegdlibrary{layered}", "tikzp
# ...

# %%
#model 12
# Generate some sample data to use with the PC algorithm

N = 1000 # number of data points

# define simple linear model with added noise
X = randn(N)
M = X + 0.3*randn(N)
Z = 0.3*Z + randn(N)*0.7
Y = 0.9*M + randn(N)*0.7
df = DataFrame(x =[X[:,1],M[:,1],Z[:,1],Y[:,1]])
# Out:
# 4×1 DataFrame
#  Row │ x
#      │ Array…
# ─────┼───────────────────────────────────
#    1 │ [-0.0680759, 0.015361, -1.59983,…
#    2 │ [-0.105218, 0.525752, -1.76295, …
#    3 │ [0.593789, -0.940658, 0.844199, …
#    4 │ [-0.526956, -0.927117, -0.734512…

# %%
est_g = pcalg(df, 0.01, gausscitest)
# Out:
# {1, 0} directed simple Int64 graph

# %%
df = Dict("X" => df[1,:], "M" => df[2,:] , "Z" => df[3,:], "Y" => df[4,:])
# Out:
# Dict{String, DataFrameRow{DataFrame, DataFrames.Index}} with 4 entries:
#   "Z" => DataFrameRow…
#   "Y" => DataFrameRow…
#   "X" => DataFrameRow…
#   "M" => DataFrameRow…

# %%
tp = plot_pc_graph(est_g, [String(k) for k in keys(df)])
# Out:
# TikzPictures.TikzPicture("\\graph [layered layout, ] {\n1/\"1\" [draw, rounded corners, fill=blue!10],\n;\n};\n", "scale=2", "\\usepackage{fontspec}\n\\setmainfont{Latin Modern Math}\n\\usetikzlibrary{arrows}\n\\usetikzlibrary{graphs}\n\\usetikzlibrary{graphdrawing}\n\n% from: https://tex.stackexchange.com/questions/453132/fresh-install-of-tl2018-no-tikz-graph-drawing-libraries-found\n\\usepackage{luacode}\n\\begin{luacode*}\n\tfunction pgf_lookup_and_require(name)\n\tlocal sep = package.config:sub(1,1)\n\tlocal function lookup(name)\n\tlocal sub = name:gsub('%.',sep)  \n\tif kpse.find_file(sub, 'lua') then\n\trequire(name)\n\telseif kpse.find_file(sub, 'clua') then\n\tcollectgarbage('stop') \n\trequire(name)\n\tcollectgarbage('restart')\n\telse\n\treturn false\n\tend\n\treturn true\n\tend\n\treturn\n\tlookup('pgf.gd.' .. name .. '.library') or\n\tlookup('pgf.gd.' .. name) or\n\tlookup(name .. '.library') or\n\tlookup(name) \n\tend\n\\end{luacode*}\n\n\\usegdlibrary{layered}", "tikzp
# ...

# %% [markdown]
# ## MODEL 13

# %%
#model 12
# Generate some sample data to use with the PC algorithm

N = 1000 # number of data points

# define simple linear model with added noise
X = randn(N)
M = 9.1*Z + X + 0.3*randn(N)
Z = randn(N)*0.7
Y = 0.9*M + randn(N)*0.7
df = DataFrame(x =[X[:,1],M[:,1],Z[:,1],Y[:,1]])
# Out:
# 4×1 DataFrame
#  Row │ x
#      │ Array…
# ─────┼───────────────────────────────────
#    1 │ [-0.298709, -0.196906, -0.182368…
#    2 │ [5.37785, -9.33303, 7.41324, -0.…
#    3 │ [0.588208, -0.327286, -0.538665,…
#    4 │ [4.92204, -8.24941, 5.66333, 0.2…

# %%
est_g = pcalg(df, 0.01, gausscitest)
# Out:
# {1, 0} directed simple Int64 graph

# %%
df = Dict("X" => df[1,:], "M" => df[2,:] , "Z" => df[3,:], "Y" => df[4,:])
# Out:
# Dict{String, DataFrameRow{DataFrame, DataFrames.Index}} with 4 entries:
#   "Z" => DataFrameRow…
#   "Y" => DataFrameRow…
#   "X" => DataFrameRow…
#   "M" => DataFrameRow…

# %%
tp = plot_pc_graph(est_g, [String(k) for k in keys(df)])
# Out:
# TikzPictures.TikzPicture("\\graph [layered layout, ] {\n1/\"1\" [draw, rounded corners, fill=blue!10],\n;\n};\n", "scale=2", "\\usepackage{fontspec}\n\\setmainfont{Latin Modern Math}\n\\usetikzlibrary{arrows}\n\\usetikzlibrary{graphs}\n\\usetikzlibrary{graphdrawing}\n\n% from: https://tex.stackexchange.com/questions/453132/fresh-install-of-tl2018-no-tikz-graph-drawing-libraries-found\n\\usepackage{luacode}\n\\begin{luacode*}\n\tfunction pgf_lookup_and_require(name)\n\tlocal sep = package.config:sub(1,1)\n\tlocal function lookup(name)\n\tlocal sub = name:gsub('%.',sep)  \n\tif kpse.find_file(sub, 'lua') then\n\trequire(name)\n\telseif kpse.find_file(sub, 'clua') then\n\tcollectgarbage('stop') \n\trequire(name)\n\tcollectgarbage('restart')\n\telse\n\treturn false\n\tend\n\treturn true\n\tend\n\treturn\n\tlookup('pgf.gd.' .. name .. '.library') or\n\tlookup('pgf.gd.' .. name) or\n\tlookup(name .. '.library') or\n\tlookup(name) \n\tend\n\\end{luacode*}\n\n\\usegdlibrary{layered}", "tikzp
# ...
