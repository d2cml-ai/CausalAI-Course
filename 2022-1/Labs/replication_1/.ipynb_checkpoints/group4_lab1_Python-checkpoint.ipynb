# %%
import pandas as pd
import numpy as np
import pyreadr as rr # package to use data form R format
import math

# %%
# !pip install pyreadr==0.4.2

# %%
data  = pd.read_csv(r'../../Github/ECO224/data/wage2015_subsample_inference.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5150 entries, 0 to 5149
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   rownames  5150 non-null   int64
#  1   wage      5150 non-null   float64
#  2   lwage     5150 non-null   float64
#  3   sex       5150 non-null   float64
#  4   shs       5150 non-null   float64
#  5   hsg       5150 non-null   float64
#  6   scl       5150 non-null   float64
#  7   clg       5150 non-null   float64
#  8   ad        5150 non-null   float64
#  9   mw        5150 non-null   float64
#  10  so        5150 non-null   float64
#  11  we        5150 non-null   float64
#  12  ne        5150 non-null   float64
#  13  exp1      5150 non-null   float64
#  14  exp2      5150 non-null   float64
#  15  exp3      5150 non-null   float64
#  16  exp4      5150 non-null   float64
#  17  occ       5150 non-null   float64
#  18  occ2      5150 non-null   int64
# ...

# %% [markdown]
# ***Variable description***
#
# - occ : occupational classification
# - ind : industry classification
# - lwage : log hourly wage
# - sex : gender (1 female) (0 male)
# - shs : some high school
# - hsg : High school graduated
# - scl : Some College
# - clg: College Graduate
# - ad: Advanced Degree
# - ne: Northeast
# - mw: Midwest
# - so: South
# - we: West
# - exp1: experience

# %%
# !pip install plotly==5.7.0
# Out:
# ...
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.6.0
#     Uninstalling plotly-5.6.0:
#       Successfully uninstalled plotly-5.6.0
# ...

# %%
import plotly.express as px

# %% [markdown]
# 1. ## Estimating the basic model: lwage and sex

# %%
formula_1 = 'lwage ~ sex'
formula_1

# %%
# Regression

basic_model = smf.ols(formula_1, data = data).fit()
basic_model.summary()

# %% [markdown]
# # 2. Estadística Descriptiva

# %% [markdown]
# ## Dummy variables

# %% [markdown]
# ### a. Sex

# %%
df = pd.DataFrame( data, columns = [ 'sex'])
df['sex'] = df['sex'].replace([0],'male')
df['sex'] = df['sex'].replace([1],'female')

fig = px.bar(df, x="sex",title="sex")
fig.show()
# Out:
# <div>                            <div id="bf7cf043-6ab5-41d6-80f8-f95ddd86478d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bf7cf043-6ab5-41d6-80f8-f95ddd86478d")) {                    Plotly.newPlot(                        "bf7cf043-6ab5-41d6-80f8-f95ddd86478d",                        [{"alignmentgroup":"True","hovertemplate":"sex=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["female","male","male","female","female","female","female","male","female","female","female","male","female","female","female","male","male","male","male","male","female","female","female","male","female","male","female","male
# ...

# %% [markdown]
# ### b. education by sex

# %%
df = pd.DataFrame( data, columns = [ 'sex','shs'])
df['sex'] = df['sex'].replace([0],'male')
df['sex'] = df['sex'].replace([1],'female')
df['shs'] = df['shs'].replace([0],'not some high school')
df['shs'] = df['shs'].replace([1],'some high school')

fig = px.bar(df, x="sex",color="shs",title="some high school by sex")
fig.show()
# Out:
# <div>                            <div id="f274d92f-4352-40b5-931b-adb47a7d7367" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f274d92f-4352-40b5-931b-adb47a7d7367")) {                    Plotly.newPlot(                        "f274d92f-4352-40b5-931b-adb47a7d7367",                        [{"alignmentgroup":"True","hovertemplate":"shs=not some high school<br>sex=%{x}<br>count=%{y}<extra></extra>","legendgroup":"not some high school","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"not some high school","offsetgroup":"not some high school","orientation":"v","showlegend":true,"textposition":"auto","x":["female","male","male","female","female","female","female","male","female","female","female","male","female","female","female","male","male
# ...

# %%
df = pd.DataFrame( data, columns = [ 'sex','hsg'])
df['sex'] = df['sex'].replace([0],'male')
df['sex'] = df['sex'].replace([1],'female')
df['hsg'] = df['hsg'].replace([0],'not high school graduate')
df['hsg'] = df['hsg'].replace([1],'high school graduate')

fig = px.bar(df, x="sex",color="hsg",title="high school graduate by sex")
fig.show()
# Out:
# <div>                            <div id="0a12154e-5d16-40b7-8e21-f3346ba49a3e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0a12154e-5d16-40b7-8e21-f3346ba49a3e")) {                    Plotly.newPlot(                        "0a12154e-5d16-40b7-8e21-f3346ba49a3e",                        [{"alignmentgroup":"True","hovertemplate":"hsg=not high school graduate<br>sex=%{x}<br>count=%{y}<extra></extra>","legendgroup":"not high school graduate","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"not high school graduate","offsetgroup":"not high school graduate","orientation":"v","showlegend":true,"textposition":"auto","x":["female","male","female","female","female","female","female","female","female","male","female","female","female","male","fe
# ...

# %%
df = pd.DataFrame( data, columns = [ 'sex','scl'])
df['sex'] = df['sex'].replace([0],'male')
df['sex'] = df['sex'].replace([1],'female')
df['scl'] = df['scl'].replace([0],'not some college')
df['scl'] = df['scl'].replace([1],'some college')

fig = px.bar(df, x="sex",color="scl",title="some college by sex")
fig.show()
# Out:
# <div>                            <div id="2c2b2ff8-f358-449f-8c79-14f6abcffda2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2c2b2ff8-f358-449f-8c79-14f6abcffda2")) {                    Plotly.newPlot(                        "2c2b2ff8-f358-449f-8c79-14f6abcffda2",                        [{"alignmentgroup":"True","hovertemplate":"scl=not some college<br>sex=%{x}<br>count=%{y}<extra></extra>","legendgroup":"not some college","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"not some college","offsetgroup":"not some college","orientation":"v","showlegend":true,"textposition":"auto","x":["female","male","male","female","female","female","female","male","female","female","female","male","female","male","male","male","male","female","male","m
# ...

# %%
df = pd.DataFrame( data, columns = [ 'sex','clg'])
df['sex'] = df['sex'].replace([0],'male')
df['sex'] = df['sex'].replace([1],'female')
df['clg'] = df['clg'].replace([0],'not college graduate')
df['clg'] = df['clg'].replace([1],'college graduate')

fig = px.bar(df, x="sex",color="clg",title="college graduate by sex")
fig.show()
# Out:
# <div>                            <div id="3f2f84ae-e5bd-4d66-86fc-baf2123f0dc1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3f2f84ae-e5bd-4d66-86fc-baf2123f0dc1")) {                    Plotly.newPlot(                        "3f2f84ae-e5bd-4d66-86fc-baf2123f0dc1",                        [{"alignmentgroup":"True","hovertemplate":"clg=college graduate<br>sex=%{x}<br>count=%{y}<extra></extra>","legendgroup":"college graduate","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"college graduate","offsetgroup":"college graduate","orientation":"v","showlegend":true,"textposition":"auto","x":["female","male","female","female","female","female","male","male","male","female","female","female","female","female","male","female","male","male","female
# ...

# %%
df = pd.DataFrame( data, columns = [ 'sex','ad'])
df['sex'] = df['sex'].replace([0],'male')
df['sex'] = df['sex'].replace([1],'female')
df['ad'] = df['ad'].replace([0],'not advanced degree')
df['ad'] = df['ad'].replace([1],'advanced degree')

fig = px.bar(df, x="sex",color="ad",title="advanced degree by sex")
fig.show()
# Out:
# <div>                            <div id="031b49f4-e262-42d0-b897-290ac2e86b95" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("031b49f4-e262-42d0-b897-290ac2e86b95")) {                    Plotly.newPlot(                        "031b49f4-e262-42d0-b897-290ac2e86b95",                        [{"alignmentgroup":"True","hovertemplate":"ad=not advanced degree<br>sex=%{x}<br>count=%{y}<extra></extra>","legendgroup":"not advanced degree","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"not advanced degree","offsetgroup":"not advanced degree","orientation":"v","showlegend":true,"textposition":"auto","x":["female","male","male","female","female","female","male","female","female","female","male","female","female","female","male","male","male","male
# ...

# %% [markdown]
# ## Continue Variables

# %% [markdown]
# ### A. Experience

# %%
df = pd.DataFrame( data, columns = [ 'sex','exp1','exp2','exp3','exp4'])
df['sex'] = df['sex'].replace([0],'male')
df['sex'] = df['sex'].replace([1],'female')

fig = px.histogram(df, x="exp1", color="sex", title = "Exp1 by sex")
fig.show()
# Out:
# <div>                            <div id="0ee45701-bcdc-42aa-b320-47231f1b3f89" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0ee45701-bcdc-42aa-b320-47231f1b3f89")) {                    Plotly.newPlot(                        "0ee45701-bcdc-42aa-b320-47231f1b3f89",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"sex=female<br>exp1=%{x}<br>count=%{y}<extra></extra>","legendgroup":"female","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"female","offsetgroup":"female","orientation":"v","showlegend":true,"x":[7.0,25.0,22.0,1.0,42.0,31.0,4.0,7.0,5.5,20.5,25.0,6.5,8.5,11.0,24.5,5.0,0.0,15.5,9.0,14.0,14.0,31.0,11.0,17.5,15.0,6.5,17.5,7.0,10.0,35.0,27.0,23.0,26.0,29.0,2.0,33.0,7.0,19.0,36.0,19.0,34.0,10.0,5.5,7
# ...

# %%
df = pd.DataFrame( data, columns = [ 'sex','exp1','exp2','exp3','exp4'])
df['sex'] = df['sex'].replace([0],'male')
df['sex'] = df['sex'].replace([1],'female')

fig = px.histogram(df, x="exp2", color="sex", title = "Exp2 by sex")
fig.show()
# Out:
# <div>                            <div id="d97e90e4-b8bb-40af-bc31-2717b3c15e14" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d97e90e4-b8bb-40af-bc31-2717b3c15e14")) {                    Plotly.newPlot(                        "d97e90e4-b8bb-40af-bc31-2717b3c15e14",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"sex=female<br>exp2=%{x}<br>count=%{y}<extra></extra>","legendgroup":"female","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"female","offsetgroup":"female","orientation":"v","showlegend":true,"x":[0.49,6.25,4.84,0.01,17.64,9.61,0.16,0.49,0.3025,4.2025,6.25,0.4225,0.7225,1.21,6.0025,0.25,0.0,2.4025,0.81,1.96,1.96,9.61,1.21,3.0625,2.25,0.4225,3.0625,0.49,1.0,12.25,7.29,5.29,6.76,8.41,0.04,10.89,0.
# ...

# %%
df = pd.DataFrame( data, columns = [ 'sex','exp1','exp2','exp3','exp4'])
df['sex'] = df['sex'].replace([0],'male')
df['sex'] = df['sex'].replace([1],'female')

fig = px.histogram(df, x="exp3", color="sex", title = "Exp3 by sex")
fig.show()
# Out:
# <div>                            <div id="b249e99e-5086-46cf-b70b-68479847cff1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b249e99e-5086-46cf-b70b-68479847cff1")) {                    Plotly.newPlot(                        "b249e99e-5086-46cf-b70b-68479847cff1",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"sex=female<br>exp3=%{x}<br>count=%{y}<extra></extra>","legendgroup":"female","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"female","offsetgroup":"female","orientation":"v","showlegend":true,"x":[0.343,15.625,10.648,0.001,74.088,29.791,0.064,0.343,0.166375,8.615125,15.625,0.274625,0.614125,1.331,14.706125,0.125,0.0,3.723875,0.729,2.744,2.744,29.791,1.331,5.359375,3.375,0.274625,5.359375,0.343,1
# ...

# %%
df = pd.DataFrame( data, columns = [ 'sex','exp1','exp2','exp3','exp4'])
df['sex'] = df['sex'].replace([0],'male')
df['sex'] = df['sex'].replace([1],'female')

fig = px.histogram(df, x="exp4", color="sex", title = "Exp4 by sex")
fig.show()
# Out:
# <div>                            <div id="f3973170-2b0a-41dd-bd81-b1f1f0178cc9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f3973170-2b0a-41dd-bd81-b1f1f0178cc9")) {                    Plotly.newPlot(                        "f3973170-2b0a-41dd-bd81-b1f1f0178cc9",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"sex=female<br>exp4=%{x}<br>count=%{y}<extra></extra>","legendgroup":"female","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"female","offsetgroup":"female","orientation":"v","showlegend":true,"x":[0.2401,39.0625,23.4256,0.0001,311.1696,92.3521,0.0256,0.2401,0.09150625,17.66100625,39.0625,0.17850625,0.52200625,1.4641,36.03000625,0.0625,0.0,5.77200625,0.6561,3.8416,3.8416,92.3521,1.4641,9.37890625
# ...

# %% [markdown]
# Make sense that until more closer to exp4 the histogram the count tend to be more small and the experience tend to be more large. It happens because exp4 is (experience)^4

# %% [markdown]
# ### B. wage and log wage

# %%
df = pd.DataFrame( data, columns = [ 'sex','wage'])
df['sex'] = df['sex'].replace([0],'male')
df['sex'] = df['sex'].replace([1],'female')

fig = px.histogram(df, x="wage", color="sex", title = "Wage by sex")
fig.show()
# Out:
# <div>                            <div id="efac5e63-762b-411e-99c0-c2ddb04b0b1e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("efac5e63-762b-411e-99c0-c2ddb04b0b1e")) {                    Plotly.newPlot(                        "efac5e63-762b-411e-99c0-c2ddb04b0b1e",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"sex=female<br>wage=%{x}<br>count=%{y}<extra></extra>","legendgroup":"female","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"female","offsetgroup":"female","orientation":"v","showlegend":true,"x":[9.615384615384617,13.942307692307692,28.846153846153847,11.73076923076923,19.23076923076923,12.0,19.23076923076923,17.307692307692307,12.01923076923077,13.461538461538462,16.346153846153847,10.68376068
# ...

# %%
df = pd.DataFrame( data, columns = [ 'sex','lwage'])
df['sex'] = df['sex'].replace([0],'male')
df['sex'] = df['sex'].replace([1],'female')

fig = px.histogram(df, x="lwage", color="sex", title = "LogWage by sex")
fig.show()
# Out:
# <div>                            <div id="6cbfba88-4b9b-487c-914d-cff72c10fdbb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6cbfba88-4b9b-487c-914d-cff72c10fdbb")) {                    Plotly.newPlot(                        "6cbfba88-4b9b-487c-914d-cff72c10fdbb",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"sex=female<br>lwage=%{x}<br>count=%{y}<extra></extra>","legendgroup":"female","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"female","offsetgroup":"female","orientation":"v","showlegend":true,"x":[2.2633643798407643,2.634927936273247,3.361976668508874,2.4622152385859297,2.9565115604007097,2.4849066497880004,2.9565115604007097,2.8511510447428834,2.486507931154974,2.5998366164619773,2.79399263090
# ...

# %% [markdown]
# ### C. Lwage - exp1

# %% [markdown]
# Here we do a scatter plot between lwage and exp 1. We chose lwage because their histogram is like a normal distribution, and the same for exp1.

# %%
df = pd.DataFrame( data, columns = [ 'exp1','lwage'])
fig = px.scatter(df, x="exp1", y="lwage", trendline="ols")
fig.show()
# Out:
# <div>                            <div id="7dc75c9b-f87f-4b02-8d1d-37339fa0d039" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7dc75c9b-f87f-4b02-8d1d-37339fa0d039")) {                    Plotly.newPlot(                        "7dc75c9b-f87f-4b02-8d1d-37339fa0d039",                        [{"hovertemplate":"exp1=%{x}<br>lwage=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[7.0,31.0,18.0,25.0,22.0,1.0,42.0,37.0,31.0,4.0,7.0,30.0,5.5,20.5,25.0,16.0,27.0,3.5,6.0,8.0,6.5,8.5,11.0,11.0,24.5,8.0,5.0,4.5,8.0,26.0,0.0,15.5,9.0,14.0,14.0,5.0,31.0,28.0,11.0,11.0,17.5,12.0,15.0,27.0,6.5,12.0,41.0,17.5,7.0,23.0,34.5,10.0,36.0,35.0,27.0,41.0,15.0,23.0,26.0,4.5,21.0,29.0,2.0,
# ...

# %% [markdown]
# how it shows, when the experience is elevated to 1, the relation between the log wage is positive. But according to the paper readed, it isn't normal because when the experience growth the lof wage slower down.

# %% [markdown]
# # 3. Replication graphic paper

# %%
a = data[["exp1","sex","lwage","exp2","exp3","exp4","scl","clg"]]
male = data[ data[ 'sex' ] == 0 ]
d_male = male[ [ "exp1","sex","lwage","exp2","exp3","exp4","scl","clg" ] ]
d_male.shape
# Out:
# (2861, 8)

# %%
pip install statsmodels
# Out:
# ...
#
# ...

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
y = 'lwage ~  (exp1+exp2+exp3+exp4)**4'
t_y = smf.ols( formula = y , data = d_male )
ty_predict = t_y.fit().predict()
ty_predict.tolist()
d_male['predict'] = ty_predict
d_male
# Out:
# C:\Users\Kenia\AppData\Local\Temp\ipykernel_8148\2040128647.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       exp1  sex     lwage   exp2    exp3      exp4  scl  clg   predict
# 1     31.0  0.0  3.872802   9.61  29.791   92.3521  0.0  1.0  3.089461
# 2     18.0  0.0  2.403126   3.24   5.832   10.4976  0.0  0.0  3.017210
# 7     37.0  0.0  2.956512  13.69  50.653  187.4161  0.0  0.0  3.005124
# 11    30.0  0.0  2.486508   9.00  27.000   81.0000  0.0  0.0  3.088679
# 15    16.0  0.0  3.328075   2.56   4.096    6.5536  0.0  0.0  3.005428
# ...    ...  ...       ...    ...     ...       ...  ...  ...       ...
# 5144  10.0  0.0  2.628007   1.00   1.000    1.0000  0.0  1.0  2.911508
# ...

# %%
d_male_scl = d_male[d_male['scl'] == 1]
d_male_clg = d_male[d_male['clg'] == 1]

# %%
scl = d_male_scl[['lwage','exp1','predict']].groupby(['exp1']).mean().reset_index()
scl['promed'] = 0
scl['promed_fit'] = 0
scl.shape
# Out:
# (79, 5)

# %%
clg = d_male_clg[['lwage','exp1','predict']].groupby(['exp1']).mean().reset_index()
clg['promed'] = 0
clg['promed_fit'] = 0
clg.shape
# Out:
# (39, 5)

# %%
for i in range(0,79):
    aaa = d_male_scl[d_male_scl['exp1'] <= scl['exp1'][i]]
    scl['promed'][i] = aaa['lwage'].mean()
    scl['promed_fit'][i] = aaa['predict'].mean()
print(scl['promed'],scl['promed_fit'])
# Out:
# 0     2.768348
# 1     2.777348
# 2     2.797620
# 3     2.740722
# 4     2.756538
#         ...
# 74    2.901841
# 75    2.902494
# 76    2.902773
# 77    2.903677
# 78    2.903377
# Name: promed, Length: 79, dtype: float64 0     3.011630
# 1     2.998413
# 2     2.991482
# 3     2.980008
# 4     2.973443
#         ...
# 74    2.976939
# 75    2.976840
# 76    2.976723
# 77    2.976520
# 78    2.976445
# Name: promed_fit, Length: 79, dtype: float64
# C:\Users\Kenia\AppData\Local\Temp\ipykernel_8148\4077359856.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Kenia\AppData\Local\Temp\ipykernel_8148\4077359856.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
for i in range(0,39):
    aaa = d_male_clg[d_male_clg['exp1'] <= clg['exp1'][i]]
    clg['promed'][i] = aaa['lwage'].mean()
    clg['promed_fit'][i] = aaa['predict'].mean()
print(clg['promed'],clg['promed_fit'])
# Out:
# 0     3.080935
# 1     3.092226
# 2     3.090095
# 3     3.098431
# 4     3.097260
# 5     3.102041
# 6     3.109478
# 7     3.117269
# 8     3.119050
# 9     3.126393
# 10    3.120493
# 11    3.122642
# 12    3.127007
# 13    3.134733
# 14    3.137351
# 15    3.141198
# 16    3.142983
# 17    3.148622
# 18    3.143766
# 19    3.144550
# 20    3.147494
# 21    3.149009
# 22    3.146669
# 23    3.148886
# 24    3.149272
# 25    3.155857
# 26    3.161876
# 27    3.162977
# 28    3.168807
# 29    3.170569
# 30    3.170831
# 31    3.172293
# 32    3.172321
# 33    3.172488
# 34    3.171342
# 35    3.173011
# 36    3.170632
# 37    3.166583
# 38    3.163974
# Name: promed, dtype: float64 0     3.129464
# 1     3.101192
# 2     3.071827
# 3     3.051438
# 4     3.034550
# 5     3.022511
# 6     3.012549
# 7     3.004547
# 8     2.997762
# 9     2.993155
# 10    2.990325
# 11    2.989366
# 12    2.988299
# 13    2.988093
# 14    2.988261
# 15    2.988553
# 16    2.988997
# 17    2.989543
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.rcParams["figure.figsize"] = (20,10)
plt.rcParams.update({'font.size': 15})
x = clg["exp1"]
y = clg['promed']
x_1 = scl['exp1']
y_1 = scl['promed']
x_2 = clg['exp1']
y_2 = clg['promed_fit']
x_3 = scl['exp1']
y_3 = scl['promed_fit']

plt.plot(x, y, label = "Collage Graduated - Actual", linestyle='-')    
plt.plot(x_1, y_1, label = "Some College Education - Actual", linestyle='-')
plt.plot(x_2, y_2, label = "Collage Graduated - Fitted", linestyle='dashed')
plt.plot(x_3, y_3, label = "Some College Education - Fitted", linestyle='dashed')

plt.xticks()
plt.legend()
plt.title("Wage for mens by college graduated and some college")
plt.xlabel("Years of Potencial Experience")
plt.ylabel("Log Wage(or Wage Gap)")
plt.show()
