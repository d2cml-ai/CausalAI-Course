# %%
pip install pyread
# Out:
# Note: you may need to restart the kernel to use updated packages.
# "C:\Users\Roberto" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.
