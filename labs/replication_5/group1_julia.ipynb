# %%
using Pkg

# %%
wget https://developer.nvidia.com/compute/cuda/9.0/Prod/local_installers/cuda-repo-ubuntu1604-9-0-local_9.0.176-1_amd64-deb
dpkg -i cuda-repo-ubuntu1604-9-0-local_9.0.176-1_amd64-deb
# !apt-key add /var/cuda-repo-9-0-local/7fa2af80.pub
# !apt update -q
# !apt install cuda gcc-6 g++-6 -y -q
# !ln -s /usr/bin/gcc-6 /usr/local/cuda/bin/gcc
# !ln -s /usr/bin/g++-6 /usr/local/cuda/bin/g++
# Out:
#   Cell In[3], line 1
#     wget https://developer.nvidia.com/compute/cuda/9.0/Prod/local_installers/cuda-repo-ubuntu1604-9-0-local_9.0.176-1_amd64-deb
#                                                                                                                      ^
# SyntaxError: invalid decimal literal

# %%
# !curl -sSL "https://julialang-s3.julialang.org/bin/linux/x64/1.7/julia-1.7.3-linux-x86_64.tar.gz" -o julia.tar.gz
# !tar -xzf julia.tar.gz -C /usr --strip-components 1
# !rm -rf julia.tar.gz*
# !julia -e 'using Pkg; pkg"add IJulia; precompile"'
# Out:
# UndefVarError: `curl` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[5]:1

# %%
using Pkg
Pkg.add("CSV"), using CSV
Pkg.add("DataFrames"), using DataFrames
Pkg.add("StatsModels"), using StatsModels
Pkg.add("GLM"), using GLM
Pkg.add("Random"), using Random
Pkg.add("MLDataUtils"), using MLDataUtils
Pkg.add("MLBase"), using MLBase
Pkg.add("FixedEffectModels"), using FixedEffectModels
Pkg.add("Lasso"), using Lasso
Pkg.add("MLJ"), using MLJ
Pkg.add("DecisionTree"), using DecisionTree
Pkg.add("RData"), using RData
Pkg.add("GLMNet"), using GLMNet
Pkg.add("PrettyTables"), using PrettyTables
# Out:
#     Updating registry at `C:\Users\Alvaro\.julia\registries\General.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\Alvaro\.julia\environments\v1.11\Project.toml`
#   No Changes to `C:\Users\Alvaro\.julia\environments\v1.11\Manifest.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\Alvaro\.julia\environments\v1.11\Project.toml`
#   No Changes to `C:\Users\Alvaro\.julia\environments\v1.11\Manifest.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\Alvaro\.julia\environments\v1.11\Project.toml`
#   No Changes to `C:\Users\Alvaro\.julia\environments\v1.11\Manifest.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\Alvaro\.julia\environments\v1.11\Project.toml`
#   No Changes to `C:\Users\Alvaro\.julia\environments\v1.11\Manifest.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\Alvaro\.julia\environments\v1.11\Project.toml`
#   No Changes to `C:\Users\Alvaro\.julia\environments\v1.11\Manifest.toml`
#    Resolving package versions...
#    Installed ZMQ ──────────────── v1.2.6
#    Installed ArrayInterface ───── v7.11.0
#    Installed NearestNeighbors ─── v0.4.17
#    Installed StaticArraysCore ─── v1.4.3
#    Installed Extents ──────────── v0.1.3
#    Installed StaticArrays ─────── v1.9.5
#    Installed StatsBase ────────── v0.33.21
#    Installed LearnBase ────────── v0.3.0
#    Installed MLDataPattern ────── v0.5.4
#    Installed MLLabelUtils ─────── v0.5.7
#    Installed IntervalArithmetic ─ v0.22.14
#    Installed MLDataUtils ──────── v0.5.4
#    Installed Polynomials ──────── v4.0.11
#     Updating `C:\Users\Alvaro\.julia\environments\v1.11\Project.toml`
#   [cc2ba9b6] + MLDataUtils v0.5.4
#     Updating `C:\Users\Alvaro\.julia\environments\v1.11\Manifest.toml`
#   [4fba245c] ↑ ArrayInterface v7.10.0 ⇒ v7.11.0
#   [411431e0] ↑ Extents v0.1.2 ⇒ v0.1.3
#   [d1acc4aa] ↑ IntervalArithmetic v0.22.13 ⇒ v0.22.14
# ⌅ [7f8f8fb0] + LearnBase v0.3.0
# ⌃ [9920b226] + MLDataPattern v0.5.4
#   [cc2ba9b6] + MLDataUtils v0.5.4
#   [66a33bbf] + MLLabelUtils v0.5.7
#   [b8a86587] ↑ NearestNeighbors v0.4.16 ⇒ v0.4.17
#   [f27b6e38] ↑ Polynomials v4.0.9 ⇒ v4.0.11
#   [90137ffa] ↑ StaticArrays v1.9.4 ⇒ v1.9.5
#   [1e83bf80] ↑ StaticArraysCore v1.4.2 ⇒ v1.4.3
# ⌅ [2913bbd2] ↓ StatsBase v0.34.3 ⇒ v0.33.21
#   [c2297ded] ↑ ZMQ v1.2.5 ⇒ v1.2.6
#         Info Packages marked with ⌃ and ⌅ have new versions available. Those with ⌃ may be upgradable, but those with ⌅ are restricted by compatibility constraints from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#     658.4 ms  ✓ StaticArraysCore
#    1160.6 ms  ✓ Extents
#     491.4 ms  ✓ DiffResults
#     942.3 ms  ✓ GeoInterface
#    2313.9 ms  ✓ StatsBase
#    2543.7 ms  ✓ IntervalArithmetic
#    2519.9 ms  ✓ ZMQ
#     728.1 ms  ✓ LearnBase
#     971.2 ms  ✓ MLLabelUtils
#    1247.0 ms  ✓ MLDataPattern
#    3480.1 ms  ✓ ForwardDiff
#     850.7 ms  ✓ LogarithmicNumbers → LogarithmicNumbersForwardDiffExt
#    1790.9 ms  ✓ IntervalArithmetic → IntervalArithmeticForwardDiffExt
#    7079.0 ms  ✓ StaticArrays
#    2585.7 ms  ✓ MLDataUtils
#     844.3 ms  ✓ IntervalArithmetic → IntervalArithmeticRecipesBaseExt
#     655.9 ms  ✓ ConstructionBase → ConstructionBaseStaticArraysExt
#     650.0 ms  ✓ Adapt → AdaptStaticArraysExt
#     663.7 ms  ✓ StaticArrays → StaticArraysStatisticsExt
#     932.4 ms  ✓ ForwardDiff → ForwardDiffStaticArraysExt
#     639.0 ms  ✓ StructArrays → StructArraysStaticArraysExt
#     700.5 ms  ✓ ArrayInterface
#     878.6 ms  ✓ Accessors → AccessorsStaticArraysExt
#    1043.1 ms  ✓ Setfield
#     676.8 ms  ✓ StaticArrays → StaticArraysChainRulesCoreExt
#     713.0 ms  ✓ ArrayInterface → ArrayInterfaceStaticArraysCoreExt
#    1074.7 ms  ✓ BangBang → BangBangStaticArraysExt
#    1215.9 ms  ✓ SplittablesBase
#    1341.1 ms  ✓ ArnoldiMethod
#    2182.4 ms  ✓ NearestNeighbors
#    2170.4 ms  ✓ Interpolations
#    1458.5 ms  ✓ FiniteDiff
#    3925.7 ms  ✓ ExactPredicates
#    2941.8 ms  ✓ Transducers
#    1292.0 ms  ✓ Interpolations → InterpolationsUnitfulExt
#    5774.1 ms  ✓ GeometryBasics
#    1000.0 ms  ✓ FiniteDiff → FiniteDiffStaticArraysExt
#    4067.6 ms  ✓ Graphs
#    2003.8 ms  ✓ Transducers → TransducersDataFramesExt
#    1423.0 ms  ✓ NetworkLayout
#    1203.7 ms  ✓ Packing
#    1560.8 ms  ✓ ShaderAbstractions
#    2493.0 ms  ✓ FreeTypeAbstraction
#    5996.4 ms  ✓ GridLayoutBase
#    1541.1 ms  ✓ NLSolversBase
#    3070.6 ms  ✓ MetaGraphs
#    3025.0 ms  ✓ TikzGraphs
#    1251.7 ms  ✓ Transducers → TransducersReferenceablesExt
#   10670.9 ms  ✓ KernelDensity
#    2336.7 ms  ✓ NetworkLayout → NetworkLayoutGraphsExt
#   20064.8 ms  ✓ Polynomials
#    2983.3 ms  ✓ LineSearches
#    1573.5 ms  ✓ Polynomials → PolynomialsFFTWExt
#    2611.0 ms  ✓ ThreadsX
#    1008.8 ms  ✓ Polynomials → PolynomialsChainRulesCoreExt
#    5949.4 ms  ✓ MathTeXEngine
#    3776.1 ms  ✓ Optim
#    2215.8 ms  ✓ Polynomials → PolynomialsMakieCoreExt
#    2405.9 ms  ✓ SimplePolynomials
#    1388.7 ms  ✓ LinearAlgebraX
#    4794.3 ms  ✓ DSP
#    3722.6 ms  ✓ SimpleGraphs
#    4287.5 ms  ✓ DelaunayTriangulation
#    9241.2 ms  ✓ Lasso
#   21667.8 ms  ✓ CausalInference
#   61349.7 ms  ✓ Plots → GeometryBasicsExt
#   63011.8 ms  ✓ Makie
#    6722.7 ms  ✓ GraphMakie
#    5630.7 ms  ✓ CausalInference → GraphMakieExt
#    2699.2 ms  ✓ CausalInference → TikzGraphsExt
#   22617.0 ms  ✓ CairoMakie
#   71 dependencies successfully precompiled in 134 seconds. 375 already precompiled.
#   2 dependencies precompiled but different versions are currently loaded. Restart julia to access the new versions
# [ Info: Precompiling MLDataUtils [cc2ba9b6-d476-5e6d-8eaf-a92d5412d41d] (cache misses: wrong dep version loaded (2))
#    Resolving package versions...
#     Updating `C:\Users\Alvaro\.julia\environments\v1.11\Project.toml`
#   [f0e99cf1] + MLBase v0.9.2
#   No Changes to `C:\Users\Alvaro\.julia\environments\v1.11\Manifest.toml`
# Precompiling project...
#    2872.8 ms  ✓ Plots → FileIOExt
#    2999.8 ms  ✓ Plots → UnitfulExt
#    5839.5 ms  ✓ Plots → IJuliaExt
#   3 dependencies successfully precompiled in 14 seconds. 443 already precompiled.
# [ Info: Precompiling MLBase [f0e99cf1-93fa-52ec-9ecc-5026115318e0] (cache misses: wrong dep version loaded (2))
#    Resolving package versions...
#    Installed FixedEffectModels ─ v1.11.0
#    Installed Vcov ────────────── v0.8.1
#    Installed GroupedArrays ───── v0.3.3
#    Installed FixedEffects ────── v2.4.0
#     Updating `C:\Users\Alvaro\.julia\environments\v1.11\Project.toml`
#   [9d5cd8c9] + FixedEffectModels v1.11.0
#     Updating `C:\Users\Alvaro\.julia\environments\v1.11\Manifest.toml`
#   [9d5cd8c9] + FixedEffectModels v1.11.0
#   [c8885935] + FixedEffects v2.4.0
#   [6407cd72] + GroupedArrays v0.3.3
#   [ec2bfdc2] + Vcov v0.8.1
# Precompiling project...
#     715.9 ms  ✓ GroupedArrays
#    3787.0 ms  ✓ FixedEffects
#    4109.4 ms  ✓ Lasso
#   11927.3 ms  ✓ Vcov
#   14617.2 ms  ✓ FixedEffectModels
#   5 dependencies successfully precompiled in 28 seconds. 445 already precompiled.
# [ Info: Precompiling FixedEffectModels [9d5cd8c9-2029-5cab-9928-427838db53e3] (cache misses: wrong dep version loaded (2))
#    Resolving package versions...
#   No Changes to `C:\Users\Alvaro\.julia\environments\v1.11\Project.toml`
#   No Changes to `C:\Users\Alvaro\.julia\environments\v1.11\Manifest.toml`
# [ Info: Precompiling Lasso [b4fcebef-c861-5a0f-a7e2-ba9dc32b180a] (cache misses: wrong dep version loaded (2))
#    Resolving package versions...
#    Installed EarlyStopping ──────────── v0.3.0
#    Installed ShowCases ──────────────── v0.1.0
#    Installed StatisticalTraits ──────── v3.3.0
#    Installed MLJFlow ────────────────── v0.1.1
#    Installed IterationControl ───────── v0.5.4
#    Installed MLJIteration ───────────── v0.5.1
#    Installed MLJModels ──────────────── v0.16.17
#    Installed CategoricalDistributions ─ v0.1.15
#    Installed PrettyPrinting ─────────── v0.4.2
#    Installed MLJBase ────────────────── v0.21.14
#    Installed ComputationalResources ─── v0.3.2
#    Installed ScientificTypes ────────── v3.0.2
#    Installed ARFFFiles ──────────────── v1.4.1
#    Installed OpenML ─────────────────── v0.3.1
#    Installed MLJ ────────────────────── v0.19.5
#    Installed MLJEnsembles ───────────── v0.3.3
#    Installed MLJTuning ──────────────── v0.7.4
#    Installed StableRNGs ─────────────── v1.0.2
#    Installed MLJModelInterface ──────── v1.10.0
#    Installed LatinHypercubeSampling ─── v1.9.0
#    Installed MLFlowClient ───────────── v0.4.7
#    Installed ScientificTypesBase ────── v3.0.0
#    Installed LossFunctions ──────────── v0.11.1
#     Updating `C:\Users\Alvaro\.julia\environments\v1.11\Project.toml`
# ⌃ [add582a8] + MLJ v0.19.5
#     Updating `C:\Users\Alvaro\.julia\environments\v1.11\Manifest.toml`
#   [da404889] + ARFFFiles v1.4.1
#   [af321ab8] + CategoricalDistributions v0.1.15
#   [ed09eef8] + ComputationalResources v0.3.2
#   [792122b4] + EarlyStopping v0.3.0
#   [b3c1a2ee] + IterationControl v0.5.4
#   [a5e1c1ea] + LatinHypercubeSampling v1.9.0
#   [30fc2ffe] + LossFunctions v0.11.1
# ⌅ [64a0f543] + MLFlowClient v0.4.7
# ⌃ [add582a8] + MLJ v0.19.5
# ⌅ [a7f614a8] + MLJBase v0.21.14
# ⌅ [50ed68f4] + MLJEnsembles v0.3.3
# ⌅ [7b7b8358] + MLJFlow v0.1.1
# ⌅ [614be32b] + MLJIteration v0.5.1
#   [e80e1ace] + MLJModelInterface v1.10.0
# ⌅ [d491faf4] + MLJModels v0.16.17
# ⌅ [03970b2e] + MLJTuning v0.7.4
#   [8b6db2d4] + OpenML v0.3.1
#   [54e16d92] + PrettyPrinting v0.4.2
#   [321657f4] + ScientificTypes v3.0.2
#   [30f210dd] + ScientificTypesBase v3.0.0
#   [605ecd9f] + ShowCases v0.1.0
#   [860ef19b] + StableRNGs v1.0.2
#   [64bff920] + StatisticalTraits v3.3.0
#         Info Packages marked with ⌃ and ⌅ have new versions available. Those with ⌃ may be upgradable, but those with ⌅ are restricted by compatibility constraints from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#     733.5 ms  ✓ ScientificTypesBase
#     791.2 ms  ✓ ShowCases
#     786.7 ms  ✓ StableRNGs
#     895.6 ms  ✓ ComputationalResources
#    2451.8 ms  ✓ PrettyPrinting
#     591.0 ms  ✓ StatisticalTraits
#     673.2 ms  ✓ EarlyStopping
#    1148.5 ms  ✓ ARFFFiles
#     985.8 ms  ✓ MLJModelInterface
#    1076.5 ms  ✓ LatinHypercubeSampling
#    1654.6 ms  ✓ MLFlowClient
#    2132.3 ms  ✓ LossFunctions
#     503.6 ms  ✓ LossFunctions → LossFunctionsCategoricalArraysExt
#    1389.7 ms  ✓ IterationControl
#    2017.8 ms  ✓ ScientificTypes
#    1531.1 ms  ✓ OpenML
#    1294.2 ms  ✓ CategoricalDistributions
#    5708.6 ms  ✓ MLJModels
#    6943.3 ms  ✓ MLJBase
#    1864.6 ms  ✓ MLJEnsembles
#    2069.2 ms  ✓ MLJTuning
#    2223.3 ms  ✓ MLJFlow
#    2472.3 ms  ✓ MLJIteration
#    3188.0 ms  ✓ MLJ
#   24 dependencies successfully precompiled in 20 seconds. 450 already precompiled.
# [ Info: Precompiling MLJ [add582a8-e3ab-11e8-2d5e-e98b27df1bc7] (cache misses: wrong dep version loaded (2))
#    Resolving package versions...
#    Installed ScikitLearnBase ─ v0.5.0
#    Installed DecisionTree ──── v0.12.4
#     Updating `C:\Users\Alvaro\.julia\environments\v1.11\Project.toml`
#   [7806a523] + DecisionTree v0.12.4
#     Updating `C:\Users\Alvaro\.julia\environments\v1.11\Manifest.toml`
#   [7806a523] + DecisionTree v0.12.4
#   [6e75b9c4] + ScikitLearnBase v0.5.0
# Precompiling project...
#     740.0 ms  ✓ ScikitLearnBase
#     822.3 ms  ✓ DecisionTree
#   2 dependencies successfully precompiled in 3 seconds. 474 already precompiled.
#    Resolving package versions...
#   No Changes to `C:\Users\Alvaro\.julia\environments\v1.11\Project.toml`
#   No Changes to `C:\Users\Alvaro\.julia\environments\v1.11\Manifest.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\Alvaro\.julia\environments\v1.11\Project.toml`
#   No Changes to `C:\Users\Alvaro\.julia\environments\v1.11\Manifest.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\Alvaro\.julia\environments\v1.11\Project.toml`
#   No Changes to `C:\Users\Alvaro\.julia\environments\v1.11\Manifest.toml`
# (nothing, nothing)

# %%
using Pkg, CSV, DataFrames, StatsModels, GLM, Random, RData, MLDataUtils, MLBase, FixedEffectModels, Lasso, MLJ, DecisionTree, GLMNet, PrettyTables
