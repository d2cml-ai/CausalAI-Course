# %%
import pandas as pd
import numpy as np

# %%
data_path = "../../data/wage2015_subsample_inference.csv"
data_read = pd.read_csv(data_path)
data = data_read.describe(include='all').drop(columns=['rownames'])

# %%
Let's have a look at the structure of the data.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, count to max
# Data columns (total 20 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   wage    8 non-null      float64
#  1   lwage   8 non-null      float64
#  2   sex     8 non-null      float64
#  3   shs     8 non-null      float64
#  4   hsg     8 non-null      float64
#  5   scl     8 non-null      float64
#  6   clg     8 non-null      float64
#  7   ad      8 non-null      float64
#  8   mw      8 non-null      float64
#  9   so      8 non-null      float64
#  10  we      8 non-null      float64
#  11  ne      8 non-null      float64
#  12  exp1    8 non-null      float64
#  13  exp2    8 non-null      float64
#  14  exp3    8 non-null      float64
#  15  exp4    8 non-null      float64
#  16  occ     8 non-null      float64
#  17  occ2    8 non-null      float64
#  18  ind     8 non-null      float64
#  19  ind2    8 non-null      float64
# dtypes: float64(20)
# ...

# %%
data.describe()
# Out:
#               wage        lwage          sex          shs          hsg  \
# count     8.000000     8.000000     8.000000     8.000000     8.000000
# mean    723.343895   646.224796   644.117678   643.896772   643.959169
# std    1797.565320  1819.800788  1820.651445  1820.740689  1820.715478
# min       3.021978     0.570385     0.000000     0.000000     0.000000
# 25%      17.788462     2.226355     0.000000     0.000000     0.000000
# 50%      22.206713     2.963649     0.470710     0.011650     0.121942
# 75%     153.044752     4.060851     1.000000     0.363154     0.572099
# max    5150.000000  5150.000000  5150.000000  5150.000000  5150.000000
#
#                scl          clg           ad           mw           so  \
# count     8.000000     8.000000     8.000000     8.000000     8.000000
# mean    644.090768   644.097911   643.935133   644.087259   644.094158
# std    1820.662318  1820.659432  1820.725189  1820.663736  1820.660948
# ...
